# %% [markdown]
# <a href="https://colab.research.google.com/github/joelpolizzi/DSC210-group_proj/blob/main/Transformer_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Personalized Recommendations with Transformers

# %% [markdown]
# ## Installing and importing packages

# %%
# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (24.3.1)

# %%
# !python3 -m pip install \
datasets \
implicit \
scikit-surprise
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.1.0)
# Requirement already satisfied: implicit in /usr/local/lib/python3.10/dist-packages (0.7.2)
# Requirement already satisfied: scikit-surprise in /usr/local/lib/python3.10/dist-packages (1.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.26.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: scipy>=0.16 in /usr/local/lib/python3.10/dist-packages (from implicit) (1.13.1)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.10/dist-packages (from implicit) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
import gzip
import random
import scipy
import pandas as pd
# import tensorflow as tf

from collections import defaultdict
from datasets import load_dataset
from implicit import bpr
from surprise import SVD, Reader, Dataset
from surprise.model_selection import train_test_split

import time
import math
import os
from tempfile import TemporaryDirectory
from typing import Tuple

import torch
from torch import nn, Tensor
from torch.nn import TransformerEncoder, TransformerEncoderLayer
# from torch.utils.data import dataset
# from torch.utils.data import DataLoader, Dataset
from torch.nn.utils.rnn import pad_sequence

from collections import Counter

from zipfile import ZipFile
from urllib.request import urlretrieve

import numpy as np

# %% [markdown]
# ## Loading and processing data

# %%
dataset = load_dataset("McAuley-Lab/Amazon-Reviews-2023", "raw_review_Musical_Instruments", trust_remote_code=True)
print(dataset["full"][0])
dataset_items = load_dataset("McAuley-Lab/Amazon-Reviews-2023", "raw_meta_Musical_Instruments", trust_remote_code=True)
print(dataset_items["full"][0])

#Print our splits
print(dataset.keys())
print(len(dataset["full"]))
print(dataset_items.keys())
print(len(dataset_items["full"]))
# Out:
# {'rating': 5.0, 'title': 'Five Stars', 'text': 'Great headphones, comfortable and sound is good. No complaints. I would buy again.', 'images': [], 'asin': 'B003LPTAYI', 'parent_asin': 'B003LPTAYI', 'user_id': 'AGKASBHYZPGTEPO6LWZPVJWB2BVA', 'timestamp': 1452650586000, 'helpful_vote': 0, 'verified_purchase': True}
# {'main_category': 'Musical Instruments', 'title': 'Pearl Export Lacquer EXL725S/C249 5-Piece New Fusion Drum Set with Hardware, Honey Amber', 'average_rating': 4.2, 'rating_number': 22, 'features': ['Item may ship in more than one box and may arrive separately', '(22x18, 10x7, 12x8, 16x16, 14x5.5)', 'P930 Demonator Pedal', '830 Hardware Pack', 'Matching snare, REMO snare batter side head'], 'description': ["Introducing the best selling drum set of all time... Export Series returns and this time with a lacquer finish. EXL Export Lacquer Series incorporates Pearl's S.S.T. Superior Shell Technology, Opti-Loc tom mounts, all-new 830 Series Hardware with a P-930 Pedal, and a choice of three amazing stocking finishes."], 'price': 'None', 'images': {'hi_res': ['https://m.media-amazon.com/images/I/91RuLqvx9IL._AC_SL1500_.jpg', 'https://m.media-amazon.com/images/I/81q8vubRs-L._AC_SL1500_.jpg', None, 'https://m.media-amazon.com/images/I/81ubSuvhnrL._AC_SL1500_.jpg', 'https://m.media-amazon.com/images/I/91MvZAf9woL._AC_SL1500_.jpg', 'https://m.media-amazon.com/images/I/71p4fUTsW+L._AC_SL1500_.jpg'], 'large': ['https://m.media-amazon.com/images/I/51QYyZgky-L._AC_.jpg', 'https://m.media-amazon.com/images/I/514Z7v65vML._AC_.jpg', 'https://m.media-amazon.com/images/I/41hXkmnBrWL._AC_.jpg', 'https://m.media-amazon.com/images/I/41kWp31FmJL._AC_.jpg', 'https://m.media-amazon.com/images/I/51bv35g1LOL._AC_.jpg', 'https://m.media-amazon.com/images/I/41GGimItXEL._AC_.jpg'], 'thumb': ['https://m.media-amazon.com/images/I/51QYyZgky-L._AC_US40_.jpg', 'https://m.media-amazon.com/images/I/514Z7v65vML._AC_US40_.jpg', 'https://m.media-amazon.com/images/I/41hXkmnBrWL._AC_US40_.jpg', 'https://m.media-amazon.com/images/I/41kWp31FmJL._AC_US40_.jpg', 'https://m.media-amazon.com/images/I/51bv35g1LOL._AC_US40_.jpg', 'https://m.media-amazon.com/images/I/41GGimItXEL._AC_US40_.jpg'], 'variant': ['MAIN', 'PT01', 'PT02', 'PT03', 'PT04', 'PT12']}, 'videos': {'title': ['Best Selling Drum Set of All Time'], 'url': ['https://www.amazon.com/vdp/0be29e27175a4280aa9c2027ec3664b4?ref=dp_vse_rvc_0'], 'user_id': ['']}, 'store': 'Pearl', 'categories': ['Musical Instruments', 'Drums & Percussion', 'Drum Sets & Set Components', 'Drum Sets'], 'details': '{"Item Weight": "33 pounds", "Product Dimensions": "22 x 22 x 20 inches", "Item model number": "EXL725S/C249", "Best Sellers Rank": {"Musical Instruments": 150300, "Drum Sets": 521}, "Date First Available": "April 4, 2014", "Color Name": "Honey Amber", "Material Type": "Pearl", "Size": "-inch", "Color": "Honey Amber", "Brand": "Pearl", "Material": "Pearl", "Model Name": "EXL725S", "Item Dimensions LxWxH": "22 x 22 x 20 inches"}', 'parent_asin': 'B01M4HO6RK', 'bought_together': None, 'subtitle': None, 'author': None}
# dict_keys(['full'])
# 3017439
# dict_keys(['full'])
# 213593

# %%
from surprise import Dataset, Reader
df = pd.DataFrame(dataset['full'][:len(dataset['full']) // 10]).sample(frac=0.5)
print(df.head())

print(df.dtypes)
reader = Reader(rating_scale=(1, 5))

surprise_data = Dataset.load_from_df(df[['title', 'text', 'rating']], reader)
# Out:
#         rating                  title  \
# 101634     5.0           Good product
# 22914      5.0            Music items
# 106836     3.0  not bad, not great...
# 254876     4.0  Quick, Easy & Works !
# 170442     5.0                   Good
#
#                                                      text  \
# 101634  Very nice and smooth switch, it has some weigh...
# 22914                                  My son loves it!!!
# 106836  My problem with this is mostly physical...<br ...
# 254876  [[VIDEOID:79d38c2c24de7d02b1a3a625b9dee531]] F...
# 170442                          Works good with Bluetooth
#
#                                                    images        asin  \
# 101634                                                 []  B07K67HRDN
# 22914                                                  []  B07GV76CVV
# 106836                                                 []  B00FQRW550
# 254876  [{'attachment_type': 'IMAGE', 'large_image_url...  B0BKL45WFZ
# 170442                                                 []  B0816K2XSR
#
#        parent_asin                       user_id      timestamp  helpful_vote  \
# 101634  B07K66F3N8  AHRK4WSXDUQA7GQCTQ7J5AV6XYLA  1560139628157             0
# 22914   B07GV76CVV  AGHQGLTEWXMXT4OIBYNQ5PK6MP7A  1567536993005             0
# 106836  B00FQRW550  AF27NCKSP7PLYDMXGIBRWDL6TZYA  1442769446000             3
# 254876  B0BKL45WFZ  AGTSDKNSMSCJPEODGBQ7W26H2RSA  1674779826075             0
# 170442  B0BTYX2DVY  AHM5CZPOBDN6IEZYOKNYRKITSHGQ  1613644497909             0
#
#         verified_purchase
# 101634               True
# 22914                True
# 106836               True
# 254876              False
# 170442               True
# rating               float64
# title                 object
# text                  object
# images                object
# asin                  object
# parent_asin           object
# user_id               object
# timestamp              int64
# helpful_vote           int64
# verified_purchase       bool
# dtype: object

# %%
df["user_id"] = df["user_id"].apply(lambda x: f"user_{x}")
df["item_id"] = df["asin"].apply(lambda x: f"item_{x}")

# %%
# Genarting a list of unique item ids
item_ids = df.item_id.unique()

# Counter is used to feed items to item_vocab
item_counter = Counter(item_ids)

# Generating vocabulary for items
# Start by creating a mapping for items (assign indices manually)
special_token = '<unk>'
item_vocab_stoi = {special_token: 0}  # Add special token at index 0
item_vocab_stoi.update({item: idx for idx, item in enumerate(item_ids, start=1)})

# Item to title mapping dictionary
item_title_dict = dict(zip(df.item_id, df.title))

# Similarly generating a vocabulary for user ids
user_ids = df['user_id'].unique()
user_counter = Counter(user_ids)

# Generate vocabulary for users
user_vocab_stoi = {special_token: 0}  # Add special token at index 0
user_vocab_stoi.update({user: idx for idx, user in enumerate(user_ids, start=1)})

# Reverse mapping (index to user) if needed
user_vocab_itos = {idx: user for user, idx in user_vocab_stoi.items()}

# %%
# Group ratings by user_id in order of increasing timestamp.
ratings_group = df.sort_values(by=["timestamp"]).groupby("user_id")

# %%
ratings_data = pd.DataFrame(
    data={
        "user_id": list(ratings_group.groups.keys()),
        "item_id": list(ratings_group.item_id.apply(list)),
        "timestamps": list(ratings_group.timestamp.apply(list)),
    }
)

# %%
# Sequence length, min history count and window slide size
sequence_length = 4
min_history = 1
step_size = 2

# Creating sequences from lists with sliding window
def create_sequences(values, window_size, step_size, min_history):
  sequences = []
  start_index = 0
  while len(values[start_index:]) > min_history:
    seq = values[start_index : start_index + window_size]
    sequences.append(seq)
    start_index += step_size
  return sequences

ratings_data.item_id = ratings_data.item_id.apply(
    lambda ids: create_sequences(ids, sequence_length, step_size, min_history)
)

del ratings_data["timestamps"]

# Sub-sequences are exploded.
# Since there might be more than one sequence for each user.
ratings_data_transformed = ratings_data[["user_id", "item_id"]].explode(
    "item_id", ignore_index=True
)

# Remove rows where 'item_id' contains NaN or empty sequences
ratings_data_transformed = ratings_data_transformed.dropna(subset=['item_id'])
ratings_data_transformed = ratings_data_transformed[ratings_data_transformed['item_id'].apply(lambda x: isinstance(x, list) and len(x) > 0)]

ratings_data_transformed.rename(
    columns={"item_id": "sequence_item_id"},
    inplace=True,
)

# %%
# Random indexing
random_selection = np.random.rand(len(ratings_data_transformed.index)) <= 0.85

# Split train data
df_train_data = ratings_data_transformed[random_selection]
train_data_raw = df_train_data[["user_id", "sequence_item_id"]].values

# Split test data
df_test_data = ratings_data_transformed[~random_selection]
test_data_raw = df_test_data[["user_id", "sequence_item_id"]].values

# %%
# Pytorch Dataset for user interactions
class ItemSeqDataset(Dataset):
    # Initialize dataset
    def __init__(self, data, item_vocab_stoi, user_vocab_stoi):
        self.data = data
        self.item_vocab_stoi = item_vocab_stoi
        self.user_vocab_stoi = user_vocab_stoi


    def __len__(self):
        return len(self.data)

    # Fetch data from the dataset
    def __getitem__(self, idx):
        user, item_sequence = self.data[idx]
        # Directly index into the vocabularies
        item_data = [self.item_vocab_stoi[item] for item in item_sequence]
        user_data = self.user_vocab_stoi[user]
        return torch.tensor(item_data), torch.tensor(user_data)


# Collate function and padding
def collate_batch(batch):
    item_list = [item[0] for item in batch]
    user_list = [item[1] for item in batch]
    return pad_sequence(item_list, padding_value=item_vocab_stoi['<unk>'], batch_first=True), torch.stack(user_list)


BATCH_SIZE = 256
# Create instances of your Dataset for each set
train_dataset = ItemSeqDataset(train_data_raw, item_vocab_stoi, user_vocab_stoi)
val_dataset = ItemSeqDataset(test_data_raw, item_vocab_stoi, user_vocab_stoi)
# Create DataLoaders
train_iter = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                        shuffle=True, collate_fn=collate_batch)
val_iter = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                      shuffle=False, collate_fn=collate_batch)

# %% [markdown]
# ## Model definition

# %%
class TransformerModel(nn.Module):
    def __init__(self, ntoken: int, nuser: int, d_model: int, nhead: int, d_hid: int,
                 nlayers: int, dropout: float = 0.5):
        super().__init__()
        self.model_type = 'Transformer'
        # positional encoder
        self.pos_encoder = PositionalEncoding(d_model, dropout)

        # Multihead attention mechanism.
        encoder_layers = TransformerEncoderLayer(d_model, nhead, d_hid, dropout)
        self.transformer_encoder = TransformerEncoder(encoder_layers, nlayers)

        # Embedding layers
        self.movie_embedding = nn.Embedding(ntoken, d_model)
        self.user_embedding = nn.Embedding(nuser, d_model)

        # Defining the size of the input to the model.
        self.d_model = d_model

        # Linear layer to map the output tomovie vocabulary.
        self.linear = nn.Linear(2*d_model, ntoken)

        self.init_weights()

    def init_weights(self) -> None:
        # Initializing the weights of the embedding and linear layers.
        initrange = 0.1
        self.movie_embedding.weight.data.uniform_(-initrange, initrange)
        self.user_embedding.weight.data.uniform_(-initrange, initrange)
        self.linear.bias.data.zero_()
        self.linear.weight.data.uniform_(-initrange, initrange)

    def forward(self, src: Tensor, user: Tensor, src_mask: Tensor = None) -> Tensor:
        # Embedding movie ids and userid
        movie_embed = self.movie_embedding(src) * math.sqrt(self.d_model)
        user_embed = self.user_embedding(user) * math.sqrt(self.d_model)

        # positional encoding
        movie_embed = self.pos_encoder(movie_embed)

        # generating output with final layers
        output = self.transformer_encoder(movie_embed, src_mask)

        # Expand user_embed tensor along the sequence length dimension
        user_embed = user_embed.expand(-1, output.size(1), -1)

        # Concatenate user embeddings with transformer output
        output = torch.cat((output, user_embed), dim=-1)

        output = self.linear(output)
        return output

# %%
ntokens = len(item_vocab_stoi)  # size of vocabulary
nusers = len(user_vocab_stoi)
emsize = 128  # embedding dimension
d_hid = 128  # dimension of the feedforward network model
nlayers = 2  # number of ``nn.TransformerEncoderLayer``
nhead = 2  # number of heads in ``nn.MultiheadAttention``
dropout = 0.2  # dropout probability

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = TransformerModel(ntokens, nusers, emsize, nhead, d_hid, nlayers, dropout).to(device)

criterion = nn.CrossEntropyLoss()
lr = 1.0  # learning rate
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(

# %%
def train(model: nn.Module, train_iter, epoch) -> None:
    # Switch to training mode
    model.train()
    total_loss = 0.
    log_interval = 200
    start_time = time.time()

    for i, (item_data, user_data) in enumerate(train_iter):
        # Load movie sequence and user id
        item_data, user_data = item_data.to(device), user_data.to(device)
        user_data = user_data.reshape(-1, 1)

        # Split movie sequence to inputs and targets
        inputs, targets = item_data[:, :-1], item_data[:, 1:]
        targets_flat = targets.reshape(-1)

        # Predict movies
        output = model(inputs, user_data)
        output_flat = output.reshape(-1, ntokens)

        # Backpropogation process
        loss = criterion(output_flat, targets_flat)
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()

        total_loss += loss.item()
        # Results
        if i % log_interval == 0 and i > 0:
            lr = scheduler.get_last_lr()[0]
            ms_per_batch = (time.time() - start_time) * 1000 / log_interval
            cur_loss = total_loss / log_interval
            ppl = math.exp(cur_loss)
            print(f'| epoch {epoch:3d} '
                  f'lr {lr:02.2f} | ms/batch {ms_per_batch:5.2f} | '
                  f'loss {cur_loss:5.2f} | ppl {ppl:8.2f}')
            total_loss = 0
            start_time = time.time()

# %%
def evaluate(model: nn.Module, eval_data: Tensor) -> float:
    # Switch the model to evaluation mode.
    # This is necessary for layers like dropout,
    model.eval()
    total_loss = 0.

    with torch.no_grad():
        for i, (item_data, user_data) in enumerate(eval_data):
            # Load item sequence and user id
            item_data, user_data = item_data.to(device), user_data.to(device)
            user_data = user_data.reshape(-1, 1)
            # Split item sequence to inputs and targets
            inputs, targets = item_data[:, :-1], item_data[:, 1:]
            targets_flat = targets.reshape(-1)
            # Predict item
            output = model(inputs, user_data)
            output_flat = output.reshape(-1, ntokens)
            # Calculate loss
            loss = criterion(output_flat, targets_flat)
            total_loss += loss.item()
    return total_loss / (len(eval_data) - 1)

# %%
best_val_loss = float('inf')
epochs = 10

with TemporaryDirectory() as tempdir:
    best_model_params_path = os.path.join(tempdir, "best_model_params.pt")

    for epoch in range(1, epochs + 1):
        epoch_start_time = time.time()

        # Training
        train(model, train_iter, epoch)

        # Evaluation
        val_loss = evaluate(model, val_iter)

        # Compute the perplexity of the validation loss
        val_ppl = math.exp(val_loss)
        elapsed = time.time() - epoch_start_time

        # Results
        print('-' * 89)
        print(f'| end of epoch {epoch:3d} | time: {elapsed:5.2f}s | '
            f'valid loss {val_loss:5.2f} | valid ppl {val_ppl:8.2f}')
        print('-' * 89)

        # Save best model
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), best_model_params_path)

        scheduler.step()
    model.load_state_dict(torch.load(best_model_params_path)) # load best model states
# Out:
# Streaming output truncated to the last 5000 lines.
# Item Sequence for idx 1441: ['item_B07HDB12FM', 'item_B00BHQXM8S', 'item_B0160ACNAI', 'item_B07TXZGRNQ']
# Item Sequence for idx 1442: ['item_B0002DV7ZM', 'item_B00P9QAH6W']
# Item Sequence for idx 1443: ['item_B01E6T56EA', 'item_B07PNF5WJK']
# Item Sequence for idx 1444: ['item_B0002H0H0E', 'item_B001LXMXU0', 'item_B0778PW65J']
# Item Sequence for idx 1445: ['item_B001OQCC3W', 'item_B001OQCC50', 'item_B008YRW6CQ', 'item_B07993X771']
# Item Sequence for idx 1446: ['item_B07CXN5Y7D', 'item_B082VSRLKB', 'item_B0921VB2D4', 'item_B09X785GLV']
# Item Sequence for idx 1447: ['item_B07XCQFG8S', 'item_B07ZRYKNGS']
# Item Sequence for idx 1448: ['item_B00PWXA1SG', 'item_B00302DN2C', 'item_B01DA8NFFA', 'item_B012S3KZWE']
# Item Sequence for idx 1449: ['item_B00HWTA7DM', 'item_B016APL8RC']
# Item Sequence for idx 1450: ['item_B00EDSUQWM', 'item_B00WZQSBBW', 'item_B001A62VAU', 'item_B01I47LBK8']
# Item Sequence for idx 1451: ['item_B001A62VAU', 'item_B01I47LBK8', 'item_B016XWCSSU', 'item_B07B8DCP7T']
# Item Sequence for idx 1452: ['item_B0006B05W6', 'item_B01D2PFJ8C', 'item_B0087UPXH0', 'item_B003LPTAYI']
# Item Sequence for idx 1453: ['item_B0087UPXH0', 'item_B003LPTAYI', 'item_B003BQ91Y6', 'item_B003PNFM7A']
# Item Sequence for idx 1454: ['item_B0034PDQPY', 'item_B000VJZOKG']
# Item Sequence for idx 1455: ['item_B000VTIT9O', 'item_B01LY3WGGL']
# Item Sequence for idx 1456: ['item_B0002GFQ1K', 'item_B001631N9M', 'item_B005L2R7FS', 'item_B0002D0MIU']
# Item Sequence for idx 1457: ['item_B01M08O7RY', 'item_B0061YYKXW', 'item_B01JZ69WZS', 'item_B0009FUPIS']
# Item Sequence for idx 1458: ['item_B00LTL0KLI', 'item_B07K8FQFN8']
# Item Sequence for idx 1459: ['item_B0163GXIVM', 'item_B087RBGXSK', 'item_B095S7WRXP', 'item_B09MZRQSTY']
# Item Sequence for idx 1460: ['item_B07V4ZVBS5', 'item_B0784RDPQT']
# Item Sequence for idx 1461: ['item_B01AM4PS78', 'item_B09DS1SCJM', 'item_B00IHVQ2FQ', 'item_B07RTYDX4Y']
# Item Sequence for idx 1462: ['item_B00IHVQ2FQ', 'item_B07RTYDX4Y', 'item_B003URZWLW', 'item_B085ZGN6LM']
# Item Sequence for idx 1463: ['item_B001J2GMDC', 'item_B00BKXN9LS', 'item_B01BNTYSKO']
# Item Sequence for idx 1464: ['item_B001D7UYBO', 'item_B002SMYUFY', 'item_B000KW4TZK', 'item_B000J5XS3C']
# Item Sequence for idx 1465: ['item_B000KW4TZK', 'item_B000J5XS3C', 'item_B0084CRYOG']
# Item Sequence for idx 1466: ['item_B000EEN9RI', 'item_B00AJHE5E6']
# Item Sequence for idx 1467: ['item_B002M8EEW8', 'item_B000EHWJ9O', 'item_B00I5DVLKC', 'item_B00JX22MIO']
# Item Sequence for idx 1468: ['item_B07BCQ7P7Z', 'item_B01M0817LI', 'item_B07CX2T7HH', 'item_B00XQEA1FG']
# Item Sequence for idx 1469: ['item_B003AZ28PM', 'item_B07HMWGDN8']
# Item Sequence for idx 1470: ['item_B01J5A06OU', 'item_B005DJOIPQ']
# Item Sequence for idx 1471: ['item_B003AYRK1K', 'item_B0002E2GMY']
# Item Sequence for idx 1472: ['item_B00DFU9GTS', 'item_B001RBQFCI', 'item_B000SZVZ74']
# Item Sequence for idx 1473: ['item_B00BHJNC4E', 'item_B001FWYAX0', 'item_B0002CZVXM', 'item_B00XH2Q9TO']
# Item Sequence for idx 1474: ['item_B00GXMLEO0', 'item_B01H62TQ68', 'item_B0010SHU18', 'item_B0002CZVXM']
# Item Sequence for idx 1475: ['item_B00Y4S5Z5O', 'item_B07FNGR17L', 'item_B0002D0CNA', 'item_B09LNFP6D9']
# Item Sequence for idx 1476: ['item_B00191WVF6', 'item_B07SB3HNPN']
# Item Sequence for idx 1477: ['item_B01N6PCKM9', 'item_B000X8CC2S', 'item_B07W7YX2DW']
# Item Sequence for idx 1478: ['item_B08YD1775G', 'item_B07V6KLP34']
# Item Sequence for idx 1479: ['item_B00RGKT2IS', 'item_B00MX3OO1S', 'item_B00P00G3EC', 'item_B012OHZJ8O']
# Item Sequence for idx 1480: ['item_B01G15DHHA', 'item_B073Z4MP9W', 'item_B000EENLDU', 'item_B07BT2GLBY']
# Item Sequence for idx 1481: ['item_B000EENLDU', 'item_B07BT2GLBY']
# Item Sequence for idx 1482: ['item_B0009G1E0K', 'item_B000L6GD04', 'item_B000EEJ8IM', 'item_B00WHLLDWO']
# Item Sequence for idx 1483: ['item_B007IHYBV2', 'item_B00646MZHK']
# Item Sequence for idx 1484: ['item_B004VQJF1Y', 'item_B00095VIMU', 'item_B00ISQCO6Q', 'item_B0002GYMBA']
# Item Sequence for idx 1485: ['item_B01MXVPQ0K', 'item_B077C4WXB8', 'item_B07BZJYRH4', 'item_B07D4RNWNJ']
# Item Sequence for idx 1486: ['item_B08M3JVSF2', 'item_B08227YV9T', 'item_B09HW1GYJ9', 'item_B09G2Z1H1G']
# Item Sequence for idx 1487: ['item_B01EPWGF8O', 'item_B09Q7R2YYB', 'item_B0769JX3RR']
# Item Sequence for idx 1488: ['item_B08Q36MHJG', 'item_B095JNR9BQ']
# Item Sequence for idx 1489: ['item_B0052VE85A', 'item_B00FB4679I']
# Item Sequence for idx 1490: ['item_B0064WE20C', 'item_B0002F4M4I', 'item_B00EADCPDS', 'item_B0002F6TNU']
# Item Sequence for idx 1491: ['item_B00G3M7502', 'item_B00EO4A7L0']
# Item Sequence for idx 1492: ['item_B005MR6IHK', 'item_B008BPI2OW']
# Item Sequence for idx 1493: ['item_B002CMLQ8E', 'item_B002CMLPYY', 'item_B00KZQ1VXY']
# Item Sequence for idx 1494: ['item_B07D6ZVDT6', 'item_B01B15JPCQ']
# Item Sequence for idx 1495: ['item_B001MZUD7C', 'item_B003H93BYI', 'item_B0002GO8NM']
# Item Sequence for idx 1496: ['item_B01LLFF6Q0', 'item_B0002OOMU8', 'item_B00XQEH5P0', 'item_B0002VSRR0']
# Item Sequence for idx 1497: ['item_B0188WO5SO', 'item_B002VJMFNS', 'item_B008XLITXS', 'item_B01G6PGQXC']
# Item Sequence for idx 1498: ['item_B0018R6AGM', 'item_B00191WVF6']
# Item Sequence for idx 1499: ['item_B000BNG668', 'item_B000V6E01I']
# Item Sequence for idx 1500: ['item_B00EWEHW2E', 'item_B00WHLLDWO', 'item_B003B0853U', 'item_B00XQCRR5U']
# Item Sequence for idx 1501: ['item_B00JB4WAR2', 'item_B0013PU75Y']
# Item Sequence for idx 1502: ['item_B012VQ5A7S', 'item_B08RC63ZD2', 'item_B014T6KIFM', 'item_B000T4SI1K']
# Item Sequence for idx 1503: ['item_B014T6KIFM', 'item_B000T4SI1K', 'item_B076V2QYSJ', 'item_B0002GL5S8']
# Item Sequence for idx 1504: ['item_B01DK7SZOW', 'item_B09TDH7BKP']
# Item Sequence for idx 1505: ['item_B00L5QAPYO', 'item_B01N1HJKKX', 'item_B07N27XQTD', 'item_B000CC4JFS']
# Item Sequence for idx 1506: ['item_B0009FUUO2', 'item_B0772MTRSH', 'item_B07GXGXPBY', 'item_B0002E1O4U']
# Item Sequence for idx 1507: ['item_B005HMQKBY', 'item_B004LYP6QO', 'item_B01IR2I1PS', 'item_B004I942W6']
# Item Sequence for idx 1508: ['item_B01IR2I1PS', 'item_B004I942W6', 'item_B01ETN32I0', 'item_B004THBOPK']
# Item Sequence for idx 1509: ['item_B08LYSJZ24', 'item_B000EEJ8CS']
# Item Sequence for idx 1510: ['item_B00191WVF6', 'item_B001L0VH3W', 'item_B002C741BI']
# Item Sequence for idx 1511: ['item_B003J7FJ98', 'item_B00BIBBKJA', 'item_B00KQGGIOK']
# Item Sequence for idx 1512: ['item_B004C3WAI6', 'item_B002KDHBRU', 'item_B07MQDXKTY', 'item_B07F2TLXQP']
# Item Sequence for idx 1513: ['item_B003ACL2CK', 'item_B0002FO8CY', 'item_B009P6D4TO']
# Item Sequence for idx 1514: ['item_B00948OEPQ', 'item_B005I7OLZU']
# Item Sequence for idx 1515: ['item_B00IY0BLB0', 'item_B000PCH4ZC', 'item_B0007WPHC2', 'item_B00B8ZFDQW']
# Item Sequence for idx 1516: ['item_B083Z82LCP', 'item_B0006H92QK', 'item_B07QR6Z1JB', 'item_B087KG23XH']
# Item Sequence for idx 1517: ['item_B00PA32WM6', 'item_B07TS5RYML']
# Item Sequence for idx 1518: ['item_B001C74GLY', 'item_B005IVUTUW', 'item_B001RIZ2R0', 'item_B001LEH7DC']
# Item Sequence for idx 1519: ['item_B001Q9EE4W', 'item_B004YUP4EY']
# Item Sequence for idx 1520: ['item_B000LPNRQ8', 'item_B07MVQFZS2', 'item_B0002DVMZ2', 'item_B000AC6DVS']
# Item Sequence for idx 1521: ['item_B00B8ZFDQW', 'item_B0002GZBO2']
# Item Sequence for idx 1522: ['item_B00B1YOENI', 'item_B005FKF1PY', 'item_B01N6E5ZNQ', 'item_B0087OS83M']
# Item Sequence for idx 1523: ['item_B000B86YR4', 'item_B00V5SNRK6']
# Item Sequence for idx 1524: ['item_B0B6VG742D', 'item_B0B4QNW69L']
# Item Sequence for idx 1525: ['item_B00T5PNYCW', 'item_B00D35CNL8', 'item_B00FM0MSDK', 'item_B00D8J0WM6']
# Item Sequence for idx 1526: ['item_B00CQ8AACM', 'item_B016LF8A0E', 'item_B00460UFD2', 'item_B00VNSOK2C']
# Item Sequence for idx 1527: ['item_B01A6B0ICC', 'item_B00CBISHS6']
# Item Sequence for idx 1528: ['item_B0055VBYWC', 'item_B0000775G0', 'item_B003VS6WSW']
# Item Sequence for idx 1529: ['item_B008Z65NIA', 'item_B08HVKYSN5']
# Item Sequence for idx 1530: ['item_B003JJQMD8', 'item_B07ZQ92L9M']
# Item Sequence for idx 1531: ['item_B00PMDPRJ4', 'item_B07J5QT23H', 'item_B00KVWK408']
# Item Sequence for idx 1532: ['item_B01H1Q2TDG', 'item_B06XBZCYHH']
# Item Sequence for idx 1533: ['item_B000OR6RCE', 'item_B00BEGS5NI', 'item_B0002F75K6', 'item_B000068NW5']
# Item Sequence for idx 1534: ['item_B004Z2G2T2', 'item_B00GOIC1S6', 'item_B00LJOBJVA', 'item_B003B0D2RO']
# Item Sequence for idx 1535: ['item_B003E0Y08Q', 'item_B001PGXIJ8', 'item_B00BHK2UHI', 'item_B004FGMBRU']
# Item Sequence for idx 1536: ['item_B004N1JFXK', 'item_B079X38XF1']
# Item Sequence for idx 1537: ['item_B0009JR9UG', 'item_B000EEHL7M', 'item_B002Q0WT6U', 'item_B000V6E01I']
# Item Sequence for idx 1538: ['item_B0006IQNCK', 'item_B002G1UT5C', 'item_B001MMYVZU', 'item_B000EEJ91I']
# Item Sequence for idx 1539: ['item_B004O37LM4', 'item_B095LPLGGB', 'item_B09BZBR5TY']
# Item Sequence for idx 1540: ['item_B00HEKIKYC', 'item_B08M45Y4VZ', 'item_B01M9FB6IJ']
# Item Sequence for idx 1541: ['item_B07BRPM8K8', 'item_B0007Y60HG', 'item_B0002M3OVI', 'item_B0019H6750']
# Item Sequence for idx 1542: ['item_B00CK2DM7Y', 'item_B005SUVFXI', 'item_B00BHJNC4E', 'item_B019BNMVFI']
# Item Sequence for idx 1543: ['item_B076F5W8Q5', 'item_B07B7NVFFJ']
# Item Sequence for idx 1544: ['item_B0039RPWJU', 'item_B000EEHBM2', 'item_B09KRXDW5P', 'item_B0014ZG676']
# Item Sequence for idx 1545: ['item_B072N6QKL7', 'item_B008I5QPZ8', 'item_B0002H0SYE', 'item_B004AE3W7U']
# Item Sequence for idx 1546: ['item_B0002F4MKM', 'item_B0002F4MKW', 'item_B0064RHZQ0', 'item_B002OYB7L6']
# Item Sequence for idx 1547: ['item_B019OO4IY6', 'item_B0040QKV18']
# Item Sequence for idx 1548: ['item_B008M0AY5G', 'item_B01571PTEI', 'item_B005K0IFBG']
# Item Sequence for idx 1549: ['item_B005168GB8', 'item_B079JJZXJ4']
# Item Sequence for idx 1550: ['item_B000EEJF4O', 'item_B00QYJ0YXE']
# Item Sequence for idx 1551: ['item_B002NPG2Z2', 'item_B004Z2ERZS', 'item_B003LZ2IT2']
# Item Sequence for idx 1552: ['item_B0007Y09VO', 'item_B000Y30NAA', 'item_B0002E1G5C']
# Item Sequence for idx 1553: ['item_B01D53KTEA', 'item_B00A7190M6', 'item_B00A270MZO']
# Item Sequence for idx 1554: ['item_B007O39HV4', 'item_B0002CZTI4', 'item_B0002E38DK']
# Item Sequence for idx 1555: ['item_B00191WVF6', 'item_B00JW44IXU', 'item_B00C29VZ7O', 'item_B0061OPQK8']
# Item Sequence for idx 1556: ['item_B09J88G29P', 'item_B09SFCW7XJ', 'item_B09VSXHWTG', 'item_B09XBFSLHJ']
# Item Sequence for idx 1557: ['item_B0009G1E0K', 'item_B0085C9TKM', 'item_B07K6GKMYF', 'item_B076TCJX1V']
# Item Sequence for idx 1558: ['item_B07K6GKMYF', 'item_B076TCJX1V']
# Item Sequence for idx 1559: ['item_B0050J268U', 'item_B000PGS5M4', 'item_B000PO1H94', 'item_B001WMC6WU']
# Item Sequence for idx 1560: ['item_B000068NYG', 'item_B002UKZ99U']
# Item Sequence for idx 1561: ['item_B01K9COJZK', 'item_B0002KZAKS', 'item_B087QDYBCC', 'item_B00XQCYRPI']
# Item Sequence for idx 1562: ['item_B004O77BJ8', 'item_B003EUHTZC', 'item_B0002OKGNK', 'item_B000RYPN38']
# Item Sequence for idx 1563: ['item_B0002OKGNK', 'item_B000RYPN38', 'item_B00HWRDSVM', 'item_B000ARLFYI']
# Item Sequence for idx 1564: ['item_B00Y3QMDC0', 'item_B076ZKGZ5X']
# Item Sequence for idx 1565: ['item_B001JSP7D2', 'item_B001IUT08E', 'item_B075M9LF3X', 'item_B005GWKPWU']
# Item Sequence for idx 1566: ['item_B00IU04BCU', 'item_B000P5ZQ54']
# Item Sequence for idx 1567: ['item_B0002F59UO', 'item_B001DCBRRE']
# Item Sequence for idx 1568: ['item_B078RDFDWS', 'item_B001NI4M1Q']
# Item Sequence for idx 1569: ['item_B00I14J76A', 'item_B01J2OSLQE']
# Item Sequence for idx 1570: ['item_B007R7ACUC', 'item_B0092V7WJ0', 'item_B00MIXDYT6']
# Item Sequence for idx 1571: ['item_B07YTXG5GJ', 'item_B08M3Z4WD6', 'item_B08L7TDG1L', 'item_B08QCHSQDF']
# Item Sequence for idx 1572: ['item_B00YXKCGXM', 'item_B015YCY6IK', 'item_B0773JJCFD', 'item_B08V25SD7X']
# Item Sequence for idx 1573: ['item_B0002F77L8', 'item_B007F43362', 'item_B0002DV7ZM', 'item_B0002KZHRO']
# Item Sequence for idx 1574: ['item_B01E5C4ZUE', 'item_B000SSMJG2', 'item_B001E6YEZG', 'item_B000BVS7WQ']
# Item Sequence for idx 1575: ['item_B0002M6CW6', 'item_B004OR9Q32', 'item_B00191WVF6', 'item_B001CKXT1Y']
# Item Sequence for idx 1576: ['item_B00191WVF6', 'item_B001CKXT1Y', 'item_B076WLYMXR']
# Item Sequence for idx 1577: ['item_B000B1FEPO', 'item_B01N94UUD0', 'item_B071937TYK', 'item_B005DGDOI6']
# Item Sequence for idx 1578: ['item_B07MTMY3LD', 'item_B0793ZCQ3G', 'item_B01DYPZ598', 'item_B078PM21S1']
# Item Sequence for idx 1579: ['item_B000KUA8EI', 'item_B000K6B59Y', 'item_B01AKRA7DC', 'item_B008O516JM']
# Item Sequence for idx 1580: ['item_B0002D0CO4', 'item_B0002E1O6I', 'item_B0BNB7GNG6']
# Item Sequence for idx 1581: ['item_B000PR3JEM', 'item_B003AYM3WQ', 'item_B00J2EKI20', 'item_B00B5LDWL2']
# Item Sequence for idx 1582: ['item_B0006NDF8A', 'item_B018B0MMTW', 'item_B06X9Q3L8Q', 'item_B06ZYCC7YG']
# Item Sequence for idx 1583: ['item_B00WA7VKEG', 'item_B01DWQMLAK', 'item_B084HPVQBK', 'item_B08GH4N1MK']
# Item Sequence for idx 1584: ['item_B00JQYUR0E', 'item_B0057R844A', 'item_B009C42TK4', 'item_B0002D04EM']
# Item Sequence for idx 1585: ['item_B00G2E3J4M', 'item_B0002D06CM', 'item_B00KBMLAV0']
# Item Sequence for idx 1586: ['item_B0006H92QK', 'item_B00CSKL36U', 'item_B076HSVZ5G', 'item_B00KWINICM']
# Item Sequence for idx 1587: ['item_B0052M1C1C', 'item_B0002E2YMG', 'item_B00I362NXU', 'item_B0002D0CYE']
# Item Sequence for idx 1588: ['item_B00I362NXU', 'item_B0002D0CYE', 'item_B003B15AWS', 'item_B000NJXSDO']
# Item Sequence for idx 1589: ['item_B000CZ0RK6', 'item_B0047AZG5S', 'item_B002M8EEW8', 'item_B000068O3C']
# Item Sequence for idx 1590: ['item_B00BWUHHYE', 'item_B0007L8BQW', 'item_B00EACWS4U', 'item_B0116X17JW']
# Item Sequence for idx 1591: ['item_B00EACWS4U', 'item_B0116X17JW', 'item_B00BK6TUAE']
# Item Sequence for idx 1592: ['item_B00T275IR2', 'item_B01CQ01YSS']
# Item Sequence for idx 1593: ['item_B00QHO7T7K', 'item_B008CVDJR0', 'item_B003CLIPHO', 'item_B00MO6KKSK']
# Item Sequence for idx 1594: ['item_B00I362NXU', 'item_B0872VDWW1']
# Item Sequence for idx 1595: ['item_B00GYGRTT4', 'item_B000J5UEGQ']
# Item Sequence for idx 1596: ['item_B0002D0E92', 'item_B00BL6JDUA']
# Item Sequence for idx 1597: ['item_B07SDGGTQ7', 'item_B08L91GWZ9', 'item_B09BMV35ST', 'item_B074QW5MJZ']
# Item Sequence for idx 1598: ['item_B000EMJG0Y', 'item_B00FQRW550']
# Item Sequence for idx 1599: ['item_B01N4MVEZD', 'item_B09ZTWRRPR']
# Item Sequence for idx 1600: ['item_B000LIGMOE', 'item_B010SCOIUW', 'item_B00PDJXGIG', 'item_B00IOSJ68C']
# Item Sequence for idx 1601: ['item_B08945DYB9', 'item_B01G85XUA2']
# Item Sequence for idx 1602: ['item_B0002KZIV4', 'item_B00QHURLCW', 'item_B00Y9AD4HS']
# Item Sequence for idx 1603: ['item_B003VWJ2K8', 'item_B0002OOMU8', 'item_B00F20MIC6', 'item_B0002CZVX2']
# Item Sequence for idx 1604: ['item_B00LMFFGOW', 'item_B08DRR6SJS', 'item_B0798NJ861', 'item_B000ATOFS4']
# Item Sequence for idx 1605: ['item_B00CTKI10A', 'item_B004Z2NW5E', 'item_B07NZ62WP4']
# Item Sequence for idx 1606: ['item_B002HJ9PTO', 'item_B0002D0I34', 'item_B017DBD44C', 'item_B01GSVQIJQ']
# Item Sequence for idx 1607: ['item_B017DBD44C', 'item_B01GSVQIJQ', 'item_B09MRVFM8N']
# Item Sequence for idx 1608: ['item_B00W5T1KTE', 'item_B0124Y99PQ', 'item_B017VXNO8S', 'item_B01KYHW22M']
# Item Sequence for idx 1609: ['item_B0002ZGE44', 'item_B014F1UKI6']
# Item Sequence for idx 1610: ['item_B00BFN58WQ', 'item_B005JTV358', 'item_B07G38453V', 'item_B09B6T7ZNN']
# Item Sequence for idx 1611: ['item_B017NGQWA0', 'item_B08HVKYSN5', 'item_B0014C97KW', 'item_B09MQNCTG3']
# Item Sequence for idx 1612: ['item_B000165DSM', 'item_B00387G1QO', 'item_B00DYD77WY', 'item_B00SFMMQQ6']
# Item Sequence for idx 1613: ['item_B002G1UT5C', 'item_B00AXTA94U', 'item_B00G69FBQM']
# Item Sequence for idx 1614: ['item_B0002F5B9I', 'item_B075K95CBW', 'item_B000A6EUSC', 'item_B0002I8Y6W']
# Item Sequence for idx 1615: ['item_B077L8D87M', 'item_B00KZHMZ1K', 'item_B0002E56H6', 'item_B07TV41HK9']
# Item Sequence for idx 1616: ['item_B0002E56H6', 'item_B07TV41HK9', 'item_B06XRPVYNS', 'item_B01H74YV56']
# Item Sequence for idx 1617: ['item_B002HJ9PTO', 'item_B00JOP0QI8', 'item_B00NAUKJTY', 'item_B0006Z4B6I']
# Item Sequence for idx 1618: ['item_B009F9V28Q', 'item_B00LTDON0K', 'item_B013NDP2TY', 'item_B01DYKV87G']
# Item Sequence for idx 1619: ['item_B013NDP2TY', 'item_B01DYKV87G', 'item_B004IYSRB8', 'item_B0002FO3LU']
# Item Sequence for idx 1620: ['item_B00MIXF1JW', 'item_B00VVK2A3I', 'item_B01MYRFJD1', 'item_B07NTYW6CK']
# Item Sequence for idx 1621: ['item_B07PQ7LLT5', 'item_B0029RVWUO', 'item_B00QXRHET4', 'item_B08FFLPWS9']
# Item Sequence for idx 1622: ['item_B002RZCZ90', 'item_B000A6CXUO', 'item_B00646MZHK', 'item_B00TY9KZOY']
# Item Sequence for idx 1623: ['item_B00JA4T6ES', 'item_B00HST61AY', 'item_B07P7HDRQN', 'item_B07QDRS4NB']
# Item Sequence for idx 1624: ['item_B00441GRXK', 'item_B083ZVXNS1', 'item_B08R3GZ6Z4', 'item_B073WNCLLF']
# Item Sequence for idx 1625: ['item_B009F8UAWQ', 'item_B00DY1F2CS']
# Item Sequence for idx 1626: ['item_B00W5Y8LI2', 'item_B011KJG300', 'item_B0023BYDHK']
# Item Sequence for idx 1627: ['item_B004WMGY3Y', 'item_B000T0A7EA', 'item_B001NEBLLY']
# Item Sequence for idx 1628: ['item_B00CPVRBOK', 'item_B078MPY48Y', 'item_B009Z2QVPW', 'item_B01I0BGYM8']
# Item Sequence for idx 1629: ['item_B00L5QFZH6', 'item_B01HRJ9NAY', 'item_B000LCM9O2', 'item_B00BP3MGN0']
# Item Sequence for idx 1630: ['item_B000LCM9O2', 'item_B00BP3MGN0', 'item_B071DFM3PS', 'item_B084KV63RF']
# Item Sequence for idx 1631: ['item_B071DFM3PS', 'item_B084KV63RF', 'item_B00SBSOYFU']
# Item Sequence for idx 1632: ['item_B0B2RN2F67', 'item_B09YYMNMX2', 'item_B0B5DTGF7V', 'item_B0B1ZYWNH6']
# Item Sequence for idx 1633: ['item_B0030DOALE', 'item_B06XDMJWCP', 'item_B018FCZKR2', 'item_B08FDQ2VHW']
# Item Sequence for idx 1634: ['item_B00BARTW42', 'item_B012B98TQO']
# Item Sequence for idx 1635: ['item_B06XTQSQKX', 'item_B003CLIPHO', 'item_B01KHMUQ2M', 'item_B07WLWN2ZT']
# Item Sequence for idx 1636: ['item_B01KHMUQ2M', 'item_B07WLWN2ZT', 'item_B07ZVHBFNJ']
# Item Sequence for idx 1637: ['item_B003VWJ2K8', 'item_B00FF90A2E']
# Item Sequence for idx 1638: ['item_B0002E2AB6', 'item_B0002E2ACK']
# Item Sequence for idx 1639: ['item_B07TT5Q25Y', 'item_B07YL5QC6P']
# Item Sequence for idx 1640: ['item_B07BVMPF5F', 'item_B0000WS6QI']
# Item Sequence for idx 1641: ['item_B000EEJ8VE', 'item_B01IP8C04M']
# Item Sequence for idx 1642: ['item_B078NTM11S', 'item_B06XDZTH2X']
# Item Sequence for idx 1643: ['item_B018E559NK', 'item_B00H44R9GS', 'item_B000H29I72', 'item_B07KRX6MNT']
# Item Sequence for idx 1644: ['item_B000H29I72', 'item_B07KRX6MNT']
# Item Sequence for idx 1645: ['item_B004P7RDZY', 'item_B0049J4O0K', 'item_B06XGC1CVY']
# Item Sequence for idx 1646: ['item_B003JJDKP6', 'item_B004J9T1IU', 'item_B003YNAQG8', 'item_B004D1RA00']
# Item Sequence for idx 1647: ['item_B0002ZO3LK', 'item_B0002E5518', 'item_B0002CZZW4', 'item_B0002F52EW']
# Item Sequence for idx 1648: ['item_B0050J3O04', 'item_B0002E1P2Q', 'item_B0013Y033Q', 'item_B001LXMXU0']
# Item Sequence for idx 1649: ['item_B0002CZV6E', 'item_B096W9F4VV']
# Item Sequence for idx 1650: ['item_B009GS6Z3S', 'item_B00CGFRJ2Y', 'item_B000A2HOB6', 'item_B005HMNT0Y']
# Item Sequence for idx 1651: ['item_B08HQCG79H', 'item_B07CXK6MDQ']
# Item Sequence for idx 1652: ['item_B01J5HGWJG', 'item_B09TGSQRBT', 'item_B09YRD68RK', 'item_B0009FC928']
# Item Sequence for idx 1653: ['item_B09YRD68RK', 'item_B0009FC928', 'item_B08SJ98DX6', 'item_B09R1SVXMG']
# Item Sequence for idx 1654: ['item_B00HZQ7RVM', 'item_B09G9WGNKT', 'item_B0B61QQFYN', 'item_B0032D0P84']
# Item Sequence for idx 1655: ['item_B005EHIN3A', 'item_B01AILRKS0', 'item_B01H22KHRY']
# Item Sequence for idx 1656: ['item_B06ZZ9347X', 'item_B0040YWRTE', 'item_B013NPCBLY']
# Item Sequence for idx 1657: ['item_B003EV6EIO', 'item_B00JA4T7HE', 'item_B089FLQ7M3']
# Item Sequence for idx 1658: ['item_B000CZ0RKG', 'item_B07LFL6YSH', 'item_B0002D0I02', 'item_B07GZLKCB5']
# Item Sequence for idx 1659: ['item_B06XJ19VWG', 'item_B01H62TQ68', 'item_B012V1TG9G', 'item_B0002KZELI']
# Item Sequence for idx 1660: ['item_B07RT9WPYY', 'item_B00XQD34PQ', 'item_B003VWKPHC', 'item_B00CAKJSOM']
# Item Sequence for idx 1661: ['item_B001PGXHXA', 'item_B0012Q7B5S']
# Item Sequence for idx 1662: ['item_B00ISQCJKM', 'item_B00B5LCADS', 'item_B0009RLE5Y', 'item_B003BHP67G']
# Item Sequence for idx 1663: ['item_B00ZYAT0U2', 'item_B07JNLPRJP', 'item_B07L8B9H8P', 'item_B00PCOIA0Q']
# Item Sequence for idx 1664: ['item_B07L8B9H8P', 'item_B00PCOIA0Q', 'item_B076PBDQSB', 'item_B08B8YYBB1']
# Item Sequence for idx 1665: ['item_B019OO4IY6', 'item_B01H62TQ68', 'item_B09WVHHCRC', 'item_B003QF8DFK']
# Item Sequence for idx 1666: ['item_B00A7Q8TXM', 'item_B01L3TZ420']
# Item Sequence for idx 1667: ['item_B00MX3OO1S', 'item_B0002KZAKS', 'item_B000VJJQUU']
# Item Sequence for idx 1668: ['item_B07FYPDMGL', 'item_B06WWP47BL']
# Item Sequence for idx 1669: ['item_B00HF07D6M', 'item_B0792G1HHL']
# Item Sequence for idx 1670: ['item_B09WYKLNPZ', 'item_B01N0LZSGN', 'item_B0BM96ZYX3']
# Item Sequence for idx 1671: ['item_B000VTH0QW', 'item_B07ZGH3GDD', 'item_B07GTGW6SX', 'item_B07NDVYB3Q']
# Item Sequence for idx 1672: ['item_B0002D01UO', 'item_B0002D0CKS', 'item_B088CWFVT8']
# Item Sequence for idx 1673: ['item_B01ATAJWWW', 'item_B000A0BSCY', 'item_B095XBRRDM', 'item_B07X6KWRQB']
# Item Sequence for idx 1674: ['item_B095XBRRDM', 'item_B07X6KWRQB']
# Item Sequence for idx 1675: ['item_B002C4SM5W', 'item_B0002F741Q']
# Item Sequence for idx 1676: ['item_B0013O4OZ4', 'item_B008OZ4WNE', 'item_B01HRJ9NAY']
# Item Sequence for idx 1677: ['item_B0057HFSBM', 'item_B0002D0JX8']
# Item Sequence for idx 1678: ['item_B071SGMQ7V', 'item_B07RQ8KDR6', 'item_B09S7RBKSV']
# Item Sequence for idx 1679: ['item_B007WWX9WK', 'item_B00B8HY7J4', 'item_B003YD8G7Y', 'item_B0050JK8S0']
# Item Sequence for idx 1680: ['item_B0002F4YQY', 'item_B003OMBDT8', 'item_B0087UPT1U', 'item_B0002F4YFA']
# Item Sequence for idx 1681: ['item_B0040FJ27S', 'item_B00DN8NKWQ', 'item_B0763LX5NQ']
# Item Sequence for idx 1682: ['item_B07CZ661DX', 'item_B07HHZ3X4M', 'item_B07DZRSV54', 'item_B06XY2YVB5']
# Item Sequence for idx 1683: ['item_B0002E2XOA', 'item_B003VWJ2K8', 'item_B000RW270M', 'item_B01IBI852M']
# Item Sequence for idx 1684: ['item_B000RW270M', 'item_B01IBI852M']
# Item Sequence for idx 1685: ['item_B000978D58', 'item_B0002CZW0Y']
# Item Sequence for idx 1686: ['item_B083LDV81C', 'item_B076BMTW9P']
# Item Sequence for idx 1687: ['item_B00F5VKFFE', 'item_B06ZZX99G8', 'item_B002L2E1TQ', 'item_B07F82BPLV']
# Item Sequence for idx 1688: ['item_B00191WVF6', 'item_B001L8PIFW']
# Item Sequence for idx 1689: ['item_B0002BACBO', 'item_B000VY8GDI', 'item_B00KGI7BY4', 'item_B0051TZBTU']
# Item Sequence for idx 1690: ['item_B001CR8372', 'item_B07PPDY2NS', 'item_B095Z2XN8L']
# Item Sequence for idx 1691: ['item_B088H4LPM3', 'item_B08PZCVC4X', 'item_B078WLKYZZ', 'item_B00BARTW3I']
# Item Sequence for idx 1692: ['item_B00F4PD2EM', 'item_B000T08JW2', 'item_B00C2DC8N0', 'item_B004XNK7AI']
# Item Sequence for idx 1693: ['item_B00GA2QPX8', 'item_B00UHBGE7A', 'item_B00PNG4BV0', 'item_B00EY6K4LQ']
# Item Sequence for idx 1694: ['item_B01M66OZ0V', 'item_B09LM927CD']
# Item Sequence for idx 1695: ['item_B00W8NNG80', 'item_B001MQ9Y5I']
# Item Sequence for idx 1696: ['item_B0002GYYD6', 'item_B0002GYYCW']
# Item Sequence for idx 1697: ['item_B07F1C2DD1', 'item_B081S9JZ4J', 'item_B004TKU4EO']
# Item Sequence for idx 1698: ['item_B0002E3CJ0', 'item_B004N0MKN8']
# Item Sequence for idx 1699: ['item_B00FSIN0U6', 'item_B001D0LMG2']
# Item Sequence for idx 1700: ['item_B00DBC0ZA4', 'item_B0002M6TX8']
# Item Sequence for idx 1701: ['item_B00NP8M098', 'item_B08PTMYWJ3']
# Item Sequence for idx 1702: ['item_B0017H4EBG', 'item_B00063678K']
# Item Sequence for idx 1703: ['item_B0002D02RQ', 'item_B0002E520C', 'item_B014BT5QX6', 'item_B07WHPTSSS']
# Item Sequence for idx 1704: ['item_B00QY4RLRQ', 'item_B003HGQTIG', 'item_B001KXKGBY']
# Item Sequence for idx 1705: ['item_B001VMG5K0', 'item_B01KNFAL46', 'item_B071LTTB2M', 'item_B008H46RD0']
# Item Sequence for idx 1706: ['item_B079GFJY8T', 'item_B00D35CNL8', 'item_B0BNNYPVYR']
# Item Sequence for idx 1707: ['item_B000B2Q2MC', 'item_B000RJ3YWK', 'item_B079X38XF1', 'item_B00724ZD40']
# Item Sequence for idx 1708: ['item_B000KIRT9C', 'item_B00CTLDI8E']
# Item Sequence for idx 1709: ['item_B016PHML0S', 'item_B01I0BGYM8', 'item_B019WTLVKW', 'item_B0018SJLFS']
# Item Sequence for idx 1710: ['item_B01ELA025W', 'item_B0002GLMPE', 'item_B009E087UM', 'item_B005ETZJEY']
# Item Sequence for idx 1711: ['item_B003AYM5JM', 'item_B00JYJFE72', 'item_B001L8PIEI', 'item_B00LJY360C']
# Item Sequence for idx 1712: ['item_B011MXD7YE', 'item_B00C29W7DU', 'item_B0188WO6OC', 'item_B00KN0EK9E']
# Item Sequence for idx 1713: ['item_B01FPRF5ZC', 'item_B08MZLD15J', 'item_B00EB123WM', 'item_B07TTQRZGD']
# Item Sequence for idx 1714: ['item_B00MRNXJ06', 'item_B01MY0S88D', 'item_B06XF6NF5Y', 'item_B08J88T8YL']
# Item Sequence for idx 1715: ['item_B06XF6NF5Y', 'item_B08J88T8YL']
# Item Sequence for idx 1716: ['item_B07DR3XTPP', 'item_B07H2G4PYG']
# Item Sequence for idx 1717: ['item_B019OO4IY6', 'item_B0BCM4GC6Q']
# Item Sequence for idx 1718: ['item_B017GSAT0E', 'item_B0035FZMXC', 'item_B0017T7XCG', 'item_B085B319L2']
# Item Sequence for idx 1719: ['item_B0002D0CQC', 'item_B00JFGPXO8', 'item_B00IOSJ68C', 'item_B00191WVF6']
# Item Sequence for idx 1720: ['item_B07HMNYPNL', 'item_B00EK1OTZC', 'item_B00TY9KZOY', 'item_B07RMV1J53']
# Item Sequence for idx 1721: ['item_B00TY9KZOY', 'item_B07RMV1J53', 'item_B019NY2PKG', 'item_B0843QS92T']
# Item Sequence for idx 1722: ['item_B003BG6KXQ', 'item_B00DWVB9K4', 'item_B013FOD978', 'item_B00AW7J4RQ']
# Item Sequence for idx 1723: ['item_B00L5QAPYO', 'item_B003WY4APM', 'item_B00P3E5VO8', 'item_B00NF9KZCQ']
# Item Sequence for idx 1724: ['item_B0002GJ3G4', 'item_B00A270MZO', 'item_B07MKBHF99']
# Item Sequence for idx 1725: ['item_B00E9EC2K4', 'item_B073TY6KHF']
# Item Sequence for idx 1726: ['item_B01A9GQZZ8', 'item_B00HJA8I8U']
# Item Sequence for idx 1727: ['item_B085GCG3LN', 'item_B08635NPWR', 'item_B07FVY8H89']
# Item Sequence for idx 1728: ['item_B00HB2ZVWM', 'item_B00GRRN2RI', 'item_B06XRDHT3J', 'item_B07RV9857K']
# Item Sequence for idx 1729: ['item_B000EEJGRK', 'item_B005XOE9BO', 'item_B00VOQQEFO']
# Item Sequence for idx 1730: ['item_B0BN6P17NQ', 'item_B0BQ7JZMF9', 'item_B0BQM9WD8J']
# Item Sequence for idx 1731: ['item_B00CBPJLFW', 'item_B0087UPXH0', 'item_B0087UPRMQ', 'item_B008AOH1O6']
# Item Sequence for idx 1732: ['item_B0163GXHK4', 'item_B0759JQ57Q']
# Item Sequence for idx 1733: ['item_B000CZ0R3S', 'item_B0002NIP98', 'item_B000AKSUP2', 'item_B01E38OLMC']
# Item Sequence for idx 1734: ['item_B000AKSUP2', 'item_B01E38OLMC', 'item_B00N8682QC']
# Item Sequence for idx 1735: ['item_B009MBT6SA', 'item_B0002F6ZJS']
# Item Sequence for idx 1736: ['item_B01EUTER1E', 'item_B0084QS4NW', 'item_B0091Q1DDC', 'item_B0002GZSWW']
# Item Sequence for idx 1737: ['item_B0091Q1DDC', 'item_B0002GZSWW', 'item_B005N2RGJ8', 'item_B01N4L8VBA']
# Item Sequence for idx 1738: ['item_B0002CZW3G', 'item_B004Z2G2T2', 'item_B07K9VWTBF', 'item_B00E8TQ3ZA']
# Item Sequence for idx 1739: ['item_B006HR16VC', 'item_B00ZV7T95E', 'item_B0183ITSB2']
# Item Sequence for idx 1740: ['item_B07H1618KF', 'item_B08N9XSBNJ', 'item_B087338JM6']
# Item Sequence for idx 1741: ['item_B000P5YJ6G', 'item_B07K8FQFN8']
# Item Sequence for idx 1742: ['item_B0002D0L4K', 'item_B0002D0L5E']
# Item Sequence for idx 1743: ['item_B01B7N8P5A', 'item_B000NTEVKS', 'item_B00FB467IO', 'item_B0002D09Y2']
# Item Sequence for idx 1744: ['item_B0827JVXGW', 'item_B001LG4VXE', 'item_B0755G9TK4']
# Item Sequence for idx 1745: ['item_B002ZQX5SQ', 'item_B078S2GVQT', 'item_B074JFNHBB', 'item_B072JVYTHS']
# Item Sequence for idx 1746: ['item_B07YZHPHF2', 'item_B004PADTX6', 'item_B06XZBYC14', 'item_B0002E2XHC']
# Item Sequence for idx 1747: ['item_B075CSHLYH', 'item_B01MZCS8MY']
# Item Sequence for idx 1748: ['item_B07ZF78HBQ', 'item_B07YDPKKWH', 'item_B003B0BLUO']
# Item Sequence for idx 1749: ['item_B01C05AL4C', 'item_B08CCTF9N6']
# Item Sequence for idx 1750: ['item_B0002CZUDS', 'item_B00CE20HKU', 'item_B01MYHBPLX', 'item_B01MU0XOFW']
# Item Sequence for idx 1751: ['item_B01MYHBPLX', 'item_B01MU0XOFW', 'item_B0002OOMW6', 'item_B003E0Y08Q']
# Item Sequence for idx 1752: ['item_B001ECQQ56', 'item_B001ECQQ5G', 'item_B001ECQQ6K']
# Item Sequence for idx 1753: ['item_B07663MBYY', 'item_B00S2VVTDG', 'item_B0009FC928']
# Item Sequence for idx 1754: ['item_B001V7M7RK', 'item_B00FSDBTHW', 'item_B07NXWBSFV', 'item_B0019H6750']
# Item Sequence for idx 1755: ['item_B00TP7C9YY', 'item_B01G647CWC']
# Item Sequence for idx 1756: ['item_B007DHN3MU', 'item_B0006NDF8A', 'item_B003CLIPHO', 'item_B00JB4WAU4']
# Item Sequence for idx 1757: ['item_B0002D0KOG', 'item_B07QNT5ZHZ', 'item_B084VFYC6Z']
# Item Sequence for idx 1758: ['item_B07GTDFY4H', 'item_B01H62FQ3U', 'item_B004ETZMD8', 'item_B01NC33N4T']
# Item Sequence for idx 1759: ['item_B004ETZMD8', 'item_B01NC33N4T']
# Item Sequence for idx 1760: ['item_B000XI6O2W', 'item_B004Z17008', 'item_B012TIJ4TI']
# Item Sequence for idx 1761: ['item_B000EEJCDS', 'item_B000PTRJUK', 'item_B00BHK2UHI']
# Item Sequence for idx 1762: ['item_B001WLSYW2', 'item_B077C4WXB8', 'item_B07Z5QL7DZ']
# Item Sequence for idx 1763: ['item_B009MBT68U', 'item_B0002H0JZC', 'item_B01M1GG05L', 'item_B0002GW3Y8']
# Item Sequence for idx 1764: ['item_B01M1GG05L', 'item_B0002GW3Y8', 'item_B07Q38FWFJ', 'item_B0821Z3QCN']
# Item Sequence for idx 1765: ['item_B001AIPXLC', 'item_B07S8YHDZY']
# Item Sequence for idx 1766: ['item_B000Y021NA', 'item_B075XQ965V']
# Item Sequence for idx 1767: ['item_B008BOXZCC', 'item_B00HV7U4CY', 'item_B00B2N3XU8']
# Item Sequence for idx 1768: ['item_B0006OK30W', 'item_B015QZPS9Q', 'item_B071YGT9H1', 'item_B0038XUDW6']
# Item Sequence for idx 1769: ['item_B0002E4Z8M', 'item_B01NCUZ32O']
# Item Sequence for idx 1770: ['item_B005EHINIK', 'item_B07K58L9MW']
# Item Sequence for idx 1771: ['item_B082ZLY1RL', 'item_B07L3CQ7G7', 'item_B00QY6SQF0']
# Item Sequence for idx 1772: ['item_B01CZPJ5SA', 'item_B0002D0L4A']
# Item Sequence for idx 1773: ['item_B005SUUIFE', 'item_B09L19G9RS', 'item_B081PSNDCV', 'item_B07Z6GWZPV']
# Item Sequence for idx 1774: ['item_B081PSNDCV', 'item_B07Z6GWZPV']
# Item Sequence for idx 1775: ['item_B0027M30Z6', 'item_B0013V1BYY', 'item_B000W02786']
# Item Sequence for idx 1776: ['item_B00CV1U4U2', 'item_B0045F6AU0', 'item_B01DBVD0G0']
# Item Sequence for idx 1777: ['item_B076F3YQJP', 'item_B000EEHOHE', 'item_B01N4OMRVG', 'item_B000EEJBDE']
# Item Sequence for idx 1778: ['item_B000EEJIFA', 'item_B009LL2ZAM', 'item_B07L5B64RG']
# Item Sequence for idx 1779: ['item_B002SDXKOK', 'item_B00DSSOVJW', 'item_B005SUS6RG', 'item_B06X9QPNXF']
# Item Sequence for idx 1780: ['item_B005SUS6RG', 'item_B06X9QPNXF', 'item_B01M1OPRJZ', 'item_B002PCHLAI']
# Item Sequence for idx 1781: ['item_B002HQRS32', 'item_B071XHM99Y']
# Item Sequence for idx 1782: ['item_B016UHP7HM', 'item_B003OUX910']
# Item Sequence for idx 1783: ['item_B00GP46ITM', 'item_B008874MWO', 'item_B01F543PAW', 'item_B001LU1SFO']
# Item Sequence for idx 1784: ['item_B01F543PAW', 'item_B001LU1SFO']
# Item Sequence for idx 1785: ['item_B07D11J72W', 'item_B00OJHISTK']
# Item Sequence for idx 1786: ['item_B00W3K8OC6', 'item_B00IOSJ72M', 'item_B0009FUTHU', 'item_B07N1JKP6N']
# Item Sequence for idx 1787: ['item_B0879HWHBN', 'item_B003WE98HM', 'item_B0018TFC1Y']
# Item Sequence for idx 1788: ['item_B07MR54J7V', 'item_B088TDS738', 'item_B077NHM2K6']
# Item Sequence for idx 1789: ['item_B0BL75QCWR', 'item_B0BLZ3BYL1']
# Item Sequence for idx 1790: ['item_B00BMFNFP4', 'item_B07DLFCP9N', 'item_B00KO8VY4O']
# Item Sequence for idx 1791: ['item_B0002E1NQE', 'item_B007KFO9DC', 'item_B016D7KIWS', 'item_B01IBI8HMA']
# Item Sequence for idx 1792: ['item_B016D7KIWS', 'item_B01IBI8HMA', 'item_B0002E1G5C', 'item_B003AYNHGW']
# Item Sequence for idx 1793: ['item_B0002E1O3G', 'item_B0002D0P9Q', 'item_B005XOE9BO', 'item_B00N1YPXW2']
# Item Sequence for idx 1794: ['item_B0779LSJCX', 'item_B0002KZEB8', 'item_B0002E2G2E', 'item_B087X1N74C']
# Item Sequence for idx 1795: ['item_B0023C5QRU', 'item_B00LNV2SAK', 'item_B0002CZVXM', 'item_B00HLW1A5O']
# Item Sequence for idx 1796: ['item_B072BX2GKD', 'item_B000L6GD04', 'item_B071DDCRDW', 'item_B00ABLA3LO']
# Item Sequence for idx 1797: ['item_B07MCZ9S8X', 'item_B01JNLUA5G', 'item_B0002KZFYE', 'item_B0002KZJIQ']
# Item Sequence for idx 1798: ['item_B0002KZFYE', 'item_B0002KZJIQ', 'item_B01H3WSLEO', 'item_B00SMIQBR8']
# Item Sequence for idx 1799: ['item_B08B65T8TY', 'item_B0983C2YGK', 'item_B0B1MW52GQ']
# Item Sequence for idx 1800: ['item_B006WAB3MG', 'item_B078P59DXP', 'item_B07YZJGNH2']
# Item Sequence for idx 1801: ['item_B0002FP1F2', 'item_B004T67G94', 'item_B0007M6A5K']
# Item Sequence for idx 1802: ['item_B003BGXW50', 'item_B07N2VQ1NH']
# Item Sequence for idx 1803: ['item_B01AAX6NOS', 'item_B00XQCRR5U', 'item_B019IBQ6EU', 'item_B07QDRS4NB']
# Item Sequence for idx 1804: ['item_B0719V8MX1', 'item_B015OPQGBC', 'item_B08133QH9W', 'item_B08SBSN88X']
# Item Sequence for idx 1805: ['item_B00I9RK97K', 'item_B00HGDRSB8', 'item_B00006I51S', 'item_B008AOH1O6']
# Item Sequence for idx 1806: ['item_B002NG7DEK', 'item_B005AL3RG8', 'item_B0002KZDGY']
# Item Sequence for idx 1807: ['item_B079H4X98G', 'item_B0795DDF33']
# Item Sequence for idx 1808: ['item_B0002KZHP6', 'item_B01MRLZCIS', 'item_B00FW773LA', 'item_B07WK2HKDP']
# Item Sequence for idx 1809: ['item_B0002H0JZ2', 'item_B000OR31BO', 'item_B0002E3D6W', 'item_B07S8NZTZD']
# Item Sequence for idx 1810: ['item_B0002F7KG0', 'item_B00066U2S8']
# Item Sequence for idx 1811: ['item_B00EZ1VAMC', 'item_B00175RNQQ', 'item_B0030YD8MA', 'item_B01B9IDFSK']
# Item Sequence for idx 1812: ['item_B0030YD8MA', 'item_B01B9IDFSK', 'item_B0002FOWBG', 'item_B01IBI8CES']
# Item Sequence for idx 1813: ['item_B005OZE9SA', 'item_B0779PKLV9', 'item_B000N31M06']
# Item Sequence for idx 1814: ['item_B017XFQHBA', 'item_B07F7ZLNLP', 'item_B079MFQJZL']
# Item Sequence for idx 1815: ['item_B0BDZC813H', 'item_B0BMGRX7GC', 'item_B0BGN8NCDH', 'item_B0BF96MQ7Z']
# Item Sequence for idx 1816: ['item_B009VYM7ZM', 'item_B003VWKPHC', 'item_B00JB4WA54', 'item_B0002CZV8M']
# Item Sequence for idx 1817: ['item_B071ZF9YKW', 'item_B07TYRQ222', 'item_B01G5D5GBI', 'item_B084ZFLXWY']
# Item Sequence for idx 1818: ['item_B08FJ5DYR8', 'item_B01EB5SYDY']
# Item Sequence for idx 1819: ['item_B0094E5TU4', 'item_B005H2007E', 'item_B000OR6J40', 'item_B00UTUJL06']
# Item Sequence for idx 1820: ['item_B078MP5LL8', 'item_B003B01QR2', 'item_B07KWVWYVW', 'item_B000EEHFY6']
# Item Sequence for idx 1821: ['item_B0055V7UR0', 'item_B00HNVYUNW']
# Item Sequence for idx 1822: ['item_B0002F74CU', 'item_B000UJE6UG', 'item_B000EY765E', 'item_B008MI70QE']
# Item Sequence for idx 1823: ['item_B000068NZC', 'item_B00005ML71', 'item_B000VSKPZG', 'item_B003FVB7XA']
# Item Sequence for idx 1824: ['item_B00QV9XSH6', 'item_B000EEL6J6', 'item_B019MIPZ8M', 'item_B000CD1R7K']
# Item Sequence for idx 1825: ['item_B019MIPZ8M', 'item_B000CD1R7K']
# Item Sequence for idx 1826: ['item_B01DCO4DCG', 'item_B01JY29YZ6']
# Item Sequence for idx 1827: ['item_B009703MBI', 'item_B00191WVF6']
# Item Sequence for idx 1828: ['item_B00HHGUAVY', 'item_B00KDU6S7Q', 'item_B00CBPAPZW', 'item_B00P6UDWXG']
# Item Sequence for idx 1829: ['item_B00CBPAPZW', 'item_B00P6UDWXG', 'item_B07X223RNZ', 'item_B09GL9MBP7']
# Item Sequence for idx 1830: ['item_B07X223RNZ', 'item_B09GL9MBP7', 'item_B07YVP6K7N']
# Item Sequence for idx 1831: ['item_B002VR2L0C', 'item_B0002GX5NG', 'item_B000Y021NA', 'item_B08RX2GK88']
# Item Sequence for idx 1832: ['item_B000Y021NA', 'item_B08RX2GK88', 'item_B0757LTZJJ']
# Item Sequence for idx 1833: ['item_B0002FOLPI', 'item_B015GCBXF2', 'item_B07BRZNF9V', 'item_B000VFCB88']
# Item Sequence for idx 1834: ['item_B01N1JNUET', 'item_B0007NQH98', 'item_B01M13A6JT']
# Item Sequence for idx 1835: ['item_B004P4MLMW', 'item_B00LFLOTFK', 'item_B00B5LEWKM', 'item_B07MZ36H9T']
# Item Sequence for idx 1836: ['item_B00NAUHX1G', 'item_B07T9NM5QR', 'item_B07HM8Q5FR']
# Item Sequence for idx 1837: ['item_B0064RTUP4', 'item_B078JGMF6M']
# Item Sequence for idx 1838: ['item_B00OET2J7K', 'item_B08MSXVF1R', 'item_B003H8MXQQ', 'item_B000EEJH9C']
# Item Sequence for idx 1839: ['item_B00HQJZVW0', 'item_B00GROJWAW', 'item_B07GXHB3C7', 'item_B072JPPVGT']
# Item Sequence for idx 1840: ['item_B01JIQ36DE', 'item_B07KT11QGJ', 'item_B07NZZ6KN9', 'item_B07149XPJ2']
# Item Sequence for idx 1841: ['item_B008TNAHTY', 'item_B008TNAHX0', 'item_B07TQDZ7L7', 'item_B07RK6FQ9J']
# Item Sequence for idx 1842: ['item_B00FC4YPL4', 'item_B00BARTW3I', 'item_B0002KZAKS', 'item_B003CY6OHY']
# Item Sequence for idx 1843: ['item_B079KN32GG', 'item_B01C0EGBGU', 'item_B07FY3M2XL']
# Item Sequence for idx 1844: ['item_B007W3VUGG', 'item_B01667IQ10', 'item_B0073K9BHS', 'item_B00T0OJGIY']
# Item Sequence for idx 1845: ['item_B00BKNXBRK', 'item_B00O4L3F9E', 'item_B01FRVNSOQ', 'item_B00XQEH5P0']
# Item Sequence for idx 1846: ['item_B01N32CO1O', 'item_B004SX1BCG', 'item_B00C5B20QE', 'item_B0002D0COE']
# Item Sequence for idx 1847: ['item_B00C5B20QE', 'item_B0002D0COE', 'item_B00JA4T7Y2', 'item_B00FD215TA']
# Item Sequence for idx 1848: ['item_B014SCVT96', 'item_B000SKHSRU', 'item_B004XWDYO0']
# Item Sequence for idx 1849: ['item_B005FKF1PY', 'item_B000CC4JFS', 'item_B0002CZVK0', 'item_B0002E3FBA']
# Item Sequence for idx 1850: ['item_B0002FP1DY', 'item_B0007XY8TO', 'item_B000A82NK2', 'item_B000A85JWG']
# Item Sequence for idx 1851: ['item_B00DDXKDF8', 'item_B001M5CZO6', 'item_B000EEHBM2', 'item_B01IR2YDP0']
# Item Sequence for idx 1852: ['item_B08L4TZQ5X', 'item_B002VA464S']
# Item Sequence for idx 1853: ['item_B00O4L3F9E', 'item_B07N95RL8W', 'item_B017YVQDGW', 'item_B01IZXHIRG']
# Item Sequence for idx 1854: ['item_B07FT2QG9Q', 'item_B074WM5MBC', 'item_B002Q0WT6U']
# Item Sequence for idx 1855: ['item_B0002II7H8', 'item_B002Q0WT6U']
# Item Sequence for idx 1856: ['item_B00N4ZHPZ6', 'item_B00NG54D4U']
# Item Sequence for idx 1857: ['item_B003ZTTDLK', 'item_B000EEJ9AY', 'item_B0002E3GV4']
# Item Sequence for idx 1858: ['item_B0007Y60HG', 'item_B00BPELU68', 'item_B07QSC92NG']
# Item Sequence for idx 1859: ['item_B0028LHV74', 'item_B0035AQCT0']
# Item Sequence for idx 1860: ['item_B077JMMPS3', 'item_B007RA3GPM', 'item_B000XP0CMS', 'item_B0009A1XC0']
# Item Sequence for idx 1861: ['item_B000RKL8R2', 'item_B0848Y4CTM', 'item_B07WWW3KJ5', 'item_B07CMQHLKD']
# Item Sequence for idx 1862: ['item_B07L4MBCZG', 'item_B081GLKKN5']
# Item Sequence for idx 1863: ['item_B002AKKO3Q', 'item_B0017OS7JY', 'item_B01CGJRNF2', 'item_B01LYZIIFN']
# Item Sequence for idx 1864: ['item_B01CGJRNF2', 'item_B01LYZIIFN', 'item_B082SLQXY7', 'item_B01BPK7PGU']
# Item Sequence for idx 1865: ['item_B0002D0CEO', 'item_B0006NDF8A']
# Item Sequence for idx 1866: ['item_B004R6IKPK', 'item_B00266HBSU']
# Item Sequence for idx 1867: ['item_B002SW36PY', 'item_B0002OOMWQ', 'item_B003EUIOG0', 'item_B07L93L2X7']
# Item Sequence for idx 1868: ['item_B00LIR7QNS', 'item_B0134BIH1K']
# Item Sequence for idx 1869: ['item_B01N1H1ZX8', 'item_B01L3LL95O', 'item_B00N1YPXW2']
# Item Sequence for idx 1870: ['item_B08L1FB2KN', 'item_B07GTDFY8Z']
# Item Sequence for idx 1871: ['item_B00IT0IHOY', 'item_B09V6D6ZN6']
# Item Sequence for idx 1872: ['item_B008PEYY2S', 'item_B0057IVG30']
# Item Sequence for idx 1873: ['item_B002AKKO8Q', 'item_B001LTZZSG']
# Item Sequence for idx 1874: ['item_B01ITCNWC8', 'item_B00GSQFWOE', 'item_B00ECAOSNY']
# Item Sequence for idx 1875: ['item_B017MVUAHM', 'item_B001L8NGJ2', 'item_B003GEKXRM', 'item_B071XNPW6G']
# Item Sequence for idx 1876: ['item_B01H74YV56', 'item_B0795PNCBG']
# Item Sequence for idx 1877: ['item_B01H62FQ3U', 'item_B083JPPC7M', 'item_B0002KZDN2', 'item_B08SQ38P78']
# Item Sequence for idx 1878: ['item_B0087UPWA8', 'item_B000XI6O2W', 'item_B00CAV0TRQ', 'item_B014MQ22XU']
# Item Sequence for idx 1879: ['item_B0001ARCFA', 'item_B00CIIQFHE']
# Item Sequence for idx 1880: ['item_B000XI6O2W', 'item_B071F4D3CF', 'item_B0002D02RQ', 'item_B002VJOIII']
# Item Sequence for idx 1881: ['item_B0002D02RQ', 'item_B002VJOIII']
# Item Sequence for idx 1882: ['item_B000CD1R7K', 'item_1423414357', 'item_B001PGXHXA', 'item_B0002OOMU8']
# Item Sequence for idx 1883: ['item_B0002E3FCO', 'item_B0018TIADQ', 'item_B00B8WM1R4']
# Item Sequence for idx 1884: ['item_B00INCGKSI', 'item_B01M9FB6IJ']
# Item Sequence for idx 1885: ['item_B07Q1HMD6J', 'item_B0047N284W', 'item_B08PYQCKNT', 'item_B089FLQ7M3']
# Item Sequence for idx 1886: ['item_B007WQIFUW', 'item_B001SN7VGO', 'item_B00188VTFS', 'item_B005NACC6M']
# Item Sequence for idx 1887: ['item_B0002D0I34', 'item_B0002GZV5Q', 'item_B0002F786W', 'item_B0064RFEUY']
# Item Sequence for idx 1888: ['item_B01GWUITG8', 'item_B0041206UW', 'item_B07JLX1JZ7', 'item_B07NQCP3CP']
# Item Sequence for idx 1889: ['item_B07JLX1JZ7', 'item_B07NQCP3CP']
# Item Sequence for idx 1890: ['item_B000EEK4VM', 'item_B08K7NL5CS', 'item_B01MT9VBMT', 'item_B07DWZN4K5']
# Item Sequence for idx 1891: ['item_B001FWYAX0', 'item_B004XLFKIO', 'item_B0020YHXM2', 'item_B000AXSFOK']
# Item Sequence for idx 1892: ['item_B0020YHXM2', 'item_B000AXSFOK', 'item_B0076IMDQ8', 'item_B082F558K5']
# Item Sequence for idx 1893: ['item_B00C9JLFUE', 'item_B004W8ZN7Q']
# Item Sequence for idx 1894: ['item_B0002GWFEQ', 'item_B073Y87GNR']
# Item Sequence for idx 1895: ['item_B000CZ0RME', 'item_B002LASBRG', 'item_B008AOH1O6', 'item_B0002CZW0Y']
# Item Sequence for idx 1896: ['item_B002VAV5HO', 'item_B0002MSQVQ']
# Item Sequence for idx 1897: ['item_B003NWYRLU', 'item_B0002MJTZ8']
# Item Sequence for idx 1898: ['item_B008I5QSY6', 'item_B077C4S8WK', 'item_B000V1K7FG', 'item_B075BBNWBT']
# Item Sequence for idx 1899: ['item_B0002DUWBW', 'item_B009DT78Q8', 'item_B005MR6IHK', 'item_B00191WVF6']
# Item Sequence for idx 1900: ['item_B005MR6IHK', 'item_B00191WVF6', 'item_B000P1RB9C', 'item_B00GD1JBIM']
# Item Sequence for idx 1901: ['item_B0B3F4F9RT', 'item_B01N0A87V8']
# Item Sequence for idx 1902: ['item_B00EA1QRHK', 'item_B07RD6JFFD']
# Item Sequence for idx 1903: ['item_B004TEWEZW', 'item_B004TEWFM4', 'item_B075MDZDXM', 'item_B0002E1O2M']
# Item Sequence for idx 1904: ['item_B01C56XMB0', 'item_B00MLARE0Q']
# Item Sequence for idx 1905: ['item_B009VSCQK4', 'item_B002NGMBGU', 'item_B0002GIKF4', 'item_B01AKRA9AI']
# Item Sequence for idx 1906: ['item_B004N0MKN8', 'item_B004XNK7AI', 'item_B00E9SX32G', 'item_B01LQO3GGS']
# Item Sequence for idx 1907: ['item_B003YVLKF6', 'item_B01AUNB8R0', 'item_B00IJ6QAO2', 'item_B01GHKH2M0']
# Item Sequence for idx 1908: ['item_B00IJ6QAO2', 'item_B01GHKH2M0', 'item_B07N58BJV4']
# Item Sequence for idx 1909: ['item_B06XHN7VRG', 'item_B00F2CWFUE']
# Item Sequence for idx 1910: ['item_B0027M30Z6', 'item_B0002H0KG0']
# Item Sequence for idx 1911: ['item_B01LX9FAZQ', 'item_B00191WVF6']
# Item Sequence for idx 1912: ['item_B00BLJYWMQ', 'item_B000EELFTW', 'item_B0144UCRL6', 'item_B076WF7DSP']
# Item Sequence for idx 1913: ['item_B0002E1G98', 'item_B0002OP0WC']
# Item Sequence for idx 1914: ['item_B01BXAY8K8', 'item_B002VA464S']
# Item Sequence for idx 1915: ['item_B075HCLMYP', 'item_B08G4KCLRP']
# Item Sequence for idx 1916: ['item_B07GB3QZ43', 'item_B00BL6J6ZC']
# Item Sequence for idx 1917: ['item_B00551817I', 'item_B003ICIVOE', 'item_B002A66PVU', 'item_B0002F6WR8']
# Item Sequence for idx 1918: ['item_B007K7LYHY', 'item_B001PGXKI2']
# Item Sequence for idx 1919: ['item_B009MBT3KQ', 'item_1881322149', 'item_B00GOIC1S6', 'item_B002G1UT5C']
# Item Sequence for idx 1920: ['item_B00GOIC1S6', 'item_B002G1UT5C', 'item_B073PLKSLG', 'item_B00LD8KGGG']
# Item Sequence for idx 1921: ['item_B016LIWSLI', 'item_B0033P1O6S', 'item_B00WH2RX7W', 'item_B000LFCXL8']
# Item Sequence for idx 1922: ['item_B0002DV7U2', 'item_B08X2VZSZ5']
# Item Sequence for idx 1923: ['item_B000EENACC', 'item_B00MP8XHBO']
# Item Sequence for idx 1924: ['item_B08M3DF8TX', 'item_B083FPFZJG', 'item_B08883KM11']
# Item Sequence for idx 1925: ['item_B00724ZKUM', 'item_B0002CZW3G', 'item_B01NBHDU69', 'item_B00KJ6WGJS']
# Item Sequence for idx 1926: ['item_B00Q1VCJ3S', 'item_B01D53IYI8', 'item_B000B1F9TU']
# Item Sequence for idx 1927: ['item_B005M05MII', 'item_B002N4TFOS', 'item_B01IELK2GI', 'item_B01L8CDG6I']
# Item Sequence for idx 1928: ['item_B08HQGQFY3', 'item_B07SJ8RZL4']
# Item Sequence for idx 1929: ['item_B00MQ4NN2A', 'item_B0732M8CG1', 'item_B08GBZFRN3', 'item_B07HRG7PBJ']
# Item Sequence for idx 1930: ['item_B077SFZCQW', 'item_B018FCZKR2']
# Item Sequence for idx 1931: ['item_B00CIOGXI4', 'item_B07DHH3LQS']
# Item Sequence for idx 1932: ['item_B01FW4BV92', 'item_B0085M6SUQ', 'item_B01FW4BV1U']
# Item Sequence for idx 1933: ['item_B00F912X96', 'item_B002RGPQJ0', 'item_B002FDIIPY']
# Item Sequence for idx 1934: ['item_B07VMYX7LR', 'item_B00B20BN80', 'item_B0065KPSK6', 'item_B07J5GBPLQ']
# Item Sequence for idx 1935: ['item_B07TZSLJZX', 'item_B09KMM277V', 'item_B07MVSM53B']
# Item Sequence for idx 1936: ['item_B01H2UAAN2', 'item_B00C2DC8N0', 'item_B06Y24TFD4', 'item_B0002E2E94']
# Item Sequence for idx 1937: ['item_B010174W14', 'item_B01MYDRUYB']
# Item Sequence for idx 1938: ['item_B0002E56P8', 'item_B08CXWCDJC']
# Item Sequence for idx 1939: ['item_B01LEZLR9M', 'item_B0747636CF']
# Item Sequence for idx 1940: ['item_B0002E1OX6', 'item_B0002E1NSW']
# Item Sequence for idx 1941: ['item_B007VOGU8O', 'item_B0010CAEFS', 'item_B004FEGXDK']
# Item Sequence for idx 1942: ['item_B00164LP7G', 'item_B00AQBT4L4', 'item_B007U4XEWA', 'item_B01BRU1LHM']
# Item Sequence for idx 1943: ['item_B007U4XEWA', 'item_B01BRU1LHM']
# Item Sequence for idx 1944: ['item_B0002F7EVQ', 'item_B0002F73VC', 'item_B00O48Z5FE', 'item_B07T5C93RK']
# Item Sequence for idx 1945: ['item_B00AQBT4NM', 'item_B019WTLVKW', 'item_B009WS7TSW', 'item_B07B6GMV7X']
# Item Sequence for idx 1946: ['item_B00K0NZQHY', 'item_B015R0IQGW', 'item_B01MSKI46R', 'item_B00KO8W2UO']
# Item Sequence for idx 1947: ['item_B0011UB9CQ', 'item_B079ZBLJ4M']
# Item Sequence for idx 1948: ['item_B0018TAITA', 'item_B000RYE5Y6', 'item_B0002D0HY4', 'item_B0002GMH08']
# Item Sequence for idx 1949: ['item_B00BTJI4Z4', 'item_B06XPNCW38']
# Item Sequence for idx 1950: ['item_B0002E2NC2', 'item_B001A667X2', 'item_B005GZ86ZA', 'item_B00H0FIT9W']
# Item Sequence for idx 1951: ['item_B005GZ86ZA', 'item_B00H0FIT9W', 'item_B000AOECJG', 'item_B07RFVT9HD']
# Item Sequence for idx 1952: ['item_B000AOECJG', 'item_B07RFVT9HD']
# Item Sequence for idx 1953: ['item_B019JD0XZ0', 'item_B003B1RGQQ']
# Item Sequence for idx 1954: ['item_B07GZMB8X7', 'item_B07N26D2T8', 'item_B0723BQGZS']
# Item Sequence for idx 1955: ['item_B000SZVYLQ', 'item_B00DYIIQ0Q']
# Item Sequence for idx 1956: ['item_B0002E3FPQ', 'item_B00BZ9OSHG', 'item_B007YFWTXU']
# Item Sequence for idx 1957: ['item_B007GO29Z2', 'item_B00MWSOV4E']
# Item Sequence for idx 1958: ['item_B01EGV6UJ8', 'item_B002TZXPJM']
# Item Sequence for idx 1959: ['item_B0006NDF8A', 'item_B0002E2XGS', 'item_B07FQNBKDK']
# Item Sequence for idx 1960: ['item_B0002D0EA6', 'item_B01BGX82G8', 'item_B0002KZISM']
# Item Sequence for idx 1961: ['item_B01CQJNTAK', 'item_B07ZYYSK9V']
# Item Sequence for idx 1962: ['item_B0013O95W6', 'item_B00CFP5ESG']
# Item Sequence for idx 1963: ['item_B0071NO7I0', 'item_B08HQW28LZ']
# Item Sequence for idx 1964: ['item_B009MBNDUC', 'item_B00GTSM8CK']
# Item Sequence for idx 1965: ['item_B0041T4DKE', 'item_B081T3898G', 'item_B00L5QAPYO', 'item_B01AAX6NOS']
# Item Sequence for idx 1966: ['item_B008GS9UNQ', 'item_B004ZKY10Q']
# Item Sequence for idx 1967: ['item_B07D6ZVDT6', 'item_B08V8TBMRT']
# Item Sequence for idx 1968: ['item_B00T0OJGO8', 'item_B01KPZ6EG8', 'item_B01M06DZFP', 'item_B00191WVF6']
# Item Sequence for idx 1969: ['item_B005SUT4VS', 'item_B00NJVS32Y']
# Item Sequence for idx 1970: ['item_B08TWNQZJX', 'item_B086MP6ZYC', 'item_B003B01QR2']
# Item Sequence for idx 1971: ['item_B018K4U0Z2', 'item_B06XSNKQZY']
# Item Sequence for idx 1972: ['item_B00M35YHFO', 'item_B0055V7UR0']
# Item Sequence for idx 1973: ['item_B0000775G0', 'item_B0060ZB43G']
# Item Sequence for idx 1974: ['item_B00G9B0C52', 'item_B007DV6K62', 'item_B00N4QF1F6', 'item_B000BBF1VG']
# Item Sequence for idx 1975: ['item_B07L92XV3G', 'item_B07RHMSV55', 'item_B01LZHUJ0W', 'item_B0732QNHQ8']
# Item Sequence for idx 1976: ['item_B001MX39RU', 'item_B01J24V1G6', 'item_B07KPBVCKJ']
# Item Sequence for idx 1977: ['item_B006SVZSY8', 'item_B0078LAUGS', 'item_B01MEI1H8G', 'item_B06XP27LCR']
# Item Sequence for idx 1978: ['item_B074VT3CTV', 'item_B00KMDS32W', 'item_B0BNT37K5N']
# Item Sequence for idx 1979: ['item_B01H74YXNQ', 'item_B00AT9IXIS']
# Item Sequence for idx 1980: ['item_B00LGWVNQG', 'item_B09F5T2FGT']
# ...
# Item Sequence for idx 6270: ['item_B003HGFSWO', 'item_B000H7GSMU', 'item_B00LTDON0K', 'item_B01D53KTEA']
# Item Sequence for idx 6271: ['item_B001G7H8YW', 'item_B00D63RU7E', 'item_B000A6ASSS', 'item_B00HWO6BWI']
# Item Sequence for idx 6272: ['item_B00EW5I30I', 'item_B003AYIKNW', 'item_B003YOT0CI', 'item_B00XKVPB6E']
# Item Sequence for idx 6273: ['item_B0002GIRQ6', 'item_B00JA4T724', 'item_B00T3SKTCO', 'item_B07N1SH5PL']
# Item Sequence for idx 6274: ['item_B00BAXJEAS', 'item_B000ATOFS4', 'item_B000VBH2IG', 'item_B00IACIQP6']
# Item Sequence for idx 6275: ['item_B000MFL7UU', 'item_B07793SCG3']
# Item Sequence for idx 6276: ['item_B00NTMC4SC', 'item_B00JJE1DX6', 'item_B0002CZW0Y', 'item_B01EXY1YV2']
# Item Sequence for idx 6277: ['item_B00GP56OYA', 'item_B08P1HMYC3']
# Item Sequence for idx 6278: ['item_B0072VPA14', 'item_B0033PSLSM', 'item_B005FKF2QC', 'item_B0037M62KA']
# Item Sequence for idx 6279: ['item_B005FKF2QC', 'item_B0037M62KA', 'item_B00SKT4PT0', 'item_B0002D0H0S']
# Item Sequence for idx 6280: ['item_B00SKT4PT0', 'item_B0002D0H0S', 'item_B0002KZDN2', 'item_B00C5B20QE']
# Item Sequence for idx 6281: ['item_B0002KZDN2', 'item_B00C5B20QE', 'item_B000068NYX', 'item_B00LJY360C']
# Item Sequence for idx 6282: ['item_B000EENC0C', 'item_B002HF9ZHK', 'item_B07MZN3Z16', 'item_B07YPZDMRK']
# Item Sequence for idx 6283: ['item_B07MZN3Z16', 'item_B07YPZDMRK', 'item_B0008FUWEG', 'item_B00VYQABEE']
# Item Sequence for idx 6284: ['item_B082Q2Y9VY', 'item_B00373GYW0']
# Item Sequence for idx 6285: ['item_B01H74YXNQ', 'item_B0818N5GVM']
# Item Sequence for idx 6286: ['item_B003ELQ23Q', 'item_B002M897SE', 'item_B004YPRPJ6', 'item_B00CPCJI2C']
# Item Sequence for idx 6287: ['item_B0092V7WJ0', 'item_B01FRB1S8E']
# Item Sequence for idx 6288: ['item_B000068NYH', 'item_B015GTG454']
# Item Sequence for idx 6289: ['item_B00QT1E3K2', 'item_B08LKMX584']
# Item Sequence for idx 6290: ['item_B0002GWRAS', 'item_B000UH2O16', 'item_B001B47WDC', 'item_B0014N0DPY']
# Item Sequence for idx 6291: ['item_B001B47WDC', 'item_B0014N0DPY', 'item_B00INK6PIU']
# Item Sequence for idx 6292: ['item_B0007NQH98', 'item_B01L3LL95O', 'item_B07WWGKL7J']
# Item Sequence for idx 6293: ['item_B0023ZOF6U', 'item_B0002CZUUQ', 'item_B0018TIADQ', 'item_B000CC4JFS']
# Item Sequence for idx 6294: ['item_B0018TIADQ', 'item_B000CC4JFS', 'item_B0002E2XOA', 'item_B003LTJ404']
# Item Sequence for idx 6295: ['item_B0002GZSKY', 'item_B012VQ5A7S', 'item_B00GHQXEFY', 'item_B0002D0CYE']
# Item Sequence for idx 6296: ['item_B00BHJNC4E', 'item_B00U49CFUA', 'item_B0197TVD6Y', 'item_B07KWVLJFM']
# Item Sequence for idx 6297: ['item_B000T9PE9E', 'item_B0002DV7U2', 'item_B00CAV0TRQ', 'item_B012VQ5A7S']
# Item Sequence for idx 6298: ['item_B002Q0WTEC', 'item_B00063678K']
# Item Sequence for idx 6299: ['item_B07176XWLD', 'item_B0002GU01G', 'item_B01KZRPPKW']
# Item Sequence for idx 6300: ['item_B000068IDU', 'item_B000XI6O2W']
# Item Sequence for idx 6301: ['item_B002XZ8NTA', 'item_B079DR3LMV', 'item_B00YC7GU9W']
# Item Sequence for idx 6302: ['item_B006HNRXV8', 'item_B002HJ9PTO', 'item_B003JJQMD8', 'item_B0002GXF8Q']
# Item Sequence for idx 6303: ['item_B077THLFYQ', 'item_B000AL8XUI', 'item_B008BPI2OW']
# Item Sequence for idx 6304: ['item_B0002F52EW', 'item_B003ZYELUS', 'item_B000E1WDS2', 'item_B00F4MOR0I']
# Item Sequence for idx 6305: ['item_B079JJZXJ4', 'item_B07T5JZ64R']
# Item Sequence for idx 6306: ['item_B00CSYN9JU', 'item_B0018TAFEI', 'item_B0002E1G5C', 'item_B0002DUWB2']
# Item Sequence for idx 6307: ['item_B0014ZG676', 'item_B0014ZG676', 'item_B06XCTSGF4']
# Item Sequence for idx 6308: ['item_B001F9LFMW', 'item_B0786WMY7G', 'item_B08PQB9W9Q']
# Item Sequence for idx 6309: ['item_B000CZ0RK6', 'item_B000OR2RNM', 'item_B000E1S3OA', 'item_B00076XOXC']
# Item Sequence for idx 6310: ['item_B000E1S3OA', 'item_B00076XOXC']
# Item Sequence for idx 6311: ['item_B00O4L3F9E', 'item_B00PB34DSG']
# Item Sequence for idx 6312: ['item_B07C7LCS2Q', 'item_B007T92I8C', 'item_B009FKHV62', 'item_B083QTGD1R']
# Item Sequence for idx 6313: ['item_B00HHGUAVY', 'item_B00UJVB08G', 'item_B07G9WDDQN']
# Item Sequence for idx 6314: ['item_B00ISQCJKM', 'item_B01LX1H4HC', 'item_B002G1UT5C', 'item_B01H74YY62']
# Item Sequence for idx 6315: ['item_B0006FL8PK', 'item_B00CAV0TRQ']
# Item Sequence for idx 6316: ['item_B07DJ4ZGZR', 'item_B01DZXE9NC']
# Item Sequence for idx 6317: ['item_B000XPSGU8', 'item_B004TEWG7S', 'item_B004FEGXDK', 'item_B08HQCG79H']
# Item Sequence for idx 6318: ['item_B00H02C9TG', 'item_B0032TUQIC', 'item_B00I3XGGPO', 'item_B00A7KC9NO']
# Item Sequence for idx 6319: ['item_B00I3XGGPO', 'item_B00A7KC9NO', 'item_B005PNXVDU', 'item_B000OR2RNM']
# Item Sequence for idx 6320: ['item_B000068NW7', 'item_B01A6B0ICC']
# Item Sequence for idx 6321: ['item_B00W1RTVGO', 'item_B0002OOMU8']
# Item Sequence for idx 6322: ['item_B00GR9W1MS', 'item_B0002GZWZ0', 'item_B00AKGAH4S']
# Item Sequence for idx 6323: ['item_B0B424Q6VB', 'item_B0BJDT1KNH', 'item_B0BHZ6Y1VG']
# Item Sequence for idx 6324: ['item_B00HEP1XV4', 'item_B00JFEHQV8']
# Item Sequence for idx 6325: ['item_B002HQPXS4', 'item_B000068NYY']
# Item Sequence for idx 6326: ['item_B073RT6KZX', 'item_B00H38AVQ0']
# Item Sequence for idx 6327: ['item_B00XQCRR5U', 'item_B00PHVGGMI', 'item_B00HJOTFI8', 'item_B0002DVD7O']
# Item Sequence for idx 6328: ['item_B0002KZAKS', 'item_B01H62FQ3U', 'item_B07TDF36B8', 'item_B08J47YJM4']
# Item Sequence for idx 6329: ['item_B0002DVBJY', 'item_B0002GIW3Y']
# Item Sequence for idx 6330: ['item_B00XMVZBUS', 'item_B01LW87E6G', 'item_B09BQJZ83G']
# Item Sequence for idx 6331: ['item_B017PMA3LG', 'item_B01E53DSLA']
# Item Sequence for idx 6332: ['item_B09YSW8QGR', 'item_B06XDCPYS1', 'item_B0B1DD45PN', 'item_B09ZQNHZXR']
# Item Sequence for idx 6333: ['item_B0B1DD45PN', 'item_B09ZQNHZXR', 'item_B09VCDHWN2', 'item_B09WVRBDMC']
# Item Sequence for idx 6334: ['item_B093KG7YW9', 'item_B0BD566VLL', 'item_B0BGNQV2F4', 'item_B09QZ5M3HD']
# Item Sequence for idx 6335: ['item_B0002GZTT4', 'item_B004P0MWCU', 'item_B000L6GD04', 'item_B09ZG1G76D']
# Item Sequence for idx 6336: ['item_B0002D02SA', 'item_B0B6SV4DN6']
# Item Sequence for idx 6337: ['item_B07N1JR6MX', 'item_B0016H8RY2', 'item_B0B21B8ZHP', 'item_B0762X9JZW']
# Item Sequence for idx 6338: ['item_B005FKF1PY', 'item_B01JLT840S', 'item_B000MFN8B6', 'item_B00BLQ7M4E']
# Item Sequence for idx 6339: ['item_B00JRG8AJ6', 'item_B00JA4T7GU', 'item_B004CG2V28', 'item_B07HLCCLQH']
# Item Sequence for idx 6340: ['item_B015OPQGBC', 'item_B07BJ4DW86']
# Item Sequence for idx 6341: ['item_B076GHR7DN', 'item_B073LSS9TJ', 'item_B0002F741G']
# Item Sequence for idx 6342: ['item_B004H7SO4G', 'item_B0036E8DE2', 'item_B0069M5U6C', 'item_B005GPYDVQ']
# Item Sequence for idx 6343: ['item_B078PTM82R', 'item_B004Q5PJ9M']
# Item Sequence for idx 6344: ['item_B08TZSQD2F', 'item_B00ESJDQ4Q']
# Item Sequence for idx 6345: ['item_B017TH7ON2', 'item_B00VYCZ79M']
# Item Sequence for idx 6346: ['item_B019NY2PKG', 'item_B018K9K034', 'item_B018NDYU5Q', 'item_B0006NMUHM']
# Item Sequence for idx 6347: ['item_B000NJ2TIE', 'item_B00OZ9C9LK', 'item_B003PC2XQE', 'item_B003Y2Q0M8']
# Item Sequence for idx 6348: ['item_B000EEK4VM', 'item_B00CAV0TRQ']
# Item Sequence for idx 6349: ['item_B018FCZBMG', 'item_B0002D0CQC', 'item_B0002GOJZO', 'item_B000A6CXUO']
# Item Sequence for idx 6350: ['item_B001VO9FNM', 'item_B07D5KK26W', 'item_B001LG2KH8', 'item_B007J49HPE']
# Item Sequence for idx 6351: ['item_B001LG2KH8', 'item_B007J49HPE', 'item_B079T4WJDT', 'item_B09XGJ626C']
# Item Sequence for idx 6352: ['item_B000KIPTE4', 'item_B000068O3X']
# Item Sequence for idx 6353: ['item_B07MH391ZF', 'item_B01DPOXS8I', 'item_B01EVPO8IO', 'item_B016C4ZG74']
# Item Sequence for idx 6354: ['item_B077N2KJZX', 'item_B07CGBD6BD']
# Item Sequence for idx 6355: ['item_1616770872', 'item_B000G1GGTM']
# Item Sequence for idx 6356: ['item_B000068NTU', 'item_B07H5QJW86']
# Item Sequence for idx 6357: ['item_B08H5R5RFG', 'item_B000EEJ91I', 'item_B017PH9682']
# Item Sequence for idx 6358: ['item_B003URZWLW', 'item_B008876Y4S', 'item_B002RLLD88', 'item_B000FMDIXY']
# Item Sequence for idx 6359: ['item_B003LPTAYI', 'item_B00F4T2KSW']
# Item Sequence for idx 6360: ['item_B019HR9DHC', 'item_B01N8TLTXW', 'item_B00VK4YXF8', 'item_B000VPLI6O']
# Item Sequence for idx 6361: ['item_B0037M62KA', 'item_B007Q2GR9I']
# Item Sequence for idx 6362: ['item_B000CD1R7K', 'item_B08B5SJSQR']
# Item Sequence for idx 6363: ['item_B003BLPCE4', 'item_B0002E2LS8']
# Item Sequence for idx 6364: ['item_B07PLMGMH8', 'item_B0773ZXW1J', 'item_B08TGGLP6V']
# Item Sequence for idx 6365: ['item_B071KCSSXZ', 'item_B0006NDF8A']
# Item Sequence for idx 6366: ['item_B0002GX63A', 'item_B00HWVCXLO']
# Item Sequence for idx 6367: ['item_B07T4X83T3', 'item_B00EQ25TXQ', 'item_B08CB1Q6B9', 'item_B081CBM256']
# Item Sequence for idx 6368: ['item_B08CB1Q6B9', 'item_B081CBM256', 'item_B000EEK4VM', 'item_B0002E1O2C']
# Item Sequence for idx 6369: ['item_B07CJG88D7', 'item_B0002E3DNU', 'item_B07TV7J574', 'item_B085QHX6DX']
# Item Sequence for idx 6370: ['item_B07S3TG2SX', 'item_B07BXYHBM9']
# Item Sequence for idx 6371: ['item_B00KEMWKNE', 'item_B015WSQKEE', 'item_B01LWNQXWZ', 'item_B00RCO415C']
# Item Sequence for idx 6372: ['item_B0002H0NOY', 'item_B003B0HZTA']
# Item Sequence for idx 6373: ['item_B0040FJ27S', 'item_B00B43LK88', 'item_B01M9K5JP3']
# Item Sequence for idx 6374: ['item_B086BCB926', 'item_B018FCZKR2']
# Item Sequence for idx 6375: ['item_B004NRVUMI', 'item_B0154JSY68']
# Item Sequence for idx 6376: ['item_B004M8YPKM', 'item_B00IJ6QAO2', 'item_B00DMHW6IW']
# Item Sequence for idx 6377: ['item_B073RMQKYG', 'item_B06VVX425G']
# Item Sequence for idx 6378: ['item_B000ZJTPLG', 'item_B0009EQOES', 'item_B002G1UT5C', 'item_B001QJGYIG']
# Item Sequence for idx 6379: ['item_B0040O49OU', 'item_B0002OOMW6', 'item_B000EELB8W', 'item_B007KRPZH4']
# Item Sequence for idx 6380: ['item_B007XSHAEQ', 'item_B00ND1KUH6', 'item_B007W2DN3A', 'item_B00P6Y0E3I']
# Item Sequence for idx 6381: ['item_B0002CZVK0', 'item_B00GTSM8CK', 'item_B000EEN7UM', 'item_B00MB5F33Q']
# Item Sequence for idx 6382: ['item_B083ND1LXV', 'item_B086XDX71B']
# Item Sequence for idx 6383: ['item_B00TXC247S', 'item_B009J8DXQW']
# Item Sequence for idx 6384: ['item_B001SN7R4A', 'item_B010UXKLLO']
# Item Sequence for idx 6385: ['item_B0844R13PX', 'item_B07YB9NPRS', 'item_B00LJY4886', 'item_B01HFLKO6G']
# Item Sequence for idx 6386: ['item_B00Y0CG9YA', 'item_B07MVYWJMW', 'item_B00191WVF6']
# Item Sequence for idx 6387: ['item_B0064RTUP4', 'item_B00191WVF6']
# Item Sequence for idx 6388: ['item_B0042EZH6W', 'item_B0045XUU08']
# Item Sequence for idx 6389: ['item_B005GWGI94', 'item_0899333990']
# Item Sequence for idx 6390: ['item_B09KGNM7KV', 'item_B09QKGPVKK']
# Item Sequence for idx 6391: ['item_B001RXMWK0', 'item_B0064S4CTM', 'item_B0083TSTRG', 'item_B000GUR8V8']
# Item Sequence for idx 6392: ['item_B07DHLSTLV', 'item_B014EJY0JE']
# Item Sequence for idx 6393: ['item_B00H40VBSY', 'item_B001FWYBKC', 'item_B00MIXFBL0', 'item_B00JB4WAR2']
# Item Sequence for idx 6394: ['item_B00JGATTG6', 'item_B003B1P1AE', 'item_B00HKLIT8W', 'item_B004UFICJW']
# Item Sequence for idx 6395: ['item_B0002D0CNA', 'item_B079T6FZQZ', 'item_B003HNY1IY', 'item_B07CRW3VYM']
# Item Sequence for idx 6396: ['item_B0000AQRSU', 'item_B09LD4SC8X', 'item_B07T14WDJF']
# Item Sequence for idx 6397: ['item_B001G9ANIS', 'item_B001BNQ6TO']
# Item Sequence for idx 6398: ['item_B010CI6M88', 'item_B01H74YXNQ']
# Item Sequence for idx 6399: ['item_B00B6WZGHS', 'item_B00E9EC2K4', 'item_B0009RLE5Y', 'item_B004UIDPNW']
# Item Sequence for idx 6400: ['item_B01IK5ZXJ4', 'item_B006ZMKJ7G', 'item_B0002PZ3A0', 'item_B01GMLOKE2']
# Item Sequence for idx 6401: ['item_B00646MZHK', 'item_B00JSCP51A', 'item_B004U2HT9Y', 'item_B0002DVD7E']
# Item Sequence for idx 6402: ['item_B002YKXIZS', 'item_B001Q3KTHE', 'item_B00B9060X6', 'item_B00RHSQ4LW']
# Item Sequence for idx 6403: ['item_B00B9060X6', 'item_B00RHSQ4LW', 'item_B07GZHQDL1']
# Item Sequence for idx 6404: ['item_B0791TFWLD', 'item_B0866CYP7Z', 'item_B0833338PJ', 'item_B09HX15ZY1']
# Item Sequence for idx 6405: ['item_B0833338PJ', 'item_B09HX15ZY1', 'item_B08TPJ51N3', 'item_B073PYNCVB']
# Item Sequence for idx 6406: ['item_B002HF483G', 'item_B002HFAAVA', 'item_B0002E2G5Q', 'item_B0002KZE7C']
# Item Sequence for idx 6407: ['item_B0002D0IIY', 'item_B0007XWUQ2', 'item_B003YU0PH6', 'item_B005O24E1K']
# Item Sequence for idx 6408: ['item_B000SOD19U', 'item_B003WVYJZ6', 'item_B0002D0MJY', 'item_B0002D0MI0']
# Item Sequence for idx 6409: ['item_B000648CPU', 'item_B01LW038J1', 'item_B07QRRXKTC', 'item_B000EAKZJ2']
# Item Sequence for idx 6410: ['item_B07QRRXKTC', 'item_B000EAKZJ2']
# Item Sequence for idx 6411: ['item_B01G7QXYOE', 'item_B012VQ5A7S']
# Item Sequence for idx 6412: ['item_B078YQW5PP', 'item_B01MSZCYKL', 'item_B07LC8LYK2', 'item_B00L5QAPYO']
# Item Sequence for idx 6413: ['item_B01IW94PLU', 'item_B0002DUQ72', 'item_B07GXWKL9Y', 'item_B001L8NGJ2']
# Item Sequence for idx 6414: ['item_B00GVGHHCG', 'item_B000N3ZK36', 'item_B0140PU546', 'item_B00N8JDJUS']
# Item Sequence for idx 6415: ['item_B007RQUYJC', 'item_B002OO18NS']
# Item Sequence for idx 6416: ['item_B00191WVF6', 'item_B0719CBYXJ', 'item_B08HKC5V5N', 'item_B0078OQ50U']
# Item Sequence for idx 6417: ['item_B00JSCP1FA', 'item_B0B4S5S91H']
# Item Sequence for idx 6418: ['item_B00004UE29', 'item_B00ADEJIQ0', 'item_B00479EI76', 'item_B0002M6CVC']
# Item Sequence for idx 6419: ['item_B07572NWC8', 'item_B0070Z8DM0', 'item_B082GLNKQR']
# Item Sequence for idx 6420: ['item_B000FP94Z2', 'item_B0002GX63A']
# Item Sequence for idx 6421: ['item_B00RMJORJ2', 'item_B007I821GI', 'item_B00B9060X6', 'item_B0013V1BYY']
# Item Sequence for idx 6422: ['item_B0012BPMHW', 'item_B0795PNCBG']
# Item Sequence for idx 6423: ['item_B003D2S7HA', 'item_B000068O3C', 'item_B01B15JPCQ']
# Item Sequence for idx 6424: ['item_B00HQWR7LA', 'item_B00Y4S5Z5O', 'item_B07CTYX4S3']
# Item Sequence for idx 6425: ['item_B0002D02SK', 'item_B000EEJ8CS', 'item_B01J5A06OU']
# Item Sequence for idx 6426: ['item_B0002H0JZC', 'item_B0055V7UR0']
# Item Sequence for idx 6427: ['item_B005RA4B7G', 'item_B01HFLKO6G', 'item_B019BNMVFI', 'item_B08945DYB9']
# Item Sequence for idx 6428: ['item_B01BO2L6KA', 'item_B08XYYT831', 'item_B08NFPZTPF', 'item_B001PGXHXA']
# Item Sequence for idx 6429: ['item_B001FUDJK2', 'item_B0006LXW8U']
# Item Sequence for idx 6430: ['item_B07JKNG4NV', 'item_B082YHPC3Z']
# Item Sequence for idx 6431: ['item_B000EEJB0M', 'item_B0007ZEY8W', 'item_B00RCO415C', 'item_B0011EG5M6']
# Item Sequence for idx 6432: ['item_B00NP8GYVS', 'item_B075RH24L3']
# Item Sequence for idx 6433: ['item_B0083FTVB8', 'item_B01HHWQHOQ']
# Item Sequence for idx 6434: ['item_B01B15JPCQ', 'item_B013LG9WQM']
# Item Sequence for idx 6435: ['item_B000Y010WS', 'item_B009WS7TSW', 'item_B003GVBDCO', 'item_B001UO05X2']
# Item Sequence for idx 6436: ['item_B000EEL6J6', 'item_B0002E1NQE']
# Item Sequence for idx 6437: ['item_B09SDG381C', 'item_B08K7DY2QN']
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 21.41s | valid loss  7.95 | valid ppl  2830.41
# -----------------------------------------------------------------------------------------
# <ipython-input-89-6292c2a5b908>:32: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_params_path)) # load best model states

# %%
def get_popular_items(df_ratings):
  # Calculate the number of ratings for each item
  rating_counts = df['item_id'].value_counts().reset_index()
  rating_counts.columns = ['item_id', 'rating_count']

  # Get the most frequently rated items
  min_ratings_threshold = rating_counts['rating_count'].quantile(0.95)

  # Filter items based on the minimum number of ratings
  popular_items = df.merge(rating_counts, on='item_id')
  popular_items = popular_items[popular_items['rating_count'] >= min_ratings_threshold]

  # Calculate the average rating for each item
  average_ratings = popular_items.groupby('item_id')['rating'].mean().reset_index()

  # Get the top 10 rated items
  top_10_items = list(average_ratings.sort_values('rating', ascending=False).head(10).item_id.values)
  return top_10_items

# %%
# A placeholders to store results of recommendations
transformer_reco_results = list()
popular_reco_results = list()

# Get top 10 items
k = 10
# Iterate over the validation data
for i, (item_data, user_data) in enumerate(val_iter):
    # Feed the input and get the outputs
    item_data, user_data = item_data.to(device), user_data.to(device)
    user_data = user_data.reshape(-1, 1)
    inputs, targets = item_data[:, :-1], item_data[:, 1:]
    output = model(inputs, user_data)
    output_flat = output.reshape(-1, ntokens)
    targets_flat = targets.reshape(-1)

    # Reshape the output_flat to get top predictions
    outputs = output_flat.reshape(output_flat.shape[0] // inputs.shape[1],
                                  inputs.shape[1],
                                  output_flat.shape[1])[: , -1, :]
    # k + inputs.shape[1] = 13 items obtained
    # In order to prevent to recommend already watched items
    values, indices = outputs.topk(k + inputs.shape[1], dim=-1)

    for sub_sequence, sub_indice_org in zip(item_data, indices):
        sub_indice_org = sub_indice_org.cpu().detach().numpy()
        sub_sequence = sub_sequence.cpu().detach().numpy()

        # Generate mask array to eliminate already watched item
        mask = np.isin(sub_indice_org, sub_sequence[:-1], invert=True)

        # After masking get top k items
        sub_indice = sub_indice_org[mask][:k]

        # Generate results array
        transformer_reco_result = np.isin(sub_indice, sub_sequence[-1]).astype(int)

        # Decode items to search in popular items
        if sub_sequence[-1] in item_vocab_stoi:
            target_item_decoded = item_vocab_stoi[sub_sequence[-1]]
        else:
            # Handle missing item (skip, set to default, etc.)
            target_item_decoded = None  # or some default value

        top_10_items = get_popular_items(df)

        popular_reco_result = np.isin(top_10_items, target_item_decoded).astype(int)

        transformer_reco_results.append(transformer_reco_result)
        popular_reco_results.append(popular_reco_result)
# Out:
# Item Sequence for idx 0: ['item_B01EUG7ENA', 'item_B00XBQ8UGG', 'item_B0007L8BQW', 'item_B075HCLMYP']
# Item Sequence for idx 1: ['item_B0051NSNFK', 'item_B07N1W86NK']
# Item Sequence for idx 2: ['item_B004NFPZLM', 'item_B0002E3A8S', 'item_B000FZ1KF4', 'item_B0009R1TUY']
# Item Sequence for idx 3: ['item_B000FZ1KF4', 'item_B0009R1TUY', 'item_B0050P09WY', 'item_B003CUJEKC']
# Item Sequence for idx 4: ['item_B0043WF8PI', 'item_B00PC17212', 'item_B000T4F9WG', 'item_B004VDD4KK']
# Item Sequence for idx 5: ['item_B00QXF3XTQ', 'item_B000EEJ6OI', 'item_B009A3B958', 'item_B003B0HLK8']
# Item Sequence for idx 6: ['item_B01BOYPXXO', 'item_B0071UH32A', 'item_B000EENLZI', 'item_B0719KM5Y8']
# Item Sequence for idx 7: ['item_B0013V1BYY', 'item_B00KCXMBES', 'item_B002QAUOKS', 'item_B00QCMEXIU']
# Item Sequence for idx 8: ['item_B000EEJ91I', 'item_B000L6GD04', 'item_B0002D0LM2', 'item_B003986L1W']
# Item Sequence for idx 9: ['item_B0851WNWCH', 'item_B07NR4NX5M']
# Item Sequence for idx 10: ['item_B07C7RR75R', 'item_B004SH5SS0']
# Item Sequence for idx 11: ['item_B0002LZU52', 'item_B0002D0HXA']
# Item Sequence for idx 12: ['item_B0046W35NW', 'item_B0002DV7ZM', 'item_B00GPHHT4C', 'item_B0037M4CPM']
# Item Sequence for idx 13: ['item_B001PGXKE6', 'item_B00WR8M5MO', 'item_B07NDW2L5L']
# Item Sequence for idx 14: ['item_B0026IC6QU', 'item_B07YTXG5GJ', 'item_B081N678BV']
# Item Sequence for idx 15: ['item_B004TVJL1U', 'item_B001QXCYZY']
# Item Sequence for idx 16: ['item_B085BK5MN6', 'item_B00ZU6PJCS', 'item_B002AQNGIU']
# Item Sequence for idx 17: ['item_B07N2QG4C3', 'item_B0002DUPZA', 'item_B00MS7GAXE', 'item_B08JPJ31MT']
# Item Sequence for idx 18: ['item_B0002D0CIK', 'item_B06ZZ65P1T', 'item_B091762MCD', 'item_B0002D05SC']
# Item Sequence for idx 19: ['item_B000F3KSPO', 'item_B083VXTMY4', 'item_B00DDXJPXY', 'item_B0746K12W7']
# Item Sequence for idx 20: ['item_B00JA4T7MO', 'item_B00AC0OBYE', 'item_B09ZQG5YCP', 'item_B00WHG21LG']
# Item Sequence for idx 21: ['item_B01MQRD6JE', 'item_B008I5QTQI']
# Item Sequence for idx 22: ['item_B018TGCFW2', 'item_B07QWGZNTX']
# Item Sequence for idx 23: ['item_B01N9PU319', 'item_B01IOL0MJK']
# Item Sequence for idx 24: ['item_B00CBISHS6', 'item_B09NZJB2JG', 'item_B08MVBVSRD']
# Item Sequence for idx 25: ['item_B07DTB6LDD', 'item_B0002KZE9U']
# Item Sequence for idx 26: ['item_B075QVMBT9', 'item_B07HD7M29H', 'item_B07YR2N76Z', 'item_B07ZR2G296']
# Item Sequence for idx 27: ['item_B00MFNYTK2', 'item_B07TT2D4RR', 'item_B087C84Y5P', 'item_B00191WVF6']
# Item Sequence for idx 28: ['item_B0002D0CIU', 'item_B004DNV9MS']
# Item Sequence for idx 29: ['item_B0077UGGQI', 'item_B005LVJRIE', 'item_B0002D0DAM', 'item_B0002F6HXW']
# Item Sequence for idx 30: ['item_B0002D0DAM', 'item_B0002F6HXW', 'item_B01M34E5G4']
# Item Sequence for idx 31: ['item_B07H9Z47Q3', 'item_B004MNCXJ2', 'item_B001FXOAQQ', 'item_B01BRV8V6K']
# Item Sequence for idx 32: ['item_B004K89PA4', 'item_B001L8PIEI', 'item_B003HGQTIG', 'item_B002A8Y49I']
# Item Sequence for idx 33: ['item_B004K87X8A', 'item_B004H1RS26', 'item_B0002E36AK', 'item_B071VB8BB6']
# Item Sequence for idx 34: ['item_B07JMFP24N', 'item_B000A7V39K', 'item_B08NFM9S89', 'item_B08PMDM1RH']
# Item Sequence for idx 35: ['item_B08NFM9S89', 'item_B08PMDM1RH', 'item_B002NLLLUM']
# Item Sequence for idx 36: ['item_B002Q0WTEC', 'item_B00NP80XMO']
# Item Sequence for idx 37: ['item_B00KMA0R38', 'item_B000WS1QC6']
# Item Sequence for idx 38: ['item_B000F51B8U', 'item_B000EENAD6']
# Item Sequence for idx 39: ['item_B08ND18BK1', 'item_B09J2P22M6']
# Item Sequence for idx 40: ['item_B0014MYTJ6', 'item_B003LPTAYI', 'item_B000788VQK', 'item_B007PZA7QA']
# Item Sequence for idx 41: ['item_B000788VQK', 'item_B007PZA7QA']
# Item Sequence for idx 42: ['item_B004WI2JVE', 'item_B0002M6CW6', 'item_B0002OOMU8', 'item_B077N2KJZX']
# Item Sequence for idx 43: ['item_B008J4CS3G', 'item_B00A270KYM', 'item_B00BV0199O', 'item_B0002KZDIM']
# Item Sequence for idx 44: ['item_B00191WVF6', 'item_B00191WVF6', 'item_B01E6T56CM', 'item_B01E6T56CM']
# Item Sequence for idx 45: ['item_B075MPBBGX', 'item_B075MPBBGX']
# Item Sequence for idx 46: ['item_B00OMRVZ1K', 'item_B00GXMWQN8']
# Item Sequence for idx 47: ['item_B00XMCRVXC', 'item_B07K8FQFN8']
# Item Sequence for idx 48: ['item_B00CAUYNCO', 'item_B000CC4JFS', 'item_B006WAB1UK']
# Item Sequence for idx 49: ['item_B007R7BN9Q', 'item_B0002GVKU6']
# Item Sequence for idx 50: ['item_B07ZVXLNX9', 'item_B083ZS59L8']
# Item Sequence for idx 51: ['item_B0050AGZBI', 'item_B000K6B4E0']
# Item Sequence for idx 52: ['item_B003VYBD44', 'item_B002BAZNHW']
# Item Sequence for idx 53: ['item_B00063678K', 'item_B00CE6BLN8']
# Item Sequence for idx 54: ['item_B011QOGY12', 'item_B00LTDON0K', 'item_B01LX1H4HC']
# Item Sequence for idx 55: ['item_B0002E1NQE', 'item_B0924BQ4B2']
# Item Sequence for idx 56: ['item_B06WVFRW4H', 'item_B0007L8BQW']
# Item Sequence for idx 57: ['item_B0BCYWGJ33', 'item_B0BNHPD9WJ', 'item_B0B28LCLNY', 'item_B06ZZZK812']
# Item Sequence for idx 58: ['item_B00IJQP0U2', 'item_B0002EJOCO', 'item_B0002FOJWI']
# Item Sequence for idx 59: ['item_B0006NL5SM', 'item_B00CXSJUZS', 'item_B0711M2VRR', 'item_B0734DZ4Q5']
# Item Sequence for idx 60: ['item_B01M6WQ2CO', 'item_B0002F58TG', 'item_B0020288RI', 'item_B003BNHJHU']
# Item Sequence for idx 61: ['item_B004HR1MY0', 'item_B00127HZG2', 'item_B00JYJFE72', 'item_B00FOL1WG6']
# Item Sequence for idx 62: ['item_B07JMP8M82', 'item_B078H37JDV', 'item_B008LUW4CI', 'item_B004YHJK4C']
# Item Sequence for idx 63: ['item_B00QHURLHM', 'item_B004FEGXDK', 'item_B004AE3W7U', 'item_B081BTFTTK']
# Item Sequence for idx 64: ['item_B00ADHKKZK', 'item_B0002D0CAI']
# Item Sequence for idx 65: ['item_B0002E4Z8M', 'item_B004LWH79A', 'item_B0130VVOOG', 'item_B084PP4DT8']
# Item Sequence for idx 66: ['item_B0130VVOOG', 'item_B084PP4DT8']
# Item Sequence for idx 67: ['item_B01K0T4ZYW', 'item_B01M0817LI', 'item_B08TQJLG5F', 'item_B01MQYTIY9']
# Item Sequence for idx 68: ['item_B00W3HKL8Y', 'item_B00UTUK1SC', 'item_B000EEJJ5Y', 'item_B00NCFWAXA']
# Item Sequence for idx 69: ['item_B000EEJJ5Y', 'item_B00NCFWAXA']
# Item Sequence for idx 70: ['item_B007HZGC08', 'item_B001UJIYIK', 'item_B0002FOXD8', 'item_B001CCQ6XA']
# Item Sequence for idx 71: ['item_B074KJ1N3D', 'item_B016C4ZG74']
# Item Sequence for idx 72: ['item_B003VYBD44', 'item_B0002E3GV4']
# Item Sequence for idx 73: ['item_B0002E1G5C', 'item_B0002ZPLDY', 'item_B0002KZSXM', 'item_B000B5IKEW']
# Item Sequence for idx 74: ['item_B000EENHAW', 'item_B000AYF8YE']
# Item Sequence for idx 75: ['item_B0002F7IEE', 'item_B00MY6VQ60']
# Item Sequence for idx 76: ['item_B01EJ7G68O', 'item_B07LGJ65JC', 'item_B07CNV5J2W', 'item_B000AYFZN8']
# Item Sequence for idx 77: ['item_B0002F4TKU', 'item_B008O0RKVA', 'item_B0013Y0340', 'item_B006HR1H1Q']
# Item Sequence for idx 78: ['item_B0013Y0340', 'item_B006HR1H1Q', 'item_B00ES57CNQ', 'item_B0002BG4O8']
# Item Sequence for idx 79: ['item_B01B15JPCQ', 'item_B08ZM67WTR']
# Item Sequence for idx 80: ['item_B01N5OYNMT', 'item_B0007WLWMG', 'item_B06XFN2L1H', 'item_B00NARHNCS']
# Item Sequence for idx 81: ['item_B07VYL88B7', 'item_B01MTXYWHV', 'item_B08G89QM3Z', 'item_B000P0XBS8']
# Item Sequence for idx 82: ['item_B079QYRRT1', 'item_B07BNPTNLZ', 'item_B0016QPXH2', 'item_B08CKB7CQ8']
# Item Sequence for idx 83: ['item_B07XZJ8KNN', 'item_B00Y83YJBG']
# Item Sequence for idx 84: ['item_B0006NDF8A', 'item_B0002E2O2Q', 'item_B075VTWHYG']
# Item Sequence for idx 85: ['item_B00F4MOR0I', 'item_B07FDHDP8H']
# Item Sequence for idx 86: ['item_B00DJA5O2M', 'item_B00DD5WWQE', 'item_B00I5R29OK', 'item_B00ZPWKO72']
# Item Sequence for idx 87: ['item_B004XLFKIO', 'item_B07WJ35RCJ']
# Item Sequence for idx 88: ['item_B000RN53LQ', 'item_B06Y27KJC5', 'item_B01KMYYKDG', 'item_B004MLKOZE']
# Item Sequence for idx 89: ['item_B088R741JZ', 'item_B01JNLUU9C', 'item_B07B6PD265', 'item_B0002F7JT8']
# Item Sequence for idx 90: ['item_B07B6PD265', 'item_B0002F7JT8', 'item_B07ZVZ8BS3', 'item_B07563QWXQ']
# Item Sequence for idx 91: ['item_B004MAX67S', 'item_B001T9O60Q', 'item_B016NULFJK']
# Item Sequence for idx 92: ['item_B003JJQMD8', 'item_B000S5L2WW', 'item_B000HZCG4G']
# Item Sequence for idx 93: ['item_B000972FWK', 'item_B00EQ232KI', 'item_B00HF07D6M', 'item_B000GFWS7W']
# Item Sequence for idx 94: ['item_B01K18HFOY', 'item_B07DPMHM69', 'item_B01N6448Q4', 'item_B0079YWOJ0']
# Item Sequence for idx 95: ['item_B01LXOJZJ9', 'item_B00AJHE54G']
# Item Sequence for idx 96: ['item_B0002F6SHM', 'item_B0002D0OSS', 'item_B000OR2T0I', 'item_B00743L8E8']
# Item Sequence for idx 97: ['item_B007G7IIU4', 'item_B0002D0CHG', 'item_B004HJ58PM', 'item_B0002D0EAG']
# Item Sequence for idx 98: ['item_B07B679W4K', 'item_B00T0OJG9S']
# Item Sequence for idx 99: ['item_B07NDWS1D4', 'item_B083H43MKM']
# Item Sequence for idx 100: ['item_B00BAFNDBW', 'item_B001FWYAX0', 'item_B0006NDF8A', 'item_B00FMK98NS']
# Item Sequence for idx 101: ['item_B01M68UK38', 'item_B08MZX89X5', 'item_B019I3J37A', 'item_B07K8FQFN8']
# Item Sequence for idx 102: ['item_B0045XUU08', 'item_B000KIPUQG', 'item_B003M76KNY']
# Item Sequence for idx 103: ['item_B006MPUZJ8', 'item_B00266N6L6', 'item_B000XPPURU', 'item_B001OMGZLQ']
# Item Sequence for idx 104: ['item_B003B01QR2', 'item_B01DBHC9U2', 'item_B075MDZDXM', 'item_B0002NYEXE']
# Item Sequence for idx 105: ['item_B00SHCH5RO', 'item_B00SHCDMRQ', 'item_B00IWRJSE2']
# Item Sequence for idx 106: ['item_B00XWH7FU6', 'item_B00IKVCZD6', 'item_B07GBXFPZ6']
# Item Sequence for idx 107: ['item_B01N9PU319', 'item_B016APP6NO', 'item_B07R6GC6GD']
# Item Sequence for idx 108: ['item_B00646MZHK', 'item_B00191WVF6', 'item_B073LSS9TJ', 'item_B00C8U7WQ0']
# Item Sequence for idx 109: ['item_B002YVSGA4', 'item_B001L8IIU4', 'item_B06XPNRNF6', 'item_B0779VVBXX']
# Item Sequence for idx 110: ['item_B006JB8TKC', 'item_B01DP0HYRS']
# Item Sequence for idx 111: ['item_B07PPDY2NS', 'item_B07SG2SGZ5', 'item_B010DEZB6U']
# Item Sequence for idx 112: ['item_B015DQ13EM', 'item_B0002J1PNK']
# Item Sequence for idx 113: ['item_B000L6GD04', 'item_B00HG29EYI', 'item_B009MIBIWK', 'item_B016K188UQ']
# Item Sequence for idx 114: ['item_B003LPTAYI', 'item_B003LTJ404', 'item_B005ZFIWAA']
# Item Sequence for idx 115: ['item_B0002F4YRS', 'item_B00T8L27ZI']
# Item Sequence for idx 116: ['item_B07QY2Q7N4', 'item_B00KIZROW4']
# Item Sequence for idx 117: ['item_B003H6ZBI0', 'item_B007B8PZP4', 'item_B004F658Y8', 'item_B007BXI4WU']
# Item Sequence for idx 118: ['item_B07L61LX19', 'item_B07X9SD5JR']
# Item Sequence for idx 119: ['item_B005LUQD28', 'item_B00J44LP6G']
# Item Sequence for idx 120: ['item_B0BFGZVYK1', 'item_B0BDFN1T55', 'item_B0BJ1QHTD3']
# Item Sequence for idx 121: ['item_B019JD0XZ0', 'item_B075P1H3W1']
# Item Sequence for idx 122: ['item_B002WYF1SS', 'item_B00COPKOUK', 'item_B00PUYTERQ', 'item_B010W6W8OW']
# Item Sequence for idx 123: ['item_B074VBHQP6', 'item_B00OAHNA10']
# Item Sequence for idx 124: ['item_B0002L52QY', 'item_B00IPTTWXO']
# Item Sequence for idx 125: ['item_B00309XFEG', 'item_B000Z38F4A', 'item_B09N6J6Q3Q']
# Item Sequence for idx 126: ['item_B000SJJCX4', 'item_B01CEULF20', 'item_B00USQY0CK', 'item_B00R15F6I8']
# Item Sequence for idx 127: ['item_B00QW2N8H2', 'item_B001UJIYIK']
# Item Sequence for idx 128: ['item_B01MSCTIB5', 'item_B01N7XLQCB']
# Item Sequence for idx 129: ['item_B00CBJORJS', 'item_B0083FTVB8', 'item_B07T1FZZLH']
# Item Sequence for idx 130: ['item_B00MO6KKSK', 'item_B01LW1AHYA', 'item_B000EENC5W', 'item_B005EU6KYG']
# Item Sequence for idx 131: ['item_B00BL6J6ZC', 'item_B01HBEAXYA']
# Item Sequence for idx 132: ['item_B01FDM2OWG', 'item_B00BVH7C66', 'item_B08R3GZ6Z4']
# Item Sequence for idx 133: ['item_B0027M30Z6', 'item_B005QIZIYO', 'item_B008CPMAY4', 'item_B000B6DHB2']
# Item Sequence for idx 134: ['item_B00FLXNM9M', 'item_B01H3D0LFK', 'item_B09CPFZN2S', 'item_B09B21KWZV']
# Item Sequence for idx 135: ['item_B00JA4T6MU', 'item_B01IWQ865Y', 'item_B07N29M92M']
# Item Sequence for idx 136: ['item_B00GD865JI', 'item_B003QTM9O2', 'item_B003VWJ2K8', 'item_B08R3GZ6Z4']
# Item Sequence for idx 137: ['item_B004UIFXRI', 'item_B000EELBQ4', 'item_B000EENCQQ']
# Item Sequence for idx 138: ['item_B0015MCGG8', 'item_B07L8DT8WC', 'item_B00CXSJUZS']
# Item Sequence for idx 139: ['item_B001P3XFTE', 'item_B001EOXCOW']
# Item Sequence for idx 140: ['item_B0106BXNIS', 'item_B0002IJD76']
# Item Sequence for idx 141: ['item_B00I3OZO7E', 'item_B00646MZHK', 'item_B01AN3G93K', 'item_B003TLSN74']
# Item Sequence for idx 142: ['item_B000CEMQVK', 'item_B0002F741Q', 'item_B002IC1D5E', 'item_B0037GRGGU']
# Item Sequence for idx 143: ['item_B08JGDN2V2', 'item_B0719CBYXJ', 'item_B001PGXKC8', 'item_B00191WVF6']
# Item Sequence for idx 144: ['item_B00B6KMDU8', 'item_B005HZYZWW', 'item_B00L6C8PN0', 'item_B00DU66WVM']
# Item Sequence for idx 145: ['item_B001AIQGUO', 'item_B00DY1F2CS']
# Item Sequence for idx 146: ['item_B06XGTN6S6', 'item_B08DLJ676B']
# Item Sequence for idx 147: ['item_B005MR6IHK', 'item_B004U1QDL0', 'item_B000UJFR4A', 'item_B0002KZDHI']
# Item Sequence for idx 148: ['item_B0002E1G5C', 'item_B00FJEJLS4', 'item_B00LIO8PK4', 'item_B07KXQ7NP4']
# Item Sequence for idx 149: ['item_B00B5LDMH6', 'item_B01M8HTFEG']
# Item Sequence for idx 150: ['item_B003VWJ2K8', 'item_B0002E1G5C', 'item_B000WGJ71U', 'item_B005OZE9SA']
# Item Sequence for idx 151: ['item_B000WGJ71U', 'item_B005OZE9SA', 'item_B0001ARCFA']
# Item Sequence for idx 152: ['item_B0859T6YFL', 'item_B0002GOK08', 'item_B08NXJDB5N']
# Item Sequence for idx 153: ['item_B01INX2HUQ', 'item_B00XKVPB6E']
# Item Sequence for idx 154: ['item_B072L1WPG4', 'item_B007EN87HO']
# Item Sequence for idx 155: ['item_B01ITCNWC8', 'item_B0B7JH1Q56']
# Item Sequence for idx 156: ['item_B006GXZHBW', 'item_B002PAW6AU', 'item_B001ANI6VQ']
# Item Sequence for idx 157: ['item_B005DM7G84', 'item_B0002CZYW0', 'item_B001CCOQHI', 'item_B005JPWNVU']
# Item Sequence for idx 158: ['item_B00AQBT3GU', 'item_B07NSND3FJ', 'item_B000EEJ91I', 'item_B000N4YTVY']
# Item Sequence for idx 159: ['item_B07THFT3QS', 'item_B079HWSY8H', 'item_B07HM16JZB', 'item_B001OI8VEO']
# Item Sequence for idx 160: ['item_B07H17FF48', 'item_B018FCZKR2', 'item_B07VHFGCM8', 'item_B01IV3DK8G']
# Item Sequence for idx 161: ['item_B007R0ORR8', 'item_B0054KC8YW']
# Item Sequence for idx 162: ['item_B00BKXN9LS', 'item_B072XHV913']
# Item Sequence for idx 163: ['item_B07L5B64RG', 'item_B07WJLCHG4', 'item_B075945TB5', 'item_B00ZR77GN0']
# Item Sequence for idx 164: ['item_B07FLWN6G4', 'item_B07F7JWBGT']
# Item Sequence for idx 165: ['item_B083FY91JP', 'item_B083FY91JP', 'item_B08RDMV1LK', 'item_B08RDMV1LK']
# Item Sequence for idx 166: ['item_B003FXO8MK', 'item_B07FF7Q53V', 'item_B075B5QSSL']
# Item Sequence for idx 167: ['item_B004XNK7AI', 'item_B01H74YV56', 'item_B07KJ1MVZH', 'item_B0002E1O7W']
# Item Sequence for idx 168: ['item_B07KJ1MVZH', 'item_B0002E1O7W']
# Item Sequence for idx 169: ['item_B00JA4T77E', 'item_B00JA4T6RU', 'item_B00TZ8WSP8', 'item_B00DMACALC']
# Item Sequence for idx 170: ['item_B000KW2YEI', 'item_B0002BG2S6', 'item_B07RLZYXZL', 'item_B07212H9P8']
# Item Sequence for idx 171: ['item_B00191WVF6', 'item_B0002E3DLM']
# Item Sequence for idx 172: ['item_B001IFZF06', 'item_B0002D0MOE', 'item_B0723G9R4D', 'item_B07567KDJM']
# Item Sequence for idx 173: ['item_B071GTNM6D', 'item_B08KS6GY51', 'item_B083ZW9TBT', 'item_B011KX7ERC']
# Item Sequence for idx 174: ['item_B083ZW9TBT', 'item_B011KX7ERC']
# Item Sequence for idx 175: ['item_B081T7Q2PY', 'item_B07CXLFMLY']
# Item Sequence for idx 176: ['item_B0002D0H80', 'item_B000A2HDXA', 'item_B009GUP7U8']
# Item Sequence for idx 177: ['item_B008FLSNCI', 'item_B01G2AIHTC']
# Item Sequence for idx 178: ['item_B0002E1P08', 'item_B0020M1VOK']
# Item Sequence for idx 179: ['item_B07719XHZH', 'item_B073S78V3Q']
# Item Sequence for idx 180: ['item_B074T6JFPB', 'item_B09DW4FQZD', 'item_B00DV9HENS']
# Item Sequence for idx 181: ['item_B000MWWT6E', 'item_B0002GX7XY', 'item_B0006Z4B68', 'item_B000IVFP5G']
# Item Sequence for idx 182: ['item_B085XRGSWV', 'item_B088NCB1DR']
# Item Sequence for idx 183: ['item_B000EE8YPK', 'item_B000BO83GI', 'item_B0009JQCAE', 'item_B018YFJ72O']
# Item Sequence for idx 184: ['item_B0002KZIUU', 'item_B0046VEF14', 'item_B002HFFIIK', 'item_B0039HD3P0']
# Item Sequence for idx 185: ['item_B004XNK7AI', 'item_B07KJHSHF5']
# Item Sequence for idx 186: ['item_B001SQAC1M', 'item_B001UC73M0', 'item_B0064RZ0IA']
# Item Sequence for idx 187: ['item_B001EL6I8W', 'item_B003LPTAYI', 'item_B008YDTVW8']
# Item Sequence for idx 188: ['item_B003CLIPHO', 'item_B00JIKFLLG', 'item_B01JTOK5DE']
# Item Sequence for idx 189: ['item_B00QHURUBE', 'item_B00SKJHD30', 'item_B08M45Y4VZ', 'item_B08M42Z1P8']
# Item Sequence for idx 190: ['item_B0037M4CPM', 'item_B003LPTAYI']
# Item Sequence for idx 191: ['item_B001FB5Z1C', 'item_B0002H0KG0']
# Item Sequence for idx 192: ['item_B002MAMCIE', 'item_B0002D0DVQ']
# Item Sequence for idx 193: ['item_B0B6QPKHM6', 'item_B0B8D87G68', 'item_B0B68TZJ93', 'item_B0BQ2ZB5JX']
# Item Sequence for idx 194: ['item_B00KMF11BA', 'item_B01I0KB89I', 'item_B00N4ZHPZ6', 'item_B003B067YE']
# Item Sequence for idx 195: ['item_B0009R5NF6', 'item_B0009R3I8A', 'item_B0002E1O2M', 'item_B004IJE6PO']
# Item Sequence for idx 196: ['item_B00TVFYE2U', 'item_B0795X4FL4', 'item_B0002GZOQC', 'item_B000B6DUB4']
# Item Sequence for idx 197: ['item_B000Y08846', 'item_B0002D0COE', 'item_B01GZKE6QW']
# Item Sequence for idx 198: ['item_B000G16GZ6', 'item_B07B4J94QD']
# Item Sequence for idx 199: ['item_B07FCGNMXL', 'item_B07ZPBFVKK', 'item_B00BPELU68']
# Item Sequence for idx 200: ['item_B00JAFTG0G', 'item_B00275G7BC', 'item_B07MZPR5GP']
# Item Sequence for idx 201: ['item_B00K3O5H1K', 'item_B07ZCJJKRG']
# Item Sequence for idx 202: ['item_B002B55U1Q', 'item_B074R8BXB5']
# Item Sequence for idx 203: ['item_B06ZYCSYFK', 'item_B07RG4GY91', 'item_B08GLQ3B26', 'item_B01HR9YEFI']
# Item Sequence for idx 204: ['item_B001HNE622', 'item_B07YLJFN6L']
# Item Sequence for idx 205: ['item_B06XBYHCM6', 'item_B00XS7YEEK', 'item_B01LZBHHC2']
# Item Sequence for idx 206: ['item_B005SUVENO', 'item_B000EEL6B4', 'item_B00BHJNC4E']
# Item Sequence for idx 207: ['item_B009MBT68U', 'item_B0006M59M6']
# Item Sequence for idx 208: ['item_B08ZCC3QYC', 'item_B08F8HL7T7']
# Item Sequence for idx 209: ['item_B00027OCXM', 'item_B003S3S0DU']
# Item Sequence for idx 210: ['item_B005OEBVYQ', 'item_B00ZO7ANJM', 'item_B00EB11OHC']
# Item Sequence for idx 211: ['item_B0002F73Z8', 'item_B07T14WDJF']
# Item Sequence for idx 212: ['item_B0044CSVRE', 'item_B004INGEB4', 'item_B003LPTAYI']
# Item Sequence for idx 213: ['item_B00NAU1N0I', 'item_B00L4KT3RQ', 'item_B01N7IJB66', 'item_B07JZYKF7P']
# Item Sequence for idx 214: ['item_B07L954JDG', 'item_B094NG7561']
# Item Sequence for idx 215: ['item_B01IEXGZAI', 'item_B07TT2D4RR', 'item_B07CQNMHR1']
# Item Sequence for idx 216: ['item_B0002FOBJY', 'item_B078C5HCVP']
# Item Sequence for idx 217: ['item_B0002E51TO', 'item_B00DY1F2CS', 'item_B07BRPM8K8', 'item_B0006NDF76']
# Item Sequence for idx 218: ['item_B005J7B2EW', 'item_B00MXUI9BM', 'item_B00TQZLD3I', 'item_B004Z17008']
# Item Sequence for idx 219: ['item_B00CMRS5XI', 'item_B00646MZHK', 'item_B01H74YY62', 'item_B07HL1H9JY']
# Item Sequence for idx 220: ['item_B0002EKAA4', 'item_B0013N3VWM']
# Item Sequence for idx 221: ['item_B00O4L3F9E', 'item_B0027OPLCE', 'item_B0027OXW4I']
# Item Sequence for idx 222: ['item_B000XPUKB6', 'item_B000UJE33Q', 'item_B011BAQLAU', 'item_B0002FOBJY']
# Item Sequence for idx 223: ['item_B008FKNVVW', 'item_B00PKP3EG2', 'item_B085NS8FN4', 'item_B07YK61YM6']
# Item Sequence for idx 224: ['item_B07F6W4FS4', 'item_B01JJXDPJG']
# Item Sequence for idx 225: ['item_B000RVX1QW', 'item_B003DASCH2', 'item_B087ZN53D4']
# Item Sequence for idx 226: ['item_B008DSBGH2', 'item_B005IS4T6K']
# Item Sequence for idx 227: ['item_B00N2MIUX2', 'item_B01BMM2BJM', 'item_B09YRQ8TX8']
# Item Sequence for idx 228: ['item_B012V15YD8', 'item_B00ISKJJ5Q']
# Item Sequence for idx 229: ['item_B077GKMZTK', 'item_B07ZRWR5CV', 'item_B08LQCVBWM']
# Item Sequence for idx 230: ['item_B005RTUSJC', 'item_B0018BSBZQ']
# Item Sequence for idx 231: ['item_B0002PYXA6', 'item_B00ET5SWKW', 'item_B00LU8K790', 'item_B00UN8OXWA']
# Item Sequence for idx 232: ['item_B00LU8K790', 'item_B00UN8OXWA']
# Item Sequence for idx 233: ['item_B000P5NXW2', 'item_B0018R6AGM', 'item_B005WJU0LI', 'item_B00I3XGBZ4']
# Item Sequence for idx 234: ['item_B003AYK4F4', 'item_B00I3XGB4K', 'item_B001J6THXU', 'item_B000XZV9R0']
# Item Sequence for idx 235: ['item_B01K601WBE', 'item_B07VY2TCSS', 'item_B06ZZ65P1T', 'item_B09BR8RTLQ']
# Item Sequence for idx 236: ['item_B000A6GY1I', 'item_B0002D0CGW', 'item_B005SUTAF8', 'item_B008B0YYI0']
# Item Sequence for idx 237: ['item_B003AYRUSI', 'item_B001FB5Z8K', 'item_B000EEL920', 'item_B0002GYMBA']
# Item Sequence for idx 238: ['item_B0002E2930', 'item_B0007WPCKE', 'item_B0002F52EW', 'item_B000GUR8V8']
# Item Sequence for idx 239: ['item_B00191WVF6', 'item_B000RLK84U', 'item_1423414357', 'item_B074CP5NSK']
# Item Sequence for idx 240: ['item_1423414357', 'item_B074CP5NSK']
# Item Sequence for idx 241: ['item_B007Z1FVZG', 'item_B000EEHEW4', 'item_B00WHLLDWO', 'item_B00CTKI5QA']
# Item Sequence for idx 242: ['item_B0056XUCJU', 'item_B079RRB5M8']
# Item Sequence for idx 243: ['item_B00HWIRQ6O', 'item_B018FCZKR2']
# Item Sequence for idx 244: ['item_B00AQE2CDS', 'item_B00XQCYRPI', 'item_B00W7ZL4TM']
# Item Sequence for idx 245: ['item_B01NBMOVYS', 'item_B001RIY5NC', 'item_B007SQZJTQ', 'item_B0036ECH1M']
# Item Sequence for idx 246: ['item_B0006GEYX2', 'item_B0007L8BQW', 'item_B000JLU26W', 'item_B000068NTZ']
# Item Sequence for idx 247: ['item_B00OBV0KEU', 'item_B00C7AFDVM', 'item_B00191WVF6']
# Item Sequence for idx 248: ['item_B08DK9SYXV', 'item_B09FQGGRSQ', 'item_B00VBH7TL4']
# Item Sequence for idx 249: ['item_B077693MLX', 'item_B075DN9C7M', 'item_B000NB2D7O']
# Item Sequence for idx 250: ['item_B00PB34DSG', 'item_B00NP80XMO']
# Item Sequence for idx 251: ['item_B0083EFDMU', 'item_B0083EHORC', 'item_B00B5LDMH6', 'item_B0002CZVXM']
# Item Sequence for idx 252: ['item_B00CKYVW2O', 'item_B001PGXKC8', 'item_B006HY8FFK', 'item_B0002CZZGA']
# Item Sequence for idx 253: ['item_B00F20MIC6', 'item_B0002GZBO2', 'item_B00IMR9FKE', 'item_B00E1CSI02']
# Item Sequence for idx 254: ['item_B00IMR9FKE', 'item_B00E1CSI02', 'item_B073B2XLLF', 'item_B019WTLVKW']
# Item Sequence for idx 255: ['item_B00JZEW3KC', 'item_B01512W26Q', 'item_B0049B3YXQ', 'item_B01M1F77G1']
# Item Sequence for idx 256: ['item_B0007OGTGS', 'item_B000KW2YEI', 'item_B08D8TKQ41']
# Item Sequence for idx 257: ['item_B01LQM3534', 'item_B0002GJEN6']
# Item Sequence for idx 258: ['item_B0009FUUOM', 'item_B00HWL9MZO']
# Item Sequence for idx 259: ['item_B000EGFRQ2', 'item_B07766LQ5J']
# Item Sequence for idx 260: ['item_B004THBT64', 'item_B00HVNTO5Q']
# Item Sequence for idx 261: ['item_B0002ZPK0S', 'item_B00GME4M2A']
# Item Sequence for idx 262: ['item_B01JM0WD3U', 'item_B01H31ITWE', 'item_B0006ZXFWO', 'item_B010W6XHRO']
# Item Sequence for idx 263: ['item_B007N9XPN0', 'item_B07F3P9NKX']
# Item Sequence for idx 264: ['item_B00M9CUL60', 'item_B000FFNDQI']
# Item Sequence for idx 265: ['item_B004U9S914', 'item_B0046HE9DW', 'item_B000F3HK78', 'item_0793533929']
# Item Sequence for idx 266: ['item_B018VOLWCG', 'item_B00TDU2IA8', 'item_B009GUP7U8']
# Item Sequence for idx 267: ['item_B0002MTGVU', 'item_B07DCWF2YL']
# Item Sequence for idx 268: ['item_B0002E2ACK', 'item_B0002DV6J4']
# Item Sequence for idx 269: ['item_B0002PZEGS', 'item_B00CAUYNCO', 'item_B0002ORPM0', 'item_B0002IHFVM']
# Item Sequence for idx 270: ['item_B002VA464S', 'item_B002VA464S', 'item_B00UI79AZG']
# Item Sequence for idx 271: ['item_B016APP6NO', 'item_B00JBQ11ES']
# Item Sequence for idx 272: ['item_B0002D00QE', 'item_B00BL6JDUA', 'item_B07H1RZJWK']
# Item Sequence for idx 273: ['item_B092PVG9BZ', 'item_B095W72BBQ', 'item_B08NJRKHSB', 'item_B095BQC9P3']
# Item Sequence for idx 274: ['item_B08XLQQS5N', 'item_B0932GPVP8', 'item_B095JSMZFL', 'item_B09C13RLZX']
# Item Sequence for idx 275: ['item_B095JSMZFL', 'item_B09C13RLZX', 'item_1739130405']
# Item Sequence for idx 276: ['item_B003VZG550', 'item_B073KZXDX5', 'item_B08GKXLHY1', 'item_B08BJ37FNS']
# Item Sequence for idx 277: ['item_B0002E1G5C', 'item_B071YBYRHN']
# Item Sequence for idx 278: ['item_B005DBEAM0', 'item_B003VWJ2K8', 'item_B015HM2D4Q', 'item_B012D1GYU8']
# Item Sequence for idx 279: ['item_B015HM2D4Q', 'item_B012D1GYU8', 'item_B00E87OLBU', 'item_B07YDPKKWH']
# Item Sequence for idx 280: ['item_B00HXE4BYW', 'item_B00HBN6T1I']
# Item Sequence for idx 281: ['item_B000EEJ74M', 'item_B000EENANG', 'item_B0072IPUTY']
# Item Sequence for idx 282: ['item_B018FCZKR2', 'item_B07HCYXKWP', 'item_B003BFZJZM']
# Item Sequence for idx 283: ['item_B08LZKP3M9', 'item_B071L66DD8', 'item_B07SPVSPM7']
# Item Sequence for idx 284: ['item_B00P7X6CNE', 'item_B0026R55IM', 'item_B002UKZ88W', 'item_B002G1UT4S']
# Item Sequence for idx 285: ['item_B006X0TBLA', 'item_B00NSET6UA', 'item_B01H74YV56', 'item_B00Z6J0C30']
# Item Sequence for idx 286: ['item_B01H74YV56', 'item_B00Z6J0C30']
# Item Sequence for idx 287: ['item_B07871TBJJ', 'item_B00V3A61DG', 'item_B00MO6KKSK', 'item_B08ND1TY4Z']
# Item Sequence for idx 288: ['item_B06XV3388Z', 'item_B06XF6NF5Y']
# Item Sequence for idx 289: ['item_B000K2GBK6', 'item_B006JCF0E4']
# Item Sequence for idx 290: ['item_B01GQ555YS', 'item_B00L1LL7DQ']
# Item Sequence for idx 291: ['item_B07VVG51QT', 'item_B07FD2PGYV', 'item_B018Z5BXOS', 'item_B07F82BPLV']
# Item Sequence for idx 292: ['item_B00CE203MC', 'item_B019RY7RUU', 'item_B07XLHX5RC', 'item_B08H7VNWC7']
# Item Sequence for idx 293: ['item_B074PQ6QWN', 'item_B07TYRQ222']
# Item Sequence for idx 294: ['item_B07NTZ6MNL', 'item_B07SPTLBFC']
# Item Sequence for idx 295: ['item_B00V3A5SDA', 'item_B012I5BCRO']
# Item Sequence for idx 296: ['item_B003USGRSI', 'item_B07WHWC632', 'item_B08BHKV441']
# Item Sequence for idx 297: ['item_B005I2YJKC', 'item_B000E0PPG0', 'item_B003P13RRO', 'item_B00GNPIJAE']
# Item Sequence for idx 298: ['item_B007MWXE02', 'item_B0002J6I7S', 'item_B0002F741Q']
# Item Sequence for idx 299: ['item_B07S592DKV', 'item_B0051Y0S6Q', 'item_B07PNF5WJK', 'item_B00GGOJGS6']
# Item Sequence for idx 300: ['item_B07PNF5WJK', 'item_B00GGOJGS6']
# Item Sequence for idx 301: ['item_B003LPTAYI', 'item_B004XNK7AI']
# Item Sequence for idx 302: ['item_B074VHGX9R', 'item_B001BAMO5W', 'item_B00EAH2W1Y']
# Item Sequence for idx 303: ['item_B01LOJMZ3K', 'item_B000A0C0X0']
# Item Sequence for idx 304: ['item_B00A2DBHMA', 'item_B002CM3I08']
# Item Sequence for idx 305: ['item_B002JCSOZU', 'item_B007T8CUNG', 'item_B00IZCSW3M', 'item_B005M0CK9M']
# Item Sequence for idx 306: ['item_B00IZCSW3M', 'item_B005M0CK9M', 'item_B072VPW9NR', 'item_B012F2AWMQ']
# Item Sequence for idx 307: ['item_B07K8FQFN8', 'item_B086PG669X', 'item_B0009G00IW', 'item_B0002CZUCO']
# Item Sequence for idx 308: ['item_B07BQVWHV3', 'item_B0006H92QK']
# Item Sequence for idx 309: ['item_B00E3VRHYO', 'item_B00OJX7UCA', 'item_B0002E1O2C', 'item_B00DY1F2CS']
# Item Sequence for idx 310: ['item_B0000775G0', 'item_B08MZG6DG3']
# Item Sequence for idx 311: ['item_B002026DR0', 'item_B00AG6XV5E', 'item_B001QTUDS8']
# Item Sequence for idx 312: ['item_B000MXJIL2', 'item_B00CFP5ESG', 'item_B000G0ATGE', 'item_B000068O3Y']
# Item Sequence for idx 313: ['item_B000G0ATGE', 'item_B000068O3Y', 'item_B002HF45Q6']
# Item Sequence for idx 314: ['item_B01MXTCVFL', 'item_B00GP3Q65Y']
# Item Sequence for idx 315: ['item_B0002F5HBK', 'item_B08HX9KFHS', 'item_B08HX9MMGL', 'item_B08JB48P4M']
# Item Sequence for idx 316: ['item_B000VTPR08', 'item_B00F58ZEFS']
# Item Sequence for idx 317: ['item_B004TVJL1U', 'item_B00KO8VZN4']
# Item Sequence for idx 318: ['item_B0197WU6I2', 'item_B07L9HJHM2', 'item_B07FMRQVPN', 'item_B0002H0SX0']
# Item Sequence for idx 319: ['item_B0002MSINW', 'item_B07VN5ZVWV']
# Item Sequence for idx 320: ['item_B000A39GTI', 'item_B016VWTOKC', 'item_B076YDYYJ3', 'item_B0736PCHTQ']
# Item Sequence for idx 321: ['item_B076YDYYJ3', 'item_B0736PCHTQ', 'item_B07SPBLNB8', 'item_B07WR87CGL']
# Item Sequence for idx 322: ['item_B003USDT1G', 'item_B08PNYPWB2', 'item_B08XY79MGQ', 'item_B095WXP5VD']
# Item Sequence for idx 323: ['item_B096KFLYSZ', 'item_B092PNZJT5', 'item_B09NR2GPHZ']
# Item Sequence for idx 324: ['item_B0002F5BKW', 'item_B08H5CC5Z2']
# Item Sequence for idx 325: ['item_B009US97AM', 'item_B00WZQSHNY', 'item_B00B5LDMH6', 'item_B0002D01K4']
# Item Sequence for idx 326: ['item_B00B5LDMH6', 'item_B0002D01K4']
# Item Sequence for idx 327: ['item_B0B75L7V9V', 'item_B0BFGK9K6H', 'item_B0BLNGZG8S', 'item_B09LMSFXGS']
# Item Sequence for idx 328: ['item_B06WVFRW4H', 'item_B0023BYDHK', 'item_B074KG3QWG', 'item_B0795PNCBG']
# Item Sequence for idx 329: ['item_B00I056PII', 'item_B000EEL920', 'item_B00C78WF74', 'item_B00I8QJVL2']
# Item Sequence for idx 330: ['item_B00U0UUUX2', 'item_B0009QYQD2', 'item_B00R6OX988', 'item_B0045HFDOC']
# Item Sequence for idx 331: ['item_B07XH5LX25', 'item_B09V2RHF96']
# Item Sequence for idx 332: ['item_B000UJHXPG', 'item_B003LWD6JQ', 'item_B004OK17QS']
# Item Sequence for idx 333: ['item_B07R8PMQ5X', 'item_B09JZL31PX', 'item_B00GJRHQGY']
# Item Sequence for idx 334: ['item_B000Y01UXM', 'item_B0016MNAAI', 'item_B097STBDPR']
# Item Sequence for idx 335: ['item_B00DDTYN1C', 'item_B08T17YLXN']
# Item Sequence for idx 336: ['item_B00K39U17U', 'item_B0016ML1C2', 'item_B005LVJRIE', 'item_B00U43T1KI']
# Item Sequence for idx 337: ['item_B018FCZKR2', 'item_B00TTQM8Z6', 'item_B074VRW7PP']
# Item Sequence for idx 338: ['item_B0143H0W3U', 'item_B073RNNWJZ']
# Item Sequence for idx 339: ['item_B0002GLCRC', 'item_B003WZ4P6K']
# Item Sequence for idx 340: ['item_B07J5Q4P38', 'item_B07WJFM2RK']
# Item Sequence for idx 341: ['item_B07JMP2MFN', 'item_B00O4L3F9E']
# Item Sequence for idx 342: ['item_B000EJODGE', 'item_B00HMD0TK4']
# Item Sequence for idx 343: ['item_B09CT1W56H', 'item_B000OY0KWA']
# Item Sequence for idx 344: ['item_B000EEL4YI', 'item_B0042SR4IW', 'item_B006GFFPLM', 'item_B004SL34IM']
# Item Sequence for idx 345: ['item_B07GG18DVZ', 'item_B07SQGS2RZ', 'item_B00YB91G40', 'item_B073ZZ3M8J']
# Item Sequence for idx 346: ['item_B0000775G0', 'item_B07WHCTF23']
# Item Sequence for idx 347: ['item_B002VCX11A', 'item_B0836YZHCG', 'item_B092H5PTFR', 'item_B08CZNJ9VY']
# Item Sequence for idx 348: ['item_B000EELFTW', 'item_B000OR2RNM']
# Item Sequence for idx 349: ['item_B00IN2WFB4', 'item_B006GVLT3Y']
# Item Sequence for idx 350: ['item_B07TC4SWT2', 'item_B0002M6BD6']
# Item Sequence for idx 351: ['item_B00FGG3OLA', 'item_B00VUR0GQU']
# Item Sequence for idx 352: ['item_B01IKHMTHQ', 'item_B0002M6B2M']
# Item Sequence for idx 353: ['item_B07T9NM5QR', 'item_B0002ZPLDY']
# Item Sequence for idx 354: ['item_B01LB3T45G', 'item_B01G0QLK2E', 'item_B0002D0CAI', 'item_B0037M4EG4']
# Item Sequence for idx 355: ['item_B00DV9HENS', 'item_B01LTI0IX0', 'item_B08PY14Q3D', 'item_B088X2DBL7']
# Item Sequence for idx 356: ['item_B00646MZHK', 'item_B000VJJQUU', 'item_B00RZYYYPG', 'item_B0002E1NOG']
# Item Sequence for idx 357: ['item_B00RZYYYPG', 'item_B0002E1NOG', 'item_B07GKB1WP2', 'item_B00SVRLPYY']
# Item Sequence for idx 358: ['item_B001PGXHXA', 'item_B085NZH6QN', 'item_B01LY6Z2M6', 'item_B06XX8NCKF']
# Item Sequence for idx 359: ['item_B019WTLVKW', 'item_B00LTDOH4M']
# Item Sequence for idx 360: ['item_B012F2ALAE', 'item_B06XF9BNHN', 'item_B00BBU036Y', 'item_B005N5USYU']
# Item Sequence for idx 361: ['item_B0002H0F5Q', 'item_B001W99HE8', 'item_B000XTHHLI', 'item_B00GS41CHW']
# Item Sequence for idx 362: ['item_B00PHVGGMI', 'item_B07R5HB9H3']
# Item Sequence for idx 363: ['item_B00TJ2FKZK', 'item_B000068O3T']
# Item Sequence for idx 364: ['item_B0002CZVXM', 'item_B002UXS4JO', 'item_B004XNK7AI', 'item_B00IJYE0SM']
# Item Sequence for idx 365: ['item_B004XNK7AI', 'item_B00IJYE0SM', 'item_B001OSW9LA', 'item_B012VQ5A7S']
# Item Sequence for idx 366: ['item_B01H2UAAN2', 'item_B072LDG76G']
# Item Sequence for idx 367: ['item_B00JA4T7QK', 'item_B089SQN2WF']
# Item Sequence for idx 368: ['item_B00724Y5R6', 'item_B0002M72JS']
# Item Sequence for idx 369: ['item_B07MVYF7WK', 'item_B06Y1XD9H7']
# Item Sequence for idx 370: ['item_B000068O4D', 'item_B000EENB2Q', 'item_B0026RJC3Q', 'item_B003B135J8']
# Item Sequence for idx 371: ['item_B07362JV2B', 'item_B01K6HBCE4', 'item_B017C14QRC', 'item_B003P4XDP2']
# Item Sequence for idx 372: ['item_B017C14QRC', 'item_B003P4XDP2', 'item_B0002F7L9Q', 'item_B078HQLGHN']
# Item Sequence for idx 373: ['item_B008NCVSU8', 'item_B00F5EDK1M', 'item_B0002GZLZQ', 'item_B005CQ99MC']
# Item Sequence for idx 374: ['item_B000GEAR08', 'item_B000EEHLFE', 'item_B0002CZVWI']
# Item Sequence for idx 375: ['item_B01MSDE4DO', 'item_B08F25QVDR', 'item_B07R2MGYJW', 'item_B01M9FB6IJ']
# Item Sequence for idx 376: ['item_B0002D0O8I', 'item_B00ECHAN36', 'item_B0002F6ONK', 'item_B0002EWZLQ']
# Item Sequence for idx 377: ['item_B0002E1VZM', 'item_B0039RWELE', 'item_B0002E3AHE', 'item_B0007Y2ZSE']
# Item Sequence for idx 378: ['item_B00NCBBTCW', 'item_B01CR68YJS', 'item_B003VWJ2K8']
# Item Sequence for idx 379: ['item_B0006NDF8A', 'item_B00PHVGGMI', 'item_B07LBDYLBD']
# Item Sequence for idx 380: ['item_B0932BCM2T', 'item_B09F5T2FGT', 'item_B093DPZKYL', 'item_B08HND2C86']
# Item Sequence for idx 381: ['item_B0002BACAA', 'item_B008TNAGQS', 'item_B003H959F2', 'item_B00845J1QC']
# Item Sequence for idx 382: ['item_B0002EJVL8', 'item_B00B4GSB14', 'item_B00RZYYYPG', 'item_B00JQYUAQU']
# Item Sequence for idx 383: ['item_B000PTRJUK', 'item_B07TWWVCWN', 'item_B01MZ99Y67', 'item_B07WGQSDGL']
# Item Sequence for idx 384: ['item_B004SURUB0', 'item_B00379WMO8', 'item_B01LY5Y6AJ', 'item_B07S5H8WVN']
# Item Sequence for idx 385: ['item_B000G0ATGE', 'item_B000EEHKPU', 'item_B000FZZ0CI', 'item_B0002KZINM']
# Item Sequence for idx 386: ['item_B0098X01ZO', 'item_B000P5OUBU', 'item_B0002F79CU', 'item_B0009G1E0K']
# Item Sequence for idx 387: ['item_B0036FFKE2', 'item_B000EEHKVY', 'item_B001LU37C6', 'item_B00GXMNOXY']
# Item Sequence for idx 388: ['item_B00KZHMZ1K', 'item_B01IBI88R4']
# Item Sequence for idx 389: ['item_B004I5DAY6', 'item_B000EAKZJ2', 'item_B002TQSQOA']
# Item Sequence for idx 390: ['item_B008JCV3MU', 'item_B0002CZVU0', 'item_B000B6DHAS']
# Item Sequence for idx 391: ['item_B00WRHTGLI', 'item_B073QP48RV', 'item_B01HTMA69Q', 'item_B076HMR23G']
# Item Sequence for idx 392: ['item_B0002D0LBI', 'item_B01CKCWID2', 'item_B0076IMDQ8', 'item_B075MXWGCS']
# Item Sequence for idx 393: ['item_B07TXTJ9CN', 'item_B07GXGXPBY', 'item_B082MF6FKV', 'item_B0002GXSWE']
# Item Sequence for idx 394: ['item_B07VSP1CH5', 'item_B016JDJE9E', 'item_B07X223RNZ']
# Item Sequence for idx 395: ['item_B004THBKJA', 'item_B01MZ8S1G8', 'item_B0778VPJ4Y', 'item_B0002E1I4Q']
# Item Sequence for idx 396: ['item_B003VWKPHC', 'item_B0002FOBJY']
# Item Sequence for idx 397: ['item_B00IJ6QAO2', 'item_B07HH1GJ27']
# Item Sequence for idx 398: ['item_B071XDKD1G', 'item_B00N4Q25R8']
# Item Sequence for idx 399: ['item_B07XV5TC2G', 'item_B07TGXNDHJ']
# Item Sequence for idx 400: ['item_B0BGQR18TX', 'item_B09ZPFPLRB', 'item_B0BPSNRN5G']
# Item Sequence for idx 401: ['item_B0722VGTHJ', 'item_B074PD6TT2', 'item_B000AROQKI']
# Item Sequence for idx 402: ['item_B002RZCZ90', 'item_B077QYB796', 'item_B073LSS9TJ']
# Item Sequence for idx 403: ['item_B003WYCJFU', 'item_B000A87N66', 'item_B000T04GME', 'item_B0039RRJ82']
# Item Sequence for idx 404: ['item_B0019IV93O', 'item_B004FZ9QGK']
# Item Sequence for idx 405: ['item_B0040SXV90', 'item_B00O4L3F9E', 'item_B01DQHXEX8']
# Item Sequence for idx 406: ['item_B003BLOSI0', 'item_B004H1METI', 'item_B0002D0CGW']
# Item Sequence for idx 407: ['item_B00ATABRJE', 'item_B005ETZMXC', 'item_B000Z4M9NC', 'item_B0098F5IF0']
# Item Sequence for idx 408: ['item_B000Z4M9NC', 'item_B0098F5IF0', 'item_B0002CZSJY', 'item_B0027M30Z6']
# Item Sequence for idx 409: ['item_B00KH8XXGI', 'item_B083QMXM1D']
# Item Sequence for idx 410: ['item_B01IBI8F86', 'item_B08HV3P63M']
# Item Sequence for idx 411: ['item_B00XKVPB6E', 'item_B01J5A06OU']
# Item Sequence for idx 412: ['item_B015XD4YLY', 'item_B07BH651WW']
# Item Sequence for idx 413: ['item_B000P40JQG', 'item_B06XYTLVPN']
# Item Sequence for idx 414: ['item_B0096JYRY6', 'item_B008H51464']
# Item Sequence for idx 415: ['item_B01E6T56EA', 'item_B00C5B20QE']
# Item Sequence for idx 416: ['item_B01M69P2F6', 'item_B000P5YJ2K', 'item_B003LPTAYI']
# Item Sequence for idx 417: ['item_B0000775G0', 'item_B01AJJIQQQ', 'item_B07KJ3TD6W']
# Item Sequence for idx 418: ['item_B00080SEAU', 'item_B0002E2UUW', 'item_B0075DMYC2', 'item_B0087UPSMK']
# Item Sequence for idx 419: ['item_B000VJJQUU', 'item_B01H74YV56', 'item_B0046A04LU', 'item_B000XT3IFW']
# Item Sequence for idx 420: ['item_B004FPK7OA', 'item_B00VMB8IW8', 'item_B004MW5B8I', 'item_B001AWL0D8']
# Item Sequence for idx 421: ['item_B0002GZLZQ', 'item_B074SHZFTQ', 'item_B000T4SI1K', 'item_B07JLSGFVH']
# Item Sequence for idx 422: ['item_B07DTD546N', 'item_B07CFM8P6Q']
# Item Sequence for idx 423: ['item_B0002E2EOE', 'item_B0002D0E88', 'item_B0002D0DJI', 'item_B07PB3DJY4']
# Item Sequence for idx 424: ['item_B000GATTM4', 'item_B00UNPW18Q', 'item_B00J3YYSUW', 'item_B0725FV21W']
# Item Sequence for idx 425: ['item_B00TZS94AK', 'item_B06X1GL96W', 'item_B07MZP3N5C', 'item_B08LQPSRGN']
# Item Sequence for idx 426: ['item_B07MZP3N5C', 'item_B08LQPSRGN', 'item_B09T9WW4BD']
# Item Sequence for idx 427: ['item_B00HNVYUNW', 'item_B0002E3CJA', 'item_B00FFVLKJE', 'item_B00IPWOEJI']
# Item Sequence for idx 428: ['item_B00FFVLKJE', 'item_B00IPWOEJI', 'item_B00A2WZJDE', 'item_B00XKVPB6E']
# Item Sequence for idx 429: ['item_B075WPVK6S', 'item_B07DPGPRZ3', 'item_B0050F3YQM', 'item_B07QMH9F7Q']
# Item Sequence for idx 430: ['item_B004BA83ZO', 'item_B0002CZVVE', 'item_B00VMB7E0U', 'item_B00JQZS4HG']
# Item Sequence for idx 431: ['item_B07BMCTRPB', 'item_B07KFNST7G', 'item_B00ZU6PJCS']
# Item Sequence for idx 432: ['item_B06ZZCR6P4', 'item_B000068NYH', 'item_B07ZVHBFNJ', 'item_B07PFQGZV2']
# Item Sequence for idx 433: ['item_B009EGQY24', 'item_B0018SVNRC', 'item_B0008FUWEG']
# Item Sequence for idx 434: ['item_B00NIX97DM', 'item_B07V4SH5BD']
# Item Sequence for idx 435: ['item_B004EVO822', 'item_B0052S3RZU']
# Item Sequence for idx 436: ['item_B003VWKPHC', 'item_B007IHYBV2', 'item_B0009V8430']
# Item Sequence for idx 437: ['item_B018FCZKR2', 'item_B07L5B64RG', 'item_B088CWFVT8', 'item_B07W8T7ZRM']
# Item Sequence for idx 438: ['item_B0002D0JHE', 'item_B000CD1R84', 'item_B00UKBLGZC']
# Item Sequence for idx 439: ['item_B0002CZUV0', 'item_B000WF1AMU', 'item_B01DK723HW', 'item_B001J6SR2W']
# Item Sequence for idx 440: ['item_B075T13ZV4', 'item_B01BWM5DVA', 'item_B01MXPZWT0', 'item_B000B6H2R2']
# Item Sequence for idx 441: ['item_B00HXH2BNC', 'item_B00LMTWI58']
# Item Sequence for idx 442: ['item_B07VGKJNFT', 'item_B07WPCZ7P1', 'item_B087CZFBWW']
# Item Sequence for idx 443: ['item_B013TPYOUY', 'item_B07L4XKS15']
# Item Sequence for idx 444: ['item_B00FEX380M', 'item_B07GDTRK3Z', 'item_B0002GX8PQ', 'item_B07S8WR748']
# Item Sequence for idx 445: ['item_B08NLQGVXV', 'item_B015J5V7WK', 'item_B005GLL8PY', 'item_B07MZDZLFV']
# Item Sequence for idx 446: ['item_B01JNLTTKS', 'item_B007534LFK', 'item_B00I2J4V5G', 'item_B00OAHNA10']
# Item Sequence for idx 447: ['item_B07N28X3TF', 'item_B00GRRN2RI']
# Item Sequence for idx 448: ['item_B01KL9WLN8', 'item_B00OB48KSK', 'item_B001RNHCJQ', 'item_B001RNHBWO']
# Item Sequence for idx 449: ['item_B0051WAJ5S', 'item_B000BVN582', 'item_B00LI7CUYS', 'item_B00HWIRCEK']
# Item Sequence for idx 450: ['item_B01N5B7LKM', 'item_B00EM5UPUE', 'item_B01CR68YKM', 'item_B07KVJKP45']
# Item Sequence for idx 451: ['item_B01CR68YKM', 'item_B07KVJKP45', 'item_B00JDP3HMQ']
# Item Sequence for idx 452: ['item_B00JI540P4', 'item_B07RDJHRZD', 'item_B07Q38FWFJ']
# Item Sequence for idx 453: ['item_B001KNSSB4', 'item_B000P4FBQO', 'item_B016APU0RG']
# Item Sequence for idx 454: ['item_B00WU8QG26', 'item_B0002GZ052', 'item_B07F2ZZ3NT', 'item_B0117TLSZS']
# Item Sequence for idx 455: ['item_B078LZNHN9', 'item_B08NCNVCK6', 'item_B0052OTXCU', 'item_B07PKJXQY9']
# Item Sequence for idx 456: ['item_B075882X98', 'item_B00166B1O6', 'item_B0832SM75H']
# Item Sequence for idx 457: ['item_B0002LDFWW', 'item_B0002D0KCI', 'item_B00LCLG5XC', 'item_B004H1RY52']
# Item Sequence for idx 458: ['item_B001VIQFIQ', 'item_B0002E2PF2', 'item_B004Y07PUK', 'item_B01E5C4ZUE']
# Item Sequence for idx 459: ['item_B003VWJ2K8', 'item_B00WU6F4M6', 'item_B00D0E8EFQ']
# Item Sequence for idx 460: ['item_B00GR9W1MS', 'item_B000BK2UNO']
# Item Sequence for idx 461: ['item_B01LXOJZJ9', 'item_B00DY1F2CS']
# Item Sequence for idx 462: ['item_B00HQXUH5W', 'item_B0010D4OOY', 'item_B06XHNQF2C']
# Item Sequence for idx 463: ['item_B00TIY4E56', 'item_B00O9SV1XO', 'item_B001MW7UBC', 'item_B01GKZCSAS']
# Item Sequence for idx 464: ['item_B084ZCV4Z8', 'item_B002103CYS']
# Item Sequence for idx 465: ['item_B08M42WR5D', 'item_B01M68GLAB']
# Item Sequence for idx 466: ['item_B07DPC75YG', 'item_B011NSCTPG', 'item_B07HQG7YW6', 'item_B07R1351L7']
# Item Sequence for idx 467: ['item_B06XXQDQPZ', 'item_B078WN6L4Q', 'item_B06XK7WQK3', 'item_B01LX01HN9']
# Item Sequence for idx 468: ['item_B06XK7WQK3', 'item_B01LX01HN9', 'item_B0002H0KG0', 'item_B00A270MZO']
# Item Sequence for idx 469: ['item_B00IWU2CBA', 'item_B00AT9IVYO', 'item_B000LFCXL8', 'item_B01EA91TI8']
# Item Sequence for idx 470: ['item_B000LFCXL8', 'item_B01EA91TI8']
# Item Sequence for idx 471: ['item_B015TJBNSY', 'item_B004B4B11I']
# Item Sequence for idx 472: ['item_B008BPI2OW', 'item_B07PRH7BGM', 'item_B0088Q50BM', 'item_B07QVXX5VY']
# Item Sequence for idx 473: ['item_B0017I2CNM', 'item_B00172UV6S']
# Item Sequence for idx 474: ['item_B00347A44I', 'item_B000978D58']
# Item Sequence for idx 475: ['item_B00000J50W', 'item_B0002F7IEE']
# Item Sequence for idx 476: ['item_B0020288RI', 'item_B0006NDF6C']
# Item Sequence for idx 477: ['item_B00AAJJLE2', 'item_B003AYNHGW', 'item_B004UIDJ7Y']
# Item Sequence for idx 478: ['item_B000EENNP6', 'item_B015NBUUFU']
# Item Sequence for idx 479: ['item_B00OO0LD1C', 'item_B00721DN40', 'item_B084TSBMH3', 'item_B000G8BDAC']
# Item Sequence for idx 480: ['item_B0002CZT1G', 'item_B0010SHU18', 'item_B07G26WNBD', 'item_B00XX6YN4M']
# Item Sequence for idx 481: ['item_B01MSAOR2Z', 'item_B0002D0ELU', 'item_B0002D0EAG', 'item_B07Y87B9Z4']
# Item Sequence for idx 482: ['item_B07ZX7JYWJ', 'item_B08LX9764G', 'item_B0013NFZHQ', 'item_B000XXBHA6']
# Item Sequence for idx 483: ['item_B092VKYPT6', 'item_B07S24RXC3', 'item_B011A4IWKY', 'item_B0BGYHKL37']
# Item Sequence for idx 484: ['item_B000EEHCUS', 'item_B000A6EUSC', 'item_B00EQ28NF2', 'item_B01J9FQ1BI']
# Item Sequence for idx 485: ['item_B01MRDE7II', 'item_B07QP8Y7VV']
# Item Sequence for idx 486: ['item_B00MO6KKSK', 'item_B00GRPCRIA', 'item_B002EWV8IU', 'item_B004U1QDL0']
# Item Sequence for idx 487: ['item_B00XC2AQN4', 'item_B002OHE0A8', 'item_B07NDW6XRS', 'item_B08BZ518HD']
# Item Sequence for idx 488: ['item_B07GGXFVNN', 'item_B005FKF1PY']
# Item Sequence for idx 489: ['item_B000A6ASSS', 'item_B00BLJYWMQ', 'item_B0002E1O7W']
# Item Sequence for idx 490: ['item_B01KH6RP9K', 'item_B07NTYGB2P']
# Item Sequence for idx 491: ['item_B000K19HYY', 'item_B00DVMEJHE']
# Item Sequence for idx 492: ['item_B011DGZH8Y', 'item_B005QIZIYO', 'item_B075FSQFPY']
# Item Sequence for idx 493: ['item_B000068NYF', 'item_B001FWYAXA', 'item_B000EEL6IW']
# Item Sequence for idx 494: ['item_B07QPX7BK2', 'item_B01H7X90DU', 'item_B00E6B7ZLQ', 'item_B007JMWS52']
# Item Sequence for idx 495: ['item_B001GZFYLI', 'item_B0002KZE7C', 'item_B000MFL7UU', 'item_B0140WN5DW']
# Item Sequence for idx 496: ['item_B0791KJQL1', 'item_B01AAH5BIS']
# Item Sequence for idx 497: ['item_B01J33CE5S', 'item_B000RW270M', 'item_B0002D0CQC', 'item_B08D5DB977']
# Item Sequence for idx 498: ['item_B0002D0CQC', 'item_B08D5DB977', 'item_B0002F73KI']
# Item Sequence for idx 499: ['item_B08HNBMDVL', 'item_B01LX1H4HC', 'item_B07KSXLKCX', 'item_B01BLRG39W']
# Item Sequence for idx 500: ['item_B07KSXLKCX', 'item_B01BLRG39W', 'item_B07L5B64RG', 'item_B00JYG7LIU']
# Item Sequence for idx 501: ['item_B07L5B64RG', 'item_B00JYG7LIU', 'item_B005NCDIOK', 'item_B0107BB4XS']
# Item Sequence for idx 502: ['item_B003TLY9HM', 'item_B00PLJOHHM', 'item_B00IUBNZO4']
# Item Sequence for idx 503: ['item_B004OK1G64', 'item_B012VQ5A7S']
# Item Sequence for idx 504: ['item_B00L42NICA', 'item_B004P4PZHA', 'item_B008YDTVW8']
# Item Sequence for idx 505: ['item_B0002PBS68', 'item_B01EGPJ67C', 'item_B07N28B35J']
# Item Sequence for idx 506: ['item_B001AS6OYC', 'item_B0002BACB4', 'item_B002T45X1G']
# Item Sequence for idx 507: ['item_B01N4DSQBR', 'item_B07T3ZJDLY']
# Item Sequence for idx 508: ['item_B01I6I1DM6', 'item_B08PFBZ994', 'item_B01N9BDJG0']
# Item Sequence for idx 509: ['item_B0002KZJIQ', 'item_B0838KLZXW', 'item_B07JYQ6S3X', 'item_B07BQNG6KL']
# Item Sequence for idx 510: ['item_B002GDFYWS', 'item_B07N8K3VZB', 'item_B01N21H9WY', 'item_B01L3LL95O']
# Item Sequence for idx 511: ['item_B0924BQ4B2', 'item_B09C5SPKPM']
# Item Sequence for idx 512: ['item_B001IM5KFY', 'item_B00DDTYN6C']
# Item Sequence for idx 513: ['item_B016N052M6', 'item_B01L77PE5A']
# Item Sequence for idx 514: ['item_B00EOID8SU', 'item_B0007L8BQW']
# Item Sequence for idx 515: ['item_B00HZQ7RVM', 'item_B0064YN4EK', 'item_B0057E3HUY', 'item_B003KYGVWE']
# Item Sequence for idx 516: ['item_B01HA0LDF8', 'item_B071XPM68Z']
# Item Sequence for idx 517: ['item_B0143H0W3U', 'item_B011BV9P34', 'item_B007J0UWMU']
# Item Sequence for idx 518: ['item_B06XFGZ6L8', 'item_B01E017BQU', 'item_B000Z0FE5G']
# Item Sequence for idx 519: ['item_B01M6Z809D', 'item_B00I01NY9K']
# Item Sequence for idx 520: ['item_B075Q8WNG9', 'item_B083ZXFX9J', 'item_B00GL64S0U', 'item_B08M42WR5D']
# Item Sequence for idx 521: ['item_B005SUVFXI', 'item_B0106MVL90']
# Item Sequence for idx 522: ['item_B01D53JG5I', 'item_B089D48YGJ', 'item_B07FDFLJ2Q']
# Item Sequence for idx 523: ['item_B00FB2VAY2', 'item_B075VF5B44']
# Item Sequence for idx 524: ['item_B00178JDCK', 'item_B000WQBIEO', 'item_B011MYKBZ6', 'item_B002YNHZI6']
# Item Sequence for idx 525: ['item_B0002E1G5C', 'item_B003VWJ2K8', 'item_B009GS6Z3S', 'item_B0006GR4L6']
# Item Sequence for idx 526: ['item_B009GS6Z3S', 'item_B0006GR4L6']
# Item Sequence for idx 527: ['item_B0002F58G4', 'item_B001B4EKNC', 'item_B0010KVKPI']
# Item Sequence for idx 528: ['item_B01D80KW88', 'item_B07574VQPQ', 'item_B06ZYZMD8Q', 'item_B01MXOWKBV']
# Item Sequence for idx 529: ['item_B009RTYYZC', 'item_B0014598WQ']
# Item Sequence for idx 530: ['item_B0002ZO3RO', 'item_B0002GIYMS', 'item_B0002H0A3S', 'item_B004VDD4KK']
# Item Sequence for idx 531: ['item_B001L8PIFW', 'item_B0002E3DNK', 'item_B0002BG2DQ', 'item_B00B2M5HEY']
# Item Sequence for idx 532: ['item_B008I1XD2A', 'item_B01BO66EQM']
# Item Sequence for idx 533: ['item_B0064RTUP4', 'item_B01FX45DUE', 'item_B08TQ9X7K7']
# Item Sequence for idx 534: ['item_B00EJCYSMQ', 'item_B01MQSAU6P']
# Item Sequence for idx 535: ['item_B0B9BTB3RW', 'item_B0BRCRLV5M']
# Item Sequence for idx 536: ['item_B0719CBYXJ', 'item_B00GMCCPR6']
# Item Sequence for idx 537: ['item_B000A1LA4O', 'item_B000BHT940']
# Item Sequence for idx 538: ['item_B001AWWN9I', 'item_B00NAUKJTY', 'item_B00H2MA644', 'item_B01FQ9RV88']
# Item Sequence for idx 539: ['item_B00D0GV3RA', 'item_B004PR4ADW', 'item_B01EUHEBDA', 'item_B072KQGD9Y']
# Item Sequence for idx 540: ['item_B00LIO8PU4', 'item_B001VS84N0', 'item_B007BKCD4I', 'item_B0002D0H9O']
# Item Sequence for idx 541: ['item_B007BKCD4I', 'item_B0002D0H9O', 'item_B0002D0DWK']
# Item Sequence for idx 542: ['item_B00UN8O5VO', 'item_B01N78G0KT']
# Item Sequence for idx 543: ['item_B001U5JFNM', 'item_B0002GJTH2', 'item_B000068O53', 'item_B01E4QT1PA']
# Item Sequence for idx 544: ['item_B003YCUGJ6', 'item_B00SO607IC']
# Item Sequence for idx 545: ['item_B004ICMJPK', 'item_B01I5EKQRY']
# Item Sequence for idx 546: ['item_B004DR0N7G', 'item_B0002DVB9Y', 'item_B00L9JDS46', 'item_B001QCXSH8']
# Item Sequence for idx 547: ['item_B00GYCDZF0', 'item_B0002LXY2I', 'item_B000KEY7MS', 'item_B004RWCW1W']
# Item Sequence for idx 548: ['item_B005GWK066', 'item_B01LSHMR86', 'item_B01IHISEY0']
# Item Sequence for idx 549: ['item_B00QNU4BL0', 'item_B07TT83XJ2']
# Item Sequence for idx 550: ['item_B0145X9SFK', 'item_B07HCKY79R', 'item_B0756V1WNZ']
# Item Sequence for idx 551: ['item_B07K8FQFN8', 'item_B000EELA3I', 'item_B00B052MZK']
# Item Sequence for idx 552: ['item_B09TPSGY1V', 'item_B00M5DWB5W']
# Item Sequence for idx 553: ['item_B005JI96SK', 'item_B000XPSI10', 'item_B003ML6N1E', 'item_B07NDW6XRS']
# Item Sequence for idx 554: ['item_B00FPWF59Y', 'item_B00FC4YPL4', 'item_B00B8VYARE', 'item_B005EYMNLQ']
# Item Sequence for idx 555: ['item_B00B8VYARE', 'item_B005EYMNLQ', 'item_B000CCSWQA', 'item_B07DCFGK6M']
# Item Sequence for idx 556: ['item_B07FBBVRG7', 'item_B0814QHWGK']
# Item Sequence for idx 557: ['item_B00A6D50L0', 'item_B0006NDF8A', 'item_B0092V7WJ0']
# ...
# Item Sequence for idx 3402: ['item_B000F51B8U', 'item_B00006HO3L', 'item_B01MEGMG32', 'item_B000GG4B08']
# Item Sequence for idx 3403: ['item_B000EEHKVY', 'item_B00JA4T6RU']
# Item Sequence for idx 3404: ['item_B079FRVSPH', 'item_B0768R4GHS']
# Item Sequence for idx 3405: ['item_B0079KQEOK', 'item_B006MB971E']
# Item Sequence for idx 3406: ['item_B06ZYXLN2J', 'item_B08B4GNWVB']
# Item Sequence for idx 3407: ['item_B078WXWNBT', 'item_B07L5B64RG']
# Item Sequence for idx 3408: ['item_B0023BYDHK', 'item_B00JNOUDX8']
# Item Sequence for idx 3409: ['item_B073QP48RV', 'item_B08F1ZHYF8']
# Item Sequence for idx 3410: ['item_B074KGZ9Z7', 'item_B019WTLVKW', 'item_B0002DUQ0O', 'item_B082QLTZD2']
# Item Sequence for idx 3411: ['item_B00E9SXJH0', 'item_B07ZCTRPLQ', 'item_B06XGZYDMX', 'item_B07PFCZ716']
# Item Sequence for idx 3412: ['item_B06XGZYDMX', 'item_B07PFCZ716', 'item_B07C44MK1N', 'item_B0002D0EA6']
# Item Sequence for idx 3413: ['item_B01M6C0Y4T', 'item_B077P1J2KN', 'item_B00AUMCC9A', 'item_B018ECP1VS']
# Item Sequence for idx 3414: ['item_B0007P3528', 'item_B0747TD557']
# Item Sequence for idx 3415: ['item_B004N0MKN8', 'item_B000TGSM6E', 'item_B0002E1O5E', 'item_B0002GJ6FC']
# Item Sequence for idx 3416: ['item_B0013CF3M4', 'item_B07SRCPBQN']
# Item Sequence for idx 3417: ['item_B004RHG2S6', 'item_B00RZIH52G']
# Item Sequence for idx 3418: ['item_B004N0MKN8', 'item_B00O4L3F9E', 'item_B002EWPX54', 'item_B000LFCXL8']
# Item Sequence for idx 3419: ['item_B01JO7AEK0', 'item_B00Y44AAR6', 'item_B07NWG39JM', 'item_B07NQRLGJM']
# Item Sequence for idx 3420: ['item_B0007XE8YO', 'item_B0047N284W']
# Item Sequence for idx 3421: ['item_B01NAX38FV', 'item_B07CWLS8D1']
# Item Sequence for idx 3422: ['item_B076F5W8Q5', 'item_B071H2PDHN']
# Item Sequence for idx 3423: ['item_B011EXBCMQ', 'item_B00006LVFF']
# Item Sequence for idx 3424: ['item_B0046XSEA0', 'item_B000OR2S86', 'item_B01B9IDFHQ', 'item_B01AKRA4PS']
# Item Sequence for idx 3425: ['item_B000RXPQSQ', 'item_B00GRRN2RI', 'item_B000P5YFDI', 'item_B003HGFRO8']
# Item Sequence for idx 3426: ['item_B00HG29EYI', 'item_B08QG55PFS', 'item_B00FUTXO8G', 'item_B01N94UUD0']
# Item Sequence for idx 3427: ['item_B06WRNX97S', 'item_B0002TKIRY']
# Item Sequence for idx 3428: ['item_B089CQ9XPD', 'item_B01N40AOA3']
# Item Sequence for idx 3429: ['item_B08K7J54DV', 'item_B07BZZWP8M', 'item_B0B4R8F7Q5', 'item_B01MUWGAGB']
# Item Sequence for idx 3430: ['item_B000FET3DG', 'item_B075KL6ZLC']
# Item Sequence for idx 3431: ['item_B07DV2XGP5', 'item_B07JNCZ1RJ']
# Item Sequence for idx 3432: ['item_B00YJ5C46K', 'item_B00N4Q25R8']
# Item Sequence for idx 3433: ['item_B00N2A6V94', 'item_B08CK97FJG', 'item_B00GXMTZE6', 'item_B07G5XWQ6B']
# Item Sequence for idx 3434: ['item_B07C91V711', 'item_B0051HNHES', 'item_B07KP2X2VP', 'item_B01D2QPWOM']
# Item Sequence for idx 3435: ['item_B08YH3935J', 'item_B072MNFZJV', 'item_B08YN8KKWR', 'item_B000A8J3N2']
# Item Sequence for idx 3436: ['item_B08YN8KKWR', 'item_B000A8J3N2', 'item_B000NE4UN6', 'item_B00N3EHVNO']
# Item Sequence for idx 3437: ['item_B008VVTL28', 'item_B00JB2EXZQ', 'item_B00NAUHX1G', 'item_B01ANJGX8U']
# Item Sequence for idx 3438: ['item_B00T8L27ZI', 'item_B00HEKV2JM', 'item_B0002D0AN2', 'item_B0002F7IN0']
# Item Sequence for idx 3439: ['item_B001ECQQ8I', 'item_B000WKW8EY']
# Item Sequence for idx 3440: ['item_B01L3LL95O', 'item_B00MK1QKF6', 'item_B07LF8FZKL']
# Item Sequence for idx 3441: ['item_B00I44TU8C', 'item_B0009E6RQS', 'item_B000XPUKB6', 'item_B002FMOMPU']
# Item Sequence for idx 3442: ['item_B089D48YGJ', 'item_B08GNZPHHF', 'item_B0018TUTSK']
# Item Sequence for idx 3443: ['item_B0197NP6Y0', 'item_B081PYJF8G']
# Item Sequence for idx 3444: ['item_B01M4QA5QB', 'item_B00GRRN2RI', 'item_B004MNB2QW']
# Item Sequence for idx 3445: ['item_B07289FZW7', 'item_B01A5U6A9Y', 'item_B00HWIRQ6O']
# Item Sequence for idx 3446: ['item_B00A4C9GSG', 'item_B00CSLIZ5Q', 'item_B0002E1I2I', 'item_B00T631UTC']
# Item Sequence for idx 3447: ['item_B001DW6RJC', 'item_B0002D0EII']
# Item Sequence for idx 3448: ['item_B0002E4ZKU', 'item_B00O34SND0', 'item_B0099XQBD4']
# Item Sequence for idx 3449: ['item_B005XOE7OI', 'item_B01H74YY62']
# Item Sequence for idx 3450: ['item_B00EKFH2UM', 'item_B0002F6JFS', 'item_B0055VBYWC']
# Item Sequence for idx 3451: ['item_B07VFF4JFL', 'item_B096RHCXS3']
# Item Sequence for idx 3452: ['item_B0002E382Q', 'item_B0002E38B2', 'item_B002JCSOZU', 'item_B000HQMS2U']
# Item Sequence for idx 3453: ['item_B000KIVMEK', 'item_B002X8Y4SQ', 'item_B000SJJCX4', 'item_B00INNJZPC']
# Item Sequence for idx 3454: ['item_B004D1E85U', 'item_B07BZWZQDD', 'item_B00ZGI5JN4', 'item_B07HM8Q5FR']
# Item Sequence for idx 3455: ['item_B002C4QWZO', 'item_B0002D0JX8', 'item_B01C2A93VC']
# Item Sequence for idx 3456: ['item_B0002D15JU', 'item_B01GHGJ8AI', 'item_B01HOTB5LC']
# Item Sequence for idx 3457: ['item_B011J65M56', 'item_B0002CZR7C', 'item_B0775CBC5R', 'item_B0719CBYXJ']
# Item Sequence for idx 3458: ['item_B0775CBC5R', 'item_B0719CBYXJ', 'item_B000VTIT7Q', 'item_B07Y9KLDV2']
# Item Sequence for idx 3459: ['item_B01N1HJKKX', 'item_B07JMYG6LF']
# Item Sequence for idx 3460: ['item_B000SL4656', 'item_B002GIJVXG', 'item_B006K35QIC', 'item_B0002GML4U']
# Item Sequence for idx 3461: ['item_B00NP8GYVS', 'item_B08LD1D3C8']
# Item Sequence for idx 3462: ['item_B00B6WZGHS', 'item_B00UJ9LNDK', 'item_B01B15JPCQ']
# Item Sequence for idx 3463: ['item_B0006Z4B6I', 'item_B08MVXX5ZX', 'item_B00ECANPOM', 'item_B00GESGHFE']
# Item Sequence for idx 3464: ['item_B00DDTYKR4', 'item_B0001DBZNM', 'item_B00O1I7I52']
# Item Sequence for idx 3465: ['item_B003YVPELM', 'item_B003VWJ2K8', 'item_B003HUWCLA', 'item_B0064BJHRQ']
# Item Sequence for idx 3466: ['item_B0051UUIH4', 'item_B004BZU4OW']
# Item Sequence for idx 3467: ['item_B00314BDOY', 'item_B003ZHVCPC', 'item_B0009V8YXA']
# Item Sequence for idx 3468: ['item_B00BU9KCXK', 'item_B07RGJ87NV', 'item_B015FTM7TW']
# Item Sequence for idx 3469: ['item_B018FCZKR2', 'item_B00N1YPXW2']
# Item Sequence for idx 3470: ['item_B091765QTK', 'item_B00XQEA1FG']
# Item Sequence for idx 3471: ['item_B0006NL5SM', 'item_B00OU28P5Q']
# Item Sequence for idx 3472: ['item_B004J953TQ', 'item_B002UXFV40', 'item_B0035LCFR2', 'item_B000EEL6J6']
# Item Sequence for idx 3473: ['item_B00MJXNEWW', 'item_B09VRZS33Z', 'item_B082YKY3QR', 'item_B08QVJBC5H']
# Item Sequence for idx 3474: ['item_B00GD1JBIM', 'item_B01N5KND14']
# Item Sequence for idx 3475: ['item_B01H74YV56', 'item_B002DPGV2G']
# Item Sequence for idx 3476: ['item_B01DK723AY', 'item_B00PHVGGMI']
# Item Sequence for idx 3477: ['item_B071P4P5DJ', 'item_B00NH0OA1K']
# Item Sequence for idx 3478: ['item_B076C9YCCL', 'item_B000B6AGCA', 'item_B000XPRUX2', 'item_B0002F7KGU']
# Item Sequence for idx 3479: ['item_B08LDVW3VD', 'item_B08LZMSBF6', 'item_B06XYYKDSX', 'item_B0087HEO64']
# Item Sequence for idx 3480: ['item_B07L66JYX6', 'item_B07987K4F5']
# Item Sequence for idx 3481: ['item_B00PIQMT7S', 'item_B0002D0A8C']
# Item Sequence for idx 3482: ['item_B004XLFKIO', 'item_B00I9FL3OA']
# Item Sequence for idx 3483: ['item_B00006HO3R', 'item_B00DU66WWQ', 'item_B00DU66WVM']
# Item Sequence for idx 3484: ['item_B082KGC61N', 'item_B08VGRD32N', 'item_B08B32WH76']
# Item Sequence for idx 3485: ['item_B092HSJ4K6', 'item_B00O4L3F9E']
# Item Sequence for idx 3486: ['item_B0002F4Y8W', 'item_B00GD1JDV2', 'item_B004SBOGSE', 'item_B01HRHZ7AQ']
# Item Sequence for idx 3487: ['item_B07MM69SV5', 'item_B07QKTJKPQ', 'item_B07NDT1SZJ', 'item_B07VKQL684']
# Item Sequence for idx 3488: ['item_B096XCZ94Q', 'item_B08QTVP49Q', 'item_B095PBNM93', 'item_B097R6MBCC']
# Item Sequence for idx 3489: ['item_B015NBV43M', 'item_B07TGPSSMZ']
# Item Sequence for idx 3490: ['item_B01B9IDFSK', 'item_B00JLKS23C', 'item_B01ASX1H0K', 'item_B01H3D0QIM']
# Item Sequence for idx 3491: ['item_B01NBNS2OA', 'item_B01MSCTIB5', 'item_B07SWXMFJV', 'item_B07PTMKPY5']
# Item Sequence for idx 3492: ['item_B00B2BZGZA', 'item_B01E12IPI6', 'item_B00ISKJJ5Q', 'item_B01FVAXMBW']
# Item Sequence for idx 3493: ['item_B0038XUDW6', 'item_B0002FOLPI']
# Item Sequence for idx 3494: ['item_B0016MNBAM', 'item_B005W2EXQI', 'item_B00KC4JMAS']
# Item Sequence for idx 3495: ['item_B07H1S4C4T', 'item_B07MF44LC2']
# Item Sequence for idx 3496: ['item_B001R2NS7C', 'item_B003VWJ2K8', 'item_B01KZRPOS0', 'item_B00AKGAH4S']
# Item Sequence for idx 3497: ['item_B00XKM6PPO', 'item_B01KPYGBR6']
# Item Sequence for idx 3498: ['item_B00NG54D4U', 'item_B01H74YV56', 'item_B009L4VZ0K', 'item_B0147FVGW4']
# Item Sequence for idx 3499: ['item_B000068O4K', 'item_B000RMQM4E', 'item_B00C78WF74', 'item_B000ZJWI2O']
# Item Sequence for idx 3500: ['item_B003VWKPHC', 'item_B00VMB8IW8', 'item_B001L8MB6G', 'item_B0052M17SK']
# Item Sequence for idx 3501: ['item_B00PHVGGMI', 'item_B00PCOIA0Q']
# Item Sequence for idx 3502: ['item_B014F1UKI6', 'item_B07K8FQFN8']
# Item Sequence for idx 3503: ['item_B0015MCGG8', 'item_B0002FOBJY', 'item_B00ICR2UL0', 'item_B00ICR2T20']
# Item Sequence for idx 3504: ['item_B00ICR2UL0', 'item_B00ICR2T20', 'item_B0002D0ABY', 'item_B09P4XM3FC']
# Item Sequence for idx 3505: ['item_B0178QBDP4', 'item_B01JB0SPEC', 'item_B0861BNGLP', 'item_B001631NEC']
# Item Sequence for idx 3506: ['item_B00012F7G4', 'item_B00CTKI10A']
# Item Sequence for idx 3507: ['item_B00Z9TIXOC', 'item_B07785J8Q4']
# Item Sequence for idx 3508: ['item_B00O5EL4MA', 'item_B00WU5OM5M', 'item_B015WSQKEE', 'item_B00B1YOENI']
# Item Sequence for idx 3509: ['item_B010KPZ6Y4', 'item_B00BN5FDM6', 'item_B004H1KBKM', 'item_B004KNTU72']
# Item Sequence for idx 3510: ['item_B08B32WH76', 'item_B001IM5KFY', 'item_B09BPV32H7', 'item_B01IQ4629Y']
# Item Sequence for idx 3511: ['item_B004Z2G2T2', 'item_B00352MHGK', 'item_B00F9FPWYU', 'item_B011QEVO44']
# Item Sequence for idx 3512: ['item_B003LPTAYI', 'item_B014MQ22XU', 'item_B00CFS5P6Y']
# Item Sequence for idx 3513: ['item_B004XNK7AI', 'item_B075HHPRTH']
# Item Sequence for idx 3514: ['item_B00GOIC1S6', 'item_B00CBISHS6']
# Item Sequence for idx 3515: ['item_B00BTGMI5O', 'item_B07Y9X8ZYW', 'item_B09J563DZ5']
# Item Sequence for idx 3516: ['item_B000068NUU', 'item_B00063678K', 'item_B00HIRARLA', 'item_B00IMPJV7S']
# Item Sequence for idx 3517: ['item_B000DZXTFK', 'item_B001HNA6ZI', 'item_B0002F7KFQ']
# Item Sequence for idx 3518: ['item_B001RBQFCI', 'item_B00KMF11BA', 'item_B0002DV7ZM', 'item_B01H74YV56']
# Item Sequence for idx 3519: ['item_B0002J6HM4', 'item_B001JJB2GM']
# Item Sequence for idx 3520: ['item_B00B9060X6', 'item_B000068NW5', 'item_B00BTGMI5O', 'item_B00MIXFBKG']
# Item Sequence for idx 3521: ['item_B00EQ25FWQ', 'item_B000LAPVGM', 'item_B0002Y6BJI', 'item_B0002PBS68']
# Item Sequence for idx 3522: ['item_B07RLLJ91J', 'item_B01E6T547Y', 'item_B00VHKM190', 'item_B07W3146WH']
# Item Sequence for idx 3523: ['item_B009WS7V5I', 'item_B07VS3VWFT', 'item_B07VW6QCVC']
# Item Sequence for idx 3524: ['item_B00C5B1AZG', 'item_B00TV90MT0']
# Item Sequence for idx 3525: ['item_B001VS90M4', 'item_B000FP92JK']
# Item Sequence for idx 3526: ['item_B000P62H7I', 'item_B006LW72XY', 'item_B00IKHBXN8', 'item_B00WHLLDWO']
# Item Sequence for idx 3527: ['item_B001R76D42', 'item_B00O51A7TO', 'item_B01CSAATY6', 'item_B00VGR75UO']
# Item Sequence for idx 3528: ['item_B000EEJAWQ', 'item_B002NLSCPE', 'item_B0035K28KC', 'item_B0028GWJCG']
# Item Sequence for idx 3529: ['item_B0010CZ8GS', 'item_B0097WDJZA', 'item_B000068NYN', 'item_B00V3A65NM']
# Item Sequence for idx 3530: ['item_B07DHLCRKD', 'item_B00OB7K46I']
# Item Sequence for idx 3531: ['item_B0002E2KKC', 'item_B07G3HPKK4']
# Item Sequence for idx 3532: ['item_B0825D1W2D', 'item_B073C6HH1R', 'item_B07MJPM33Y']
# Item Sequence for idx 3533: ['item_B01N327U2K', 'item_B07H8T6KLK', 'item_B00MUFJXTM', 'item_B075CYXSRY']
# Item Sequence for idx 3534: ['item_B003D2VT2K', 'item_B0036UTTBC', 'item_B00VG6A37C', 'item_B0002BG4NO']
# Item Sequence for idx 3535: ['item_B0002F51B6', 'item_B0087HEO64']
# Item Sequence for idx 3536: ['item_B08W51VKTF', 'item_B08T7FX7QL', 'item_B0773M39P6']
# Item Sequence for idx 3537: ['item_B007Y0TJ38', 'item_B0030O0Q2U', 'item_B0001ARCFA']
# Item Sequence for idx 3538: ['item_B005ES7VSW', 'item_B003H3JKX0']
# Item Sequence for idx 3539: ['item_B000788VVU', 'item_B014LTK4D8', 'item_B000068NYH']
# Item Sequence for idx 3540: ['item_B072DXG4T7', 'item_B09BN6Q7V2']
# Item Sequence for idx 3541: ['item_B00TUMJLY0', 'item_B0002E1G5C', 'item_B00JQYUIJ4']
# Item Sequence for idx 3542: ['item_B00HX40Q3C', 'item_B0051M6JJI', 'item_B00L349XUU', 'item_B07PH6KF6W']
# Item Sequence for idx 3543: ['item_B00L349XUU', 'item_B07PH6KF6W']
# Item Sequence for idx 3544: ['item_B0002Z2CZY', 'item_B008GS9UNQ', 'item_B003B067YE']
# Item Sequence for idx 3545: ['item_B00O4L3F9E', 'item_B019BNMVFI', 'item_B08FJ5DYR8', 'item_B0895GW4NK']
# Item Sequence for idx 3546: ['item_B01N7WET79', 'item_B077N2KJZX', 'item_B00IACCJLI', 'item_B01N79XU4D']
# Item Sequence for idx 3547: ['item_B00IACCJLI', 'item_B01N79XU4D', 'item_B07MM42BNG', 'item_B07FB944VD']
# Item Sequence for idx 3548: ['item_B003UCZMLW', 'item_B00EQ29HAM', 'item_B011SESKTY', 'item_B00A8SYWUS']
# Item Sequence for idx 3549: ['item_B0772MTRSH', 'item_B00SY3422M', 'item_B07Y3NCHR9']
# Item Sequence for idx 3550: ['item_B00GOIC1S6', 'item_B00YJ5C46K']
# Item Sequence for idx 3551: ['item_B08HYJ33RX', 'item_B07PQKTSQP', 'item_B003V4E1AC']
# Item Sequence for idx 3552: ['item_B07BP53PQ6', 'item_B000FLLUU8', 'item_B002SPLBFI', 'item_B07CNHDHTJ']
# Item Sequence for idx 3553: ['item_B07556N9JG', 'item_B00CQEHK6U']
# Item Sequence for idx 3554: ['item_B085DSPQW3', 'item_B07DCQW156']
# Item Sequence for idx 3555: ['item_B000978D58', 'item_B07Z3GKWH8']
# Item Sequence for idx 3556: ['item_B06XGH58GY', 'item_B08KJHRCGV', 'item_B079DWQTQT']
# Item Sequence for idx 3557: ['item_B004M3OXL8', 'item_B00FX7MMRO', 'item_B004YGMOSC', 'item_B00N1YPXW2']
# Item Sequence for idx 3558: ['item_B084D6SBMR', 'item_B07FRZNCGG', 'item_B01I6I1BSC', 'item_B000VY8INQ']
# Item Sequence for idx 3559: ['item_B00AWTTAWS', 'item_B004WLLX22', 'item_B0033PQUB2']
# Item Sequence for idx 3560: ['item_B00GVMH3HY', 'item_B003CLIPHO', 'item_B00TY8JE60']
# Item Sequence for idx 3561: ['item_B000QDRTNW', 'item_B001JT0L46']
# Item Sequence for idx 3562: ['item_B08KRP6FJR', 'item_B085VD8ZS1', 'item_B08HWTPRQQ', 'item_B08NK4772T']
# Item Sequence for idx 3563: ['item_B08HWTPRQQ', 'item_B08NK4772T', 'item_B07WTK92MV', 'item_B08PHKFP6G']
# Item Sequence for idx 3564: ['item_B09542FSQH', 'item_B094JRCY9G', 'item_B08Z3MYFZ4', 'item_B093S2G5MV']
# Item Sequence for idx 3565: ['item_B08Z3MYFZ4', 'item_B093S2G5MV', 'item_B091WWWVPS', 'item_B085G662CW']
# Item Sequence for idx 3566: ['item_B08KZQMWTN', 'item_B08KZV2877', 'item_B08M5C8Y95', 'item_B08T75ZPGT']
# Item Sequence for idx 3567: ['item_B073RMQKYG', 'item_B00QHURLCW', 'item_B00106OTJG', 'item_B07NDW2L5L']
# Item Sequence for idx 3568: ['item_B00106OTJG', 'item_B07NDW2L5L', 'item_B078C5HCVP', 'item_B07WT3XD6W']
# Item Sequence for idx 3569: ['item_B077B67GD6', 'item_B078Y79BFV']
# Item Sequence for idx 3570: ['item_B0002GO8XC', 'item_B0063GIQH4', 'item_B0002M72JS', 'item_B005IYUWX8']
# Item Sequence for idx 3571: ['item_B00805CQ7C', 'item_B01JNLUMMW']
# Item Sequence for idx 3572: ['item_B00HG29EYI', 'item_B01ATUKVF4', 'item_B076346CZ9', 'item_B07QNCC6LR']
# Item Sequence for idx 3573: ['item_B08CSPJTTJ', 'item_B00ZO92VSQ', 'item_B01MD1VZCU', 'item_B06XG2LJXN']
# Item Sequence for idx 3574: ['item_B08DHSHG7K', 'item_B00PU048K8', 'item_B00CE2047Q', 'item_B0002MSQVQ']
# Item Sequence for idx 3575: ['item_B0007XWUQ2', 'item_B0002CZX62']
# Item Sequence for idx 3576: ['item_B00XP5W6EK', 'item_B076F5W8Q5']
# Item Sequence for idx 3577: ['item_B005M35B6S', 'item_B00MMTWQ4U']
# Item Sequence for idx 3578: ['item_B000XPUTY4', 'item_B003INZ0DI']
# Item Sequence for idx 3579: ['item_B0002GLCRC', 'item_B00095VIMU', 'item_B005M2O4U8', 'item_B00J63Q5M4']
# Item Sequence for idx 3580: ['item_B000NJ2TIE', 'item_B000J5UEGQ', 'item_B0027GE33A', 'item_B001U1QLO2']
# Item Sequence for idx 3581: ['item_B01CRFT290', 'item_B07L4HQ2X5', 'item_B004XWDYO0']
# Item Sequence for idx 3582: ['item_B07DN6W9Z1', 'item_B0000775FZ', 'item_B083QMXM1D', 'item_B07G2QP5MK']
# Item Sequence for idx 3583: ['item_B00O4L3F9E', 'item_B0002CZVWI', 'item_B015NBUZEG', 'item_B00V7YMOLG']

# %%
from sklearn.metrics import ndcg_score

# Since we have already sorted our recommendations
# An array that represent our recommendation scores is used.
representative_array = [[i for i in range(k, 0, -1)]] * len(transformer_reco_results)

for k in [3, 5, 10]:
  transformer_result = ndcg_score(transformer_reco_results,
                                  representative_array, k=k)
  popular_result = ndcg_score(popular_reco_results,
                              representative_array, k=k)

  print(f"Transformer NDCG result at top {k}: {round(transformer_result, 4)}")
  print(f"Popular recommendation NDCG result at top {k}: {round(popular_result, 4)}\n\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c7177e6214d5> in <cell line: 5>()
#       3 # Since we have already sorted our recommendations
#       4 # An array that represent our recommendation scores is used.
# ----> 5 representative_array = [[i for i in range(k, 0, -1)]] * len(transformer_reco_results)
#       6
#       7 for k in [3, 5, 10]:
#
# NameError: name 'k' is not defined
